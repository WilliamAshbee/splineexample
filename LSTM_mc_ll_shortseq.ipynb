# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/LSTM_mc_ll_shortseq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %% [markdown]
# https://r2rt.com/non-zero-initial-states-for-recurrent-neural-networks.html

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):
    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}


def plot_all( sample = None, model = None, labels = None):
    img = sample[:,:].squeeze().cpu().numpy()
    #img = img.T
    plt.imshow(img, cmap=plt.cm.gray_r)
    if model != None:
        with torch.no_grad():
            global numpoints
            print(labels.shape,sample.shape)
            sample = torch.stack([sample for i in range(2)],dim = 0).cuda()
            labels = torch.stack([labels for i in range(2)],dim = 0).cuda()
            h0 = None
            c0 = None
            X = []
            Y = []
            for i in range(3):
              if i == 0:
                out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
              else:
                out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
                
              X.extend(out[0,:,0].tolist())
              Y.extend(out[0,:,1].tolist())

            predres = len(X)

            s = [.001 for x in range(predres)]
            
            assert len(s) == predres
            c = ['red' for x in range(predres)]
            assert len(c) == predres
            #print("type",type(X))
            ascatter = plt.scatter(X,Y,s = s,c = c)
            plt.gca().add_artist(ascatter)
    else:
        #print(labels.shape)
        X = labels[:,0]
        Y = labels[:,1]
        #print(X.shape)
        #print(Y.shape)
        s = [.001 for x in range(numpoints)]
        #print(len(s))
        c = ['red' for x in range(numpoints)]
        #print(len(c))
        ascatter = plt.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
        plt.gca().add_artist(ascatter)

class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        for i in range(100):
            sample, labels = dataset[i]
            plt.subplot(10,10,i+1)
            plot_all(sample = sample,model=model, labels = labels)
            plt.axis('off')
        plt.savefig(title,dpi=600)

dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
for i in range(100):
  print(torch.sum(dataset[i][0]))
# Out:
# tensor(84.)
# tensor(133.)
# tensor(119.)
# tensor(213.)
# tensor(241.)
# tensor(252.)
# tensor(105.)
# tensor(162.)
# tensor(103.)
# tensor(151.)
# tensor(89.)
# tensor(134.)
# tensor(102.)
# tensor(108.)
# tensor(106.)
# tensor(122.)
# tensor(91.)
# tensor(87.)
# tensor(123.)
# tensor(222.)
# tensor(86.)
# tensor(83.)
# tensor(141.)
# tensor(146.)
# tensor(172.)
# tensor(122.)
# tensor(109.)
# tensor(100.)
# tensor(89.)
# tensor(159.)
# tensor(68.)
# tensor(104.)
# tensor(177.)
# tensor(84.)
# tensor(93.)
# tensor(180.)
# tensor(67.)
# tensor(138.)
# tensor(79.)
# tensor(97.)
# tensor(207.)
# tensor(141.)
# tensor(154.)
# tensor(112.)
# tensor(149.)
# tensor(148.)
# tensor(143.)
# tensor(127.)
# tensor(210.)
# tensor(99.)
# tensor(109.)
# tensor(214.)
# tensor(113.)
# tensor(90.)
# tensor(107.)
# tensor(104.)
# tensor(160.)
# tensor(128.)
# tensor(79.)
# tensor(172.)
# tensor(103.)
# tensor(116.)
# tensor(89.)
# tensor(152.)
# tensor(202.)
# tensor(217.)
# tensor(124.)
# tensor(154.)
# tensor(180.)
# tensor(216.)
# tensor(151.)
# tensor(74.)
# tensor(230.)
# tensor(67.)
# tensor(184.)
# tensor(107.)
# tensor(99.)
# tensor(116.)
# tensor(107.)
# tensor(163.)
# tensor(104.)
# tensor(80.)
# tensor(75.)
# tensor(84.)
# tensor(79.)
# tensor(199.)
# tensor(107.)
# tensor(81.)
# tensor(97.)
# tensor(188.)
# tensor(102.)
# tensor(203.)
# tensor(151.)
# tensor(65.)
# tensor(192.)
# tensor(126.)
# tensor(93.)
# tensor(209.)
# tensor(228.)
# tensor(152.)

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
dataset = DonutDataset(length = 64*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1280, 1]) torch.Size([1280, 1]) torch.Size([1280, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 50
        self.lm_len = 20
        self.longtermMem = None
        self.longtermMemP = None
        # lstm cell
        self.lstm_cell = nn.LSTM(2+1024, self.hidden_size,self.num_layers)

        
        
        self.fc_out = nn.Sequential(
            nn.Linear(2+self.hidden_size+1024,10000),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(10000,2),
            nn.Sigmoid()
        )
        
        


        

            
        
    def forward(self, features, captions,h0 = None, c0= None,ind = 0, o = None):

        assert features != None
        self.track +=1
        batch_size = features.size(0)
        

        #img_emb = torch.empty((batch_size, captions.size(1), self.hidden_size)).cuda()
        
        p0 = torch.flatten(captions[:,0,:2],start_dim=1)
        

        if o == None:
          out = p0
          #self.longtermMem = torch.zeros(batch_size,self.hidden_size,self.lm_len).cuda()
        else:
          out = o

                
        if h0 == None and c0 == None:
          h0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
          c0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
        
        
        if self.num_layers>1 and h0.shape[0] == 1:
          h0 = torch.stack([h0.detach().clone().squeeze() for i in range(self.num_layers)],dim = 0)
          c0 = torch.stack([c0.detach().clone().squeeze() for i in range(self.num_layers)],dim = 0)
        
        hidden_state = h0
        cell_state = c0
        outputs = torch.empty((batch_size, captions.size(1), 2)).cuda()
        
        
        for t in range(captions.size(1)):
        
            # for the first time step the input is the feature vector
            combin_lstm = torch.cat([torch.flatten(features,start_dim=1),out],dim=1)
            output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))

            #print(torch.flatten(features,start_dim=1).shape,output.shape,out.shape)  
            combOut = torch.cat([torch.flatten(features,start_dim=1), output.squeeze(),out],dim=1)
            
            out = self.fc_out(combOut)
            out = out*32.0
            # build the output tensor

            outputs[:, t, :] = out
        #self.longtermMem = self.longtermMem.detach()
        return outputs, hidden_state.detach(), cell_state.detach(), out.detach()#, captions

# %%
a = torch.ones(64,256,50)
b = torch.from_numpy(np.random.randn(50))
c = a*b
print(c[0,1,:])
print(c[1,1,:])
# Out:
# tensor([ 1.6284,  0.0741,  0.1042,  0.3805, -0.4608, -1.1002, -1.5308,  1.2823,
#         -0.5174,  0.9396, -0.2074,  0.1030,  0.1327,  0.8248, -0.7150, -1.5463,
#         -0.7844, -0.3893,  0.4877,  0.6318,  1.0663, -0.2432, -1.6195,  0.0952,
#         -0.4574, -1.2123, -0.7114,  0.2801,  0.6050, -0.6675,  0.4522, -0.4271,
#         -0.1431, -1.2717,  1.2346,  0.4932, -0.0776, -0.9651, -1.0483, -0.0909,
#         -0.7750,  0.9367, -1.7831, -0.5614,  0.4037,  2.0943,  0.4804, -0.0339,
#          0.0486,  0.7364], dtype=torch.float64)
# tensor([ 1.6284,  0.0741,  0.1042,  0.3805, -0.4608, -1.1002, -1.5308,  1.2823,
#         -0.5174,  0.9396, -0.2074,  0.1030,  0.1327,  0.8248, -0.7150, -1.5463,
#         -0.7844, -0.3893,  0.4877,  0.6318,  1.0663, -0.2432, -1.6195,  0.0952,
#         -0.4574, -1.2123, -0.7114,  0.2801,  0.6050, -0.6675,  0.4522, -0.4271,
#         -0.1431, -1.2717,  1.2346,  0.4932, -0.0776, -0.9651, -1.0483, -0.0909,
#         -0.7750,  0.9367, -1.7831, -0.5614,  0.4037,  2.0943,  0.4804, -0.0339,
#          0.0486,  0.7364], dtype=torch.float64)

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
model = model.train()
#for seql in range(3,20,4):
seql = 1
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 0 seql 1
# tensor(0.5762, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.4284, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3498, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.4012, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3823, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3453, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.4187, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.4525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3929, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3452, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3588, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.4159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3778, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.4154, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3658, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3564, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3060, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(0.3660, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3403, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3269, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3696, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3496, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3236, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3119, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.2931, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3145, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3138, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3181, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3876, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.2649, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.2906, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3255, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3300, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(0.3405, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3000, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3034, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3082, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3018, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3041, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2883, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3003, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2853, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3157, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2743, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2775, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2851, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.3000, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2530, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(0.2784, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2772, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2897, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2946, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2988, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2415, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2768, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2878, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2439, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2639, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2735, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.3014, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2797, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2883, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2703, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2712, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2423, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2630, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2675, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2709, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(0.2586, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2601, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2605, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2502, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2666, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2616, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2550, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2765, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2628, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2395, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2597, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2445, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2654, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2396, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2427, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2546, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2548, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2519, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(0.2518, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2691, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2429, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2468, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2322, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2436, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2479, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2254, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2366, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2364, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2154, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2238, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2471, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2471, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2387, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2269, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(0.2234, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2349, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2152, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2330, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2594, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2313, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2531, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2229, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2266, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2170, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2343, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2292, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2404, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2237, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2341, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2157, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(0.2276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2224, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.1966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2372, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2187, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2427, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2134, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2228, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2200, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.1962, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2207, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2154, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2222, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.1994, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2045, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(0.2206, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2017, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2113, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2134, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2172, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.1955, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2366, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.1960, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2261, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2295, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2188, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2192, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2157, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2279, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.1975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2002, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.1991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2109, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(0.2010, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2117, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1977, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1998, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1988, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1970, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2146, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2045, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1944, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1983, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2031, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2034, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2080, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1894, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2140, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2112, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.2204, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(0.1987, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
model = model.train()
#for seql in range(3,20,4):
seql = 1
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
        assert out.shape[0] ==64
        assert out.shape[1] ==2
        
      #print("predictions",torch.max(torch.abs(out[0,:].detach().clone()-out[3,:].detach().clone())),torch.min(torch.abs(out[0,:].detach().clone()-out[3,:].detach().clone())))
      print("predictions",torch.mean(torch.abs(out[0,:].detach().clone()-out[3,:].detach().clone())))
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# predictions tensor(1.6442, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8724, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0539, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5627, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0525, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5214, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0538, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8982, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0526, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1052, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0547, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9981, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0503, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7745, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0475, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3478, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0535, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6316, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0505, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.3428, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0498, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2128, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0547, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1372, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0564, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.9211, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.4179, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0546, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6971, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0545, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4448, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0530, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6958, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0542, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2619, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0551, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1250, device='cuda:0')
# epoch 0 seql 1
# tensor(0.0580, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6590, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0516, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2879, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0522, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8325, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0594, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1721, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0515, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2637, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0569, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9163, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0575, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5793, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0486, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7812, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0511, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5035, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0559, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1256, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0532, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.9235, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0521, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3101, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0514, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1025, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0561, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7084, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0520, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3089, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0523, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.3269, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0514, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.3594, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0554, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8238, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0493, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.2732, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0528, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0702, device='cuda:0')
# epoch 1 seql 1
# tensor(0.0541, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8020, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0536, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1248, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0534, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2227, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0516, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6974, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0534, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3024, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0531, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9866, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0548, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9186, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0544, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2015, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0519, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6898, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6041, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0472, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6367, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5047, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0498, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2169, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0512, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.9634, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0520, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2466, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0520, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8379, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0531, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4688, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0516, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5789, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0505, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4967, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0533, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6179, device='cuda:0')
# epoch 2 seql 1
# tensor(0.0526, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.3280, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0529, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4590, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0499, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8826, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0529, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0017, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0515, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8712, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0495, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1325, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0480, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5777, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0496, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0167, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0502, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0439, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0516, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9408, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0546, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2102, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0532, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5946, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0522, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5737, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0483, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7694, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0512, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7735, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0502, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2471, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0585, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1818, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0540, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1719, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0491, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2002, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0495, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.1678, device='cuda:0')
# epoch 3 seql 1
# tensor(0.0496, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8599, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0494, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6652, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0519, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9266, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0523, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7960, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0512, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4623, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0524, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4118, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0478, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3253, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0504, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9312, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0505, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9439, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0507, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1148, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0515, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7330, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0517, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0543, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0490, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5196, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0480, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5111, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0490, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4963, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0488, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1587, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0469, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0576, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0528, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2580, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0543, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6996, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0576, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0663, device='cuda:0')
# epoch 4 seql 1
# tensor(0.0544, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6907, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0531, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4205, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0519, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.1953, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0501, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7063, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0463, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9962, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0507, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5296, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0552, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7880, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0523, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5126, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0471, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7871, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0501, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6788, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0518, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4983, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0499, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0542, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0507, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9009, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0519, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3679, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0495, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.9288, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0524, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5280, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8551, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0515, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4602, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0514, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7218, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0504, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8911, device='cuda:0')
# epoch 5 seql 1
# tensor(0.0499, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7215, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0498, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5455, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0504, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7075, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0519, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8259, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0529, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3033, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0509, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8223, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0529, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3791, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0481, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9403, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0501, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8511, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0531, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0935, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0517, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5552, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0509, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0942, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0501, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7311, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0550, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6034, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0487, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6008, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0511, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7033, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0513, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6440, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0501, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6845, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0508, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0566, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0538, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8041, device='cuda:0')
# epoch 6 seql 1
# tensor(0.0552, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9529, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0521, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2059, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0516, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6212, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0510, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4783, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0506, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7531, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0482, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4821, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0519, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2752, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0502, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5394, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0512, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1804, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0474, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8673, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0505, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1488, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0522, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0873, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0492, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8327, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0528, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3107, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0517, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8912, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0517, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4552, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0471, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9079, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0518, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3701, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0484, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5420, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.3141, device='cuda:0')
# epoch 7 seql 1
# tensor(0.0545, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6504, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0497, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1580, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0508, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4671, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0541, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(3.3596, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0474, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5978, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0486, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7765, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0541, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8457, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0488, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9612, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0562, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0557, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0495, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8303, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0543, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9821, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0491, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5924, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0535, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6840, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0481, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6936, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0483, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4894, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0504, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7549, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0511, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3500, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0503, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5915, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4705, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0515, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1314, device='cuda:0')
# epoch 8 seql 1
# tensor(0.0501, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7259, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0509, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0794, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0468, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1366, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0480, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4633, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0528, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6098, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0550, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6201, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0504, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5891, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0503, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.5453, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0479, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7316, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0514, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6877, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0547, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0334, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0489, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0063, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0516, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0686, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0509, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0842, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0515, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8734, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0492, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1834, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0497, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8830, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0492, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.4895, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0545, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8301, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0499, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7287, device='cuda:0')
# epoch 9 seql 1
# tensor(0.0478, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
"""model = model.train()
for epoch in range (20):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      #print(x.shape,y.shape)
      if i == 0:
        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
        
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)"""
# Out:
# 'model = model.train()\nfor epoch in range (20):\n  loss = None\n  for x,y in loader_train:\n    h0 = None\n    c0 = None\n    for i in range(19):\n      x = x.cuda()\n      y = y.cuda()\n      \n      optimizer.zero_grad()\n      #print(x.shape,y.shape)\n      if i == 0:\n        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)\n      else:\n        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)\n        \n      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)\n      writer.add_scalar("Loss/train", loss, epoch)\n\n      loss.backward()\n      optimizer.step()\n    #print(y[:,0,:2])\n    print(\'epoch\',epoch)\n    print(loss)'

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model = model.eval()
for epoch in range (1):
  loss = None
  for x,y in loader_test:
    h0 = None
    c0 = None
    loss = torch.zeros(3)
    for i in range(3):
      x = x.cuda()
      y = y.cuda()
      
      #print(x.shape,y.shape)
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
      
      loss[i] = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      print(loss[i])
      writer.add_scalar("Loss/val", loss[i],i, epoch)

    #print(y[:,0,:2])
    print('epoch',epoch)
    print('test loss', torch.mean(loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# tensor(0.6416, grad_fn=<SelectBackward>)
# tensor(0.9844, grad_fn=<SelectBackward>)
# tensor(0.9286, grad_fn=<SelectBackward>)
# epoch 0
# test loss tensor(0.8515, grad_fn=<MeanBackward0>)

# %%
writer.flush()
writer.close()

# %% [markdown]
# **started** with .0001 then moved to .00001 learning rate (20 epochs)
# finished with .000001 lr, but didn't see much more improvement (total 60 epochs 20,20,20) extra 20 over previous comment

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
# Out:
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
