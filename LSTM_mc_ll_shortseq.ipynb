# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/LSTM_mc_ll_shortseq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %% [markdown]
# https://r2rt.com/non-zero-initial-states-for-recurrent-neural-networks.html

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):
    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}


def plot_all( sample = None, model = None, labels = None):
    img = sample[:,:].squeeze().cpu().numpy()
    #img = img.T
    plt.imshow(img, cmap=plt.cm.gray_r)
    if model != None:
        with torch.no_grad():
            global numpoints
            print(labels.shape,sample.shape)
            sample = torch.stack([sample for i in range(2)],dim = 0).cuda()
            labels = torch.stack([labels for i in range(2)],dim = 0).cuda()
            h0 = None
            c0 = None
            X = []
            Y = []
            for i in range(3):
              if i == 0:
                out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
              else:
                out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
                
              X.extend(out[0,:,0].tolist())
              Y.extend(out[0,:,1].tolist())

            predres = len(X)

            s = [.001 for x in range(predres)]
            
            assert len(s) == predres
            c = ['red' for x in range(predres)]
            assert len(c) == predres
            #print("type",type(X))
            ascatter = plt.scatter(X,Y,s = s,c = c)
            plt.gca().add_artist(ascatter)
    else:
        #print(labels.shape)
        X = labels[:,0]
        Y = labels[:,1]
        #print(X.shape)
        #print(Y.shape)
        s = [.001 for x in range(numpoints)]
        #print(len(s))
        c = ['red' for x in range(numpoints)]
        #print(len(c))
        ascatter = plt.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
        plt.gca().add_artist(ascatter)

class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        for i in range(100):
            sample, labels = dataset[i]
            plt.subplot(10,10,i+1)
            plot_all(sample = sample,model=model, labels = labels)
            plt.axis('off')
        plt.savefig(title,dpi=600)

dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
dataset = DonutDataset(length = 64*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1280, 1]) torch.Size([1280, 1]) torch.Size([1280, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 50
        self.lm_len = 20
        self.longtermMem = None
        self.longtermMemP = None
        # lstm cell
        self.lstm_cell = nn.LSTM(2+1024, self.hidden_size,self.num_layers)

        
        
        self.fc_out = nn.Sequential(
            nn.Linear(2+self.hidden_size+1024,10000),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(10000,2),
            nn.Sigmoid()
        )
        
        


        

            
        
    def forward(self, features, captions,h0 = None, c0= None,ind = 0, o = None):

        assert features != None
        self.track +=1
        batch_size = features.size(0)
        

        #img_emb = torch.empty((batch_size, captions.size(1), self.hidden_size)).cuda()
        
        p0 = torch.flatten(captions[:,0,:2],start_dim=1)
        

        if o == None:
          out = p0
          #self.longtermMem = torch.zeros(batch_size,self.hidden_size,self.lm_len).cuda()
        else:
          out = o

                
        if h0 == None and c0 == None:
          h0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
          c0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
        
        
        if self.num_layers>1 and h0.shape[0] == 1:
          h0 = torch.stack([h0.detach().clone().squeeze() for i in range(self.num_layers)],dim = 0)
          c0 = torch.stack([c0.detach().clone().squeeze() for i in range(self.num_layers)],dim = 0)
        
        hidden_state = h0
        cell_state = c0
        outputs = torch.empty((batch_size, captions.size(1), 2)).cuda()
        
        
        for t in range(captions.size(1)):
        
            # for the first time step the input is the feature vector
            combin_lstm = torch.cat([torch.flatten(features,start_dim=1),out],dim=1)
            output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))

            #print(torch.flatten(features,start_dim=1).shape,output.shape,out.shape)  
            combOut = torch.cat([torch.flatten(features,start_dim=1), output.squeeze(),out],dim=1)
            
            out = self.fc_out(combOut)
            out = out*32.0
            # build the output tensor

            outputs[:, t, :] = out
        #self.longtermMem = self.longtermMem.detach()
        return outputs, hidden_state.detach(), cell_state.detach(), out.detach()#, captions

# %%
a = torch.ones(64,256,50)
b = torch.from_numpy(np.random.randn(50))
c = a*b
print(c[0,1,:])
print(c[1,1,:])
# Out:
# tensor([ 1.6065,  2.3255, -0.0871,  1.1809,  1.3962, -1.6679, -0.7518,  0.3383,
#          1.4467,  0.0752, -0.1433,  0.2961,  1.2948, -0.7736,  1.0334,  0.5419,
#         -0.8081, -0.3724, -0.6713,  1.1723,  1.5193,  1.8143, -0.6553,  0.6192,
#          0.1055, -1.2217,  0.0126,  1.7821,  0.8621,  1.1766,  0.1388, -0.7886,
#          2.0243, -0.1497, -0.1268,  0.1093,  1.6002,  1.3279, -1.0369, -0.7237,
#         -0.0475, -1.7587,  0.3684, -0.4101, -0.5568, -0.8052,  0.2446,  0.3333,
#         -0.8245, -0.1450], dtype=torch.float64)
# tensor([ 1.6065,  2.3255, -0.0871,  1.1809,  1.3962, -1.6679, -0.7518,  0.3383,
#          1.4467,  0.0752, -0.1433,  0.2961,  1.2948, -0.7736,  1.0334,  0.5419,
#         -0.8081, -0.3724, -0.6713,  1.1723,  1.5193,  1.8143, -0.6553,  0.6192,
#          0.1055, -1.2217,  0.0126,  1.7821,  0.8621,  1.1766,  0.1388, -0.7886,
#          2.0243, -0.1497, -0.1268,  0.1093,  1.6002,  1.3279, -1.0369, -0.7237,
#         -0.0475, -1.7587,  0.3684, -0.4101, -0.5568, -0.8052,  0.2446,  0.3333,
#         -0.8245, -0.1450], dtype=torch.float64)

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
model = model.train()
#for seql in range(3,20,4):
seql = 3
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 0 seql 3
# tensor(14.4472, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(21.3185, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(23.7318, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(19.7240, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(12.0000, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(6.8400, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(5.7591, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(8.0964, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(11.0092, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(13.2288, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(10.7448, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(8.6516, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(7.9298, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(6.9711, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(7.5916, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(8.7963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(9.2863, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(9.6012, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(8.3052, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(7.9005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.0974, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(7.7208, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.1059, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.5100, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.1521, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.0403, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.0623, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.1167, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(7.7573, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(7.7212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.2033, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.2158, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(7.7300, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(7.9754, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.0569, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.2193, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.3073, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(8.0501, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(7.3013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(7.7674, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.5333, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(8.0035, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(8.1159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.7706, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(8.0049, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(6.9217, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.7850, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.7348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.8008, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.7678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.8391, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.0714, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.3654, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.5748, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.2381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.7922, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.1101, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(6.8585, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.0606, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(7.5695, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(7.2462, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(7.1214, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.7953, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(7.0710, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(7.0233, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(7.5768, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.6180, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.9901, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(7.1441, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(7.5216, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.5812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.6679, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.9097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(7.2254, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.0778, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.9975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.3559, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.4305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(6.7517, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(5.8550, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(6.8007, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(5.5606, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(6.0459, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(6.5505, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(4.7735, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(5.9528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(4.9551, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(5.6253, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(5.3462, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(4.1604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(4.0591, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(5.8610, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(3.1819, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(5.7882, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(4.0734, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(3.3825, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(6.4725, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(2.8724, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(4.0302, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(5.9655, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(2.8278, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(4.1457, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(5.5962, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(2.5353, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(4.8285, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(7.6212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(2.5024, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(3.9228, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(8.5450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(3.9691, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(3.4937, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(4.8733, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(5.5984, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(2.7097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(3.4078, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(6.0631, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(2.5944, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(5.4234, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(5.7361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(2.9281, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(4.4165, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(3.0549, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.7266, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(5.1840, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.4155, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(3.5171, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(5.8383, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.3149, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.8212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(4.9113, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(5.4812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.5293, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.7124, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(4.3773, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(4.5352, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.1465, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.6114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(4.7654, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(3.6983, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(2.2288, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.7513, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(3.5922, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.5339, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.2242, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.0972, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.7471, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.4010, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.1504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.5114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.5691, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.1411, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(1.9881, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.6326, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.1159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.1466, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.4810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.1551, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.0089, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(2.1515, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(1.9019, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.6870, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(2.0298, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.6639, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.9711, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.6519, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.7537, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(2.4896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.8937, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.8223, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(2.7501, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.6822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.7401, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(3.4337, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.8067, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.6346, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(2.9749, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.8101, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.9886, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(1.6572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(2.7046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.7918, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.7026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(3.4888, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.5935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.6833, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(2.3801, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(2.3575, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.7653, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.5025, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(3.3380, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.4510, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.6108, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(2.2727, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(2.1226, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.8070, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.7298, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(3.5920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.3231, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.7014, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(1.8207, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
model = model.train()
#for seql in range(3,20,4):
seql = 3
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
"""model = model.train()
for epoch in range (20):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      #print(x.shape,y.shape)
      if i == 0:
        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
        
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)"""
# Out:
# 'model = model.train()\nfor epoch in range (20):\n  loss = None\n  for x,y in loader_train:\n    h0 = None\n    c0 = None\n    for i in range(19):\n      x = x.cuda()\n      y = y.cuda()\n      \n      optimizer.zero_grad()\n      #print(x.shape,y.shape)\n      if i == 0:\n        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)\n      else:\n        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)\n        \n      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)\n      writer.add_scalar("Loss/train", loss, epoch)\n\n      loss.backward()\n      optimizer.step()\n    #print(y[:,0,:2])\n    print(\'epoch\',epoch)\n    print(loss)'

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model = model.eval()
for epoch in range (1):
  loss = None
  for x,y in loader_test:
    h0 = None
    c0 = None
    loss = torch.zeros(3)
    for i in range(3):
      x = x.cuda()
      y = y.cuda()
      
      #print(x.shape,y.shape)
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
      
      loss[i] = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      print(loss[i])
      writer.add_scalar("Loss/val", loss[i],i, epoch)

    #print(y[:,0,:2])
    print('epoch',epoch)
    print('test loss', torch.mean(loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# tensor(1.1777, grad_fn=<SelectBackward>)
# tensor(1.5275, grad_fn=<SelectBackward>)
# tensor(2.3553, grad_fn=<SelectBackward>)
# epoch 0
# test loss tensor(1.6868, grad_fn=<MeanBackward0>)

# %%
writer.flush()
writer.close()

# %% [markdown]
# **started** with .0001 then moved to .00001 learning rate (20 epochs)
# finished with .000001 lr, but didn't see much more improvement (total 60 epochs 20,20,20) extra 20 over previous comment

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
# Out:
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
