# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/LSTM_mc_ll_shortseq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):
    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}


def plot_all( sample = None, model = None, labels = None):
    img = sample[:,:].squeeze().cpu().numpy()
    #img = img.T
    plt.imshow(img, cmap=plt.cm.gray_r)
    if model != None:
        with torch.no_grad():
            global numpoints
            print(labels.shape,sample.shape)
            sample = torch.stack([sample for i in range(2)],dim = 0).cuda()
            labels = torch.stack([labels for i in range(2)],dim = 0).cuda()
            h0 = None
            c0 = None
            X = []
            Y = []
            for i in range(3):
              if i == 0:
                out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
              else:
                out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
                
              X.extend(out[0,:,0].tolist())
              Y.extend(out[0,:,1].tolist())

            predres = len(X)

            s = [.001 for x in range(predres)]
            
            assert len(s) == predres
            c = ['red' for x in range(predres)]
            assert len(c) == predres
            #print("type",type(X))
            ascatter = plt.scatter(X,Y,s = s,c = c)
            plt.gca().add_artist(ascatter)
    else:
        #print(labels.shape)
        X = labels[:,0]
        Y = labels[:,1]
        #print(X.shape)
        #print(Y.shape)
        s = [.001 for x in range(numpoints)]
        #print(len(s))
        c = ['red' for x in range(numpoints)]
        #print(len(c))
        ascatter = plt.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
        plt.gca().add_artist(ascatter)

class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        for i in range(100):
            sample, labels = dataset[i]
            plt.subplot(10,10,i+1)
            plot_all(sample = sample,model=model, labels = labels)
            plt.axis('off')
        plt.savefig(title,dpi=600)

dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
dataset = DonutDataset(length = 64*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1280, 1]) torch.Size([1280, 1]) torch.Size([1280, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 50
        self.lm_len = 20
        self.longtermMem = None
        self.longtermMemP = None
        # lstm cell
        self.lstm_cell = nn.LSTM(2+1024, self.hidden_size,self.num_layers)

        
        
        self.fc_out = nn.Sequential(
            nn.Linear(self.hidden_size*2,1000),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(1000,2),
            nn.Sigmoid()
        )
        self.alpharead = nn.Sequential(
            nn.Linear((self.lm_len+1)*self.hidden_size,self.lm_len),
            nn.Softmax()
        )
        self.alphashort = nn.Sequential(
            nn.Linear((self.seq_len)*self.hidden_size,50),
            nn.Softmax()
        )

        self.alphawrite = nn.Sequential(
            nn.Linear((self.seq_len)*self.hidden_size,self.seq_len),
            nn.Softmax()
        )
        


        #self.hiddenMlp = nn.Sequential(
        #    nn.Linear(1024+2,self.hidden_size),nn.ReLU())
        #self.cellMlp = nn.Sequential(
        #    nn.Linear(1024+2,self.hidden_size),nn.ReLU())
        

            
        
    def forward(self, features, captions,h0 = None, c0= None,ind = 0, o = None):

        assert features != None
        self.track +=1
        batch_size = features.size(0)
        

        img_emb = torch.empty((batch_size, captions.size(1), self.hidden_size)).cuda()
        
        p0 = torch.flatten(captions[:,0,:2],start_dim=1)
        

        if o == None:
          out = p0
          self.longtermMem = torch.zeros(batch_size,self.hidden_size,self.lm_len).cuda()
        else:
          out = o

                
        if h0 == None and c0 == None:
          h0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
          c0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
        
        
        if self.num_layers>1 and h0.shape[0] == 1:
          h0 = torch.stack([h0.detach().clone().squeeze() for i in range(self.num_layers)],dim = 0)
          c0 = torch.stack([c0.detach().clone().squeeze() for i in range(self.num_layers)],dim = 0)
        
        hidden_state = h0
        cell_state = c0
        outputs = torch.empty((batch_size, captions.size(1), 2)).cuda()
        
        
        for t in range(captions.size(1)):
        
            # for the first time step the input is the feature vector
            combin_lstm = torch.cat([torch.flatten(features,start_dim=1),out],dim=1)
            output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))
                
                
            assert h0 != None

            
            emb = output.squeeze()
            img_emb[:, t, :] = emb
            
            if t ==49:
              aw_in = torch.cat([torch.flatten(img_emb,start_dim=1)],dim=1)
              alphawrite = self.alphawrite(aw_in)
              outeswritea = img_emb.clone()*alphawrite.unsqueeze(2)
              outeswrite = torch.sum(outeswritea,dim=1)
              self.longtermMem[:,:,ind]=outeswrite
            
            ar_in = torch.cat([torch.flatten(self.longtermMem,start_dim=1),output.squeeze()],dim=1)
            
            alpharead = self.alpharead(ar_in)
            outesreada = self.longtermMem.clone()*alpharead.unsqueeze(1)
            
            outesread = torch.sum(outesreada,dim=2)

            #print("5")
        
            
            alph = self.alphashort(torch.cat([torch.flatten(img_emb.clone(),start_dim=1)],dim=1))
            outesalpha = img_emb.clone()*alph.unsqueeze(2)
            
            outeshort = torch.sum(outesalpha,dim=1)
            assert features != None
            combOut = torch.cat([outesread, outeshort],dim=1)
            
            out = self.fc_out(combOut)
            out = out*32.0
            # build the output tensor

            outputs[:, t, :] = out
        self.longtermMem = self.longtermMem.detach()
        return outputs, hidden_state.detach(), cell_state.detach(), out.detach()#, captions

# %%
a = torch.ones(64,256,50)
b = torch.from_numpy(np.random.randn(50))
c = a*b
print(c[0,1,:])
print(c[1,1,:])
# Out:
# tensor([ 4.6062e-01, -3.5360e-01,  6.8360e-02,  6.2281e-02, -9.4788e-01,
#          8.8591e-01, -1.4695e-01,  4.8181e-01,  2.9888e-01, -3.0281e-02,
#          1.8302e+00,  2.3899e-01, -8.2259e-01, -1.5752e+00,  8.7280e-01,
#         -1.5045e+00,  5.2544e-01,  1.3294e+00, -7.8049e-01, -1.1739e-01,
#          2.7922e-04, -7.3727e-01, -6.7415e-01,  8.2809e-01, -7.1750e-01,
#         -4.8138e-01, -1.4460e+00, -5.5874e-01, -1.3685e-02,  1.3800e+00,
#         -4.9550e-01,  6.1852e-02, -1.6218e+00,  2.5838e-01,  1.8785e+00,
#          1.0028e+00, -4.6282e-01, -4.2085e-01,  1.3384e-01, -8.2892e-01,
#         -1.1252e+00, -7.3158e-01,  2.6010e-01, -1.1810e-01,  6.4590e-02,
#         -7.9599e-01, -3.4970e-01,  4.8819e-01,  4.6257e-01,  1.0153e-01],
#        dtype=torch.float64)
# tensor([ 4.6062e-01, -3.5360e-01,  6.8360e-02,  6.2281e-02, -9.4788e-01,
#          8.8591e-01, -1.4695e-01,  4.8181e-01,  2.9888e-01, -3.0281e-02,
#          1.8302e+00,  2.3899e-01, -8.2259e-01, -1.5752e+00,  8.7280e-01,
#         -1.5045e+00,  5.2544e-01,  1.3294e+00, -7.8049e-01, -1.1739e-01,
#          2.7922e-04, -7.3727e-01, -6.7415e-01,  8.2809e-01, -7.1750e-01,
#         -4.8138e-01, -1.4460e+00, -5.5874e-01, -1.3685e-02,  1.3800e+00,
#         -4.9550e-01,  6.1852e-02, -1.6218e+00,  2.5838e-01,  1.8785e+00,
#          1.0028e+00, -4.6282e-01, -4.2085e-01,  1.3384e-01, -8.2892e-01,
#         -1.1252e+00, -7.3158e-01,  2.6010e-01, -1.1810e-01,  6.4590e-02,
#         -7.9599e-01, -3.4970e-01,  4.8819e-01,  4.6257e-01,  1.0153e-01],
#        dtype=torch.float64)

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
model = model.train()
#for seql in range(3,20,4):
seql = 3
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 3
# tensor(42.6524, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(40.0406, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(32.2738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(23.3306, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(18.4557, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(11.2126, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(10.3054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(11.8694, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(11.5103, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(10.6166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(8.8604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(9.1322, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(8.7447, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(8.4728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(6.9803, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(6.2275, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(5.9883, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(5.8162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(5.2772, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(4.9775, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(4.7510, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(4.4605, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(4.3208, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(4.3023, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(4.0069, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(3.7144, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(4.1813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(3.5809, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(3.5537, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(3.0599, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(3.2714, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(2.7698, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(2.9260, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(2.7983, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(3.0448, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(2.5837, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(2.6680, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(2.5467, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(2.5241, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(2.3165, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.4286, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.1535, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.2389, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.2016, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.1054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.0779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.0201, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.0756, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.9210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(2.0287, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.7223, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.9847, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.7297, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.7397, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.8905, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.9620, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.9459, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.8061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.6582, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(1.7250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.9128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.6458, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.8836, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.8651, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.6810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.6814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.8395, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.8278, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.7426, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.8451, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.6185, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.6176, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.4319, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.7233, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.5968, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.4662, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.6512, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.5394, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.7145, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(1.7919, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.5393, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.5518, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.7585, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.6994, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.6248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.7410, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.5690, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.6588, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.6386, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.4257, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.6836, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.7957, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.8210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.5265, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.5824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.4979, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.6108, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.7249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.6512, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(1.5245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.6377, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.5826, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.7082, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.6839, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.7346, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.6469, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.5448, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.6652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.5998, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.4480, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.7768, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.7469, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.5748, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.5676, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.8022, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.7584, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.6951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.5477, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.4633, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(1.4111, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
model = model.train()
#for seql in range(3,20,4):
seql = 3
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 3
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-cf0a0639c743> in <module>()
#      17       else:
#      18         out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
# ---> 19       loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
#      20       writer.add_scalar("Loss/train", loss, epoch)
#      21
#
# KeyboardInterrupt:

# %%
"""model = model.train()
for epoch in range (20):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      #print(x.shape,y.shape)
      if i == 0:
        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
        
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)"""

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)

# %%
model = model.eval()
for epoch in range (1):
  loss = None
  for x,y in loader_test:
    h0 = None
    c0 = None
    loss = torch.zeros(19)
    for i in range(3):
      x = x.cuda()
      y = y.cuda()
      
      #print(x.shape,y.shape)
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
      
      loss[i] = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      print(loss[i])
      writer.add_scalar("Loss/val", loss[i],i, epoch)

    #print(y[:,0,:2])
    print('epoch',epoch)
    print('test loss', torch.mean(loss))

# %%
writer.flush()
writer.close()

# %% [markdown]
# **started** with .0001 then moved to .00001 learning rate (20 epochs)
# finished with .000001 lr, but didn't see much more improvement (total 60 epochs 20,20,20) extra 20 over previous comment

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
pred_dataset = DonutDataset(length = 100)

# %%
DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
