# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/LSTM_mc_ll_shortseq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %% [markdown]
# https://r2rt.com/non-zero-initial-states-for-recurrent-neural-networks.html

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):
    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}


def plot_all( sample = None, model = None, labels = None):
    img = sample[:,:].squeeze().cpu().numpy()
    #img = img.T
    plt.imshow(img, cmap=plt.cm.gray_r)
    if model != None:
        with torch.no_grad():
            global numpoints
            print(labels.shape,sample.shape)
            sample = torch.stack([sample for i in range(2)],dim = 0).cuda()
            labels = torch.stack([labels for i in range(2)],dim = 0).cuda()
            h0 = None
            c0 = None
            X = []
            Y = []
            for i in range(1):
              if i == 0:
                out, h0, c0,o = model(sample,labels[:,i*50:50*(i+1),:2],h0,c0,ind = i)
              else:
                out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
                
              X.extend(out[0,:,0].tolist())
              Y.extend(out[0,:,1].tolist())

            predres = len(X)

            s = [.001 for x in range(predres)]
            
            assert len(s) == predres
            c = ['red' for x in range(predres)]
            assert len(c) == predres
            #print("type",type(X))
            ascatter = plt.scatter(X,Y,s = s,c = c)
            plt.gca().add_artist(ascatter)
    else:
        #print(labels.shape)
        X = labels[:,0]
        Y = labels[:,1]
        #print(X.shape)
        #print(Y.shape)
        s = [.001 for x in range(numpoints)]
        #print(len(s))
        c = ['red' for x in range(numpoints)]
        #print(len(c))
        ascatter = plt.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
        plt.gca().add_artist(ascatter)

class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        for i in range(100):
            sample, labels = dataset[i]
            plt.subplot(10,10,i+1)
            plot_all(sample = sample,model=model, labels = labels)
            plt.axis('off')
        plt.savefig(title,dpi=600)

dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
for i in range(100):
  print(torch.sum(dataset[i][0]))
# Out:
# tensor(84.)
# tensor(103.)
# tensor(128.)
# tensor(119.)
# tensor(173.)
# tensor(193.)
# tensor(89.)
# tensor(97.)
# tensor(80.)
# tensor(209.)
# tensor(222.)
# tensor(84.)
# tensor(106.)
# tensor(186.)
# tensor(98.)
# tensor(89.)
# tensor(134.)
# tensor(84.)
# tensor(78.)
# tensor(114.)
# tensor(108.)
# tensor(232.)
# tensor(226.)
# tensor(82.)
# tensor(99.)
# tensor(139.)
# tensor(177.)
# tensor(110.)
# tensor(133.)
# tensor(70.)
# tensor(188.)
# tensor(176.)
# tensor(74.)
# tensor(126.)
# tensor(166.)
# tensor(169.)
# tensor(78.)
# tensor(169.)
# tensor(81.)
# tensor(74.)
# tensor(121.)
# tensor(124.)
# tensor(136.)
# tensor(70.)
# tensor(160.)
# tensor(87.)
# tensor(222.)
# tensor(84.)
# tensor(226.)
# tensor(187.)
# tensor(91.)
# tensor(139.)
# tensor(187.)
# tensor(148.)
# tensor(136.)
# tensor(133.)
# tensor(254.)
# tensor(122.)
# tensor(90.)
# tensor(158.)
# tensor(141.)
# tensor(76.)
# tensor(87.)
# tensor(84.)
# tensor(105.)
# tensor(233.)
# tensor(109.)
# tensor(247.)
# tensor(86.)
# tensor(126.)
# tensor(108.)
# tensor(110.)
# tensor(104.)
# tensor(163.)
# tensor(123.)
# tensor(231.)
# tensor(163.)
# tensor(245.)
# tensor(232.)
# tensor(83.)
# tensor(121.)
# tensor(100.)
# tensor(254.)
# tensor(95.)
# tensor(72.)
# tensor(138.)
# tensor(174.)
# tensor(162.)
# tensor(84.)
# tensor(120.)
# tensor(140.)
# tensor(94.)
# tensor(185.)
# tensor(89.)
# tensor(104.)
# tensor(174.)
# tensor(224.)
# tensor(74.)
# tensor(118.)
# tensor(134.)

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
dataset = DonutDataset(length = 64*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1280, 1]) torch.Size([1280, 1]) torch.Size([1280, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 50
        self.lm_len = 20
        self.longtermMem = None
        self.longtermMemP = None
        # lstm cell
        self.lstm_cell = nn.LSTM(2+1024, self.hidden_size,self.num_layers)

        
        
        self.fc_out = nn.Sequential(
            nn.Linear(2+self.hidden_size+1024,10000),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(10000,2),
            nn.Sigmoid()
        )
        
        


        

            
        
    def forward(self, features, captions,h0 = None, c0= None,ind = 0, o = None):

        assert features != None
        self.track +=1
        batch_size = features.size(0)
        

        #img_emb = torch.empty((batch_size, captions.size(1), self.hidden_size)).cuda()
        
        p0 = torch.flatten(captions[:,0,:2],start_dim=1)
        

        if o == None:
          out = p0
          #self.longtermMem = torch.zeros(batch_size,self.hidden_size,self.lm_len).cuda()
        else:
          out = o

                
        if h0 == None and c0 == None:
          h0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
          c0 = torch.zeros(1,batch_size, self.hidden_size).cuda()
        
        
        if self.num_layers>1 and h0.shape[0] == 1:
          h0 = torch.stack([h0.detach().clone().squeeze() for i in range(self.num_layers)],dim = 0)
          c0 = torch.stack([c0.detach().clone().squeeze() for i in range(self.num_layers)],dim = 0)
        
        hidden_state = h0
        cell_state = c0
        outputs = torch.empty((batch_size, captions.size(1), 2)).cuda()
        
        
        for t in range(captions.size(1)):
        
            # for the first time step the input is the feature vector
            combin_lstm = torch.cat([torch.flatten(features,start_dim=1),out],dim=1)
            output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))

            #print(torch.flatten(features,start_dim=1).shape,output.shape,out.shape)  
            combOut = torch.cat([torch.flatten(features,start_dim=1), output.squeeze(),out],dim=1)
            
            out = self.fc_out(combOut)
            out = out*32.0
            # build the output tensor

            outputs[:, t, :] = out
        #self.longtermMem = self.longtermMem.detach()
        return outputs, hidden_state.detach(), cell_state.detach(), out.detach()#, captions

# %%
a = torch.ones(64,256,50)
b = torch.from_numpy(np.random.randn(50))
c = a*b
print(c[0,1,:])
print(c[1,1,:])
# Out:
# tensor([ 0.1275, -0.4907, -0.0587, -0.1480, -0.6834,  0.8089, -0.2513, -0.6111,
#         -0.3138,  2.0848,  1.5238, -1.6468, -0.1288, -1.0664, -0.1650, -0.8361,
#          0.6211, -1.8103,  1.6789,  0.2082,  1.4232,  0.3289,  0.6032,  0.5571,
#         -0.4924, -1.0921,  1.1268, -0.1648, -0.0279,  0.0058, -0.5314, -0.6144,
#         -1.9818, -0.6520,  0.8392,  0.9973, -0.3115, -1.7244, -0.2404, -0.1673,
#          1.5726,  0.0567, -0.2966, -0.6954, -0.7857, -0.9051,  0.5808, -1.0069,
#          1.3732,  1.1654], dtype=torch.float64)
# tensor([ 0.1275, -0.4907, -0.0587, -0.1480, -0.6834,  0.8089, -0.2513, -0.6111,
#         -0.3138,  2.0848,  1.5238, -1.6468, -0.1288, -1.0664, -0.1650, -0.8361,
#          0.6211, -1.8103,  1.6789,  0.2082,  1.4232,  0.3289,  0.6032,  0.5571,
#         -0.4924, -1.0921,  1.1268, -0.1648, -0.0279,  0.0058, -0.5314, -0.6144,
#         -1.9818, -0.6520,  0.8392,  0.9973, -0.3115, -1.7244, -0.2404, -0.1673,
#          1.5726,  0.0567, -0.2966, -0.6954, -0.7857, -0.9051,  0.5808, -1.0069,
#          1.3732,  1.1654], dtype=torch.float64)

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
model = model.train()
#for seql in range(3,20,4):
seql = 1
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 0 seql 1
# tensor(64.2107, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(22.5704, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(6.7147, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(5.9427, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(9.7720, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(11.2079, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(12.9511, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(14.0261, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(15.9850, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(15.8845, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(15.1257, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(15.2173, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(14.2309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(12.7287, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(10.0250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(8.9668, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(6.4771, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(6.4019, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(4.9992, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 1
# tensor(4.7144, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(6.0779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(5.9975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(6.2993, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(7.8049, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(6.4703, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(7.9678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(6.0789, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.7851, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(5.1891, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.5575, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(5.3980, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.1339, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(5.0654, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.6661, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.4535, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.4162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.8464, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.8197, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.4304, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 1
# tensor(4.1166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.7794, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(4.1143, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.9251, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.6278, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(4.0748, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.8096, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(4.0565, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.7759, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.6760, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.7434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.5642, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.5358, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.3580, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.5828, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.3639, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.2463, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.4518, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.5739, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.3992, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 1
# tensor(3.3333, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(3.1154, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(3.1728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(3.2291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.9975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(3.0610, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(3.1685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.9704, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(3.2148, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.8136, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.9652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.8665, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.9592, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.8235, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(3.0374, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.7749, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.7619, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.9556, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.7502, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.7005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 1
# tensor(2.7604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.6312, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.6335, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.5857, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.6913, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.6232, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.7525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.5747, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.6215, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.5822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.6032, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.6562, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.5562, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.3795, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.5791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.5539, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.4986, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.5299, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.4963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.3977, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 1
# tensor(2.4704, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.3440, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.3382, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.3305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.2419, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.1764, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.4768, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.2031, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.3346, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.3061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.2887, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.3332, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.3085, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.4192, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.2938, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.1975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.1699, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.2812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.0851, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.2573, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 1
# tensor(2.1106, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.1861, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.1483, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.1123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.2485, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.1157, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.0977, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.0667, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.0873, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.0267, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(1.9917, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.0098, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(1.9709, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.1178, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(2.0232, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(1.9423, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(1.9768, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(1.8332, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(1.9316, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(1.9240, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 1
# tensor(1.9094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.8445, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.8811, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.8478, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.7782, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.6920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.9943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.8926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.9151, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.7641, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.7132, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.9250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.7754, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.7569, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.6529, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.6873, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.7203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.7124, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.7409, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.8212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 1
# tensor(1.6708, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.7573, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.7142, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.7631, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.7406, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.6761, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.5371, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.6353, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.6753, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.5990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.5344, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.5601, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.4700, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.5887, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.5910, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.5454, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.4814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.6237, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.4899, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.4974, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 1
# tensor(1.6000, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.3869, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.5416, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4613, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.5116, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4271, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4221, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4937, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4350, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4614, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.3434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.3879, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.3909, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.3806, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4399, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.3361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.3554, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.3777, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4132, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 1
# tensor(1.4789, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
model = model.train()
#for seql in range(3,20,4):
seql = 1
for epoch in range (10):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o = o)
        assert out.shape[0] ==64
        assert out.shape[1] ==2
        
      #print("predictions",torch.max(torch.abs(out[0,:].detach().clone()-out[3,:].detach().clone())),torch.min(torch.abs(out[0,:].detach().clone()-out[3,:].detach().clone())))
      print("predictions",torch.mean(torch.abs(out[0,:].detach().clone()-out[3,:].detach().clone())))
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# predictions tensor(1.0722, device='cuda:0')
# epoch 0 seql 1
# tensor(1.3315, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.1718, device='cuda:0')
# epoch 0 seql 1
# tensor(1.4882, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1942, device='cuda:0')
# epoch 0 seql 1
# tensor(1.3109, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0771, device='cuda:0')
# epoch 0 seql 1
# tensor(1.4087, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1547, device='cuda:0')
# epoch 0 seql 1
# tensor(1.3446, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2263, device='cuda:0')
# epoch 0 seql 1
# tensor(1.4124, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.3178, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2030, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8879, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2653, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9127, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2379, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5040, device='cuda:0')
# epoch 0 seql 1
# tensor(1.3274, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9161, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2792, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(3.1987, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2662, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2491, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2353, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8520, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2539, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6726, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2784, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8317, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2560, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9494, device='cuda:0')
# epoch 0 seql 1
# tensor(1.3108, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3504, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2193, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.1434, device='cuda:0')
# epoch 0 seql 1
# tensor(1.3575, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9264, device='cuda:0')
# epoch 0 seql 1
# tensor(1.2594, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.2834, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2665, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1559, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2139, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.9316, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2067, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5749, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2337, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5176, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2057, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7566, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2328, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9554, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2724, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1817, device='cuda:0')
# epoch 1 seql 1
# tensor(1.3486, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1719, device='cuda:0')
# epoch 1 seql 1
# tensor(1.1543, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0319, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2028, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4810, device='cuda:0')
# epoch 1 seql 1
# tensor(1.1435, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5574, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2292, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1091, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2154, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0934, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2906, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7093, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2591, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7640, device='cuda:0')
# epoch 1 seql 1
# tensor(1.1829, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3692, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2922, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4247, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2103, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0164, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2485, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6527, device='cuda:0')
# epoch 1 seql 1
# tensor(1.2609, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9968, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1864, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0203, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1790, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6476, device='cuda:0')
# epoch 2 seql 1
# tensor(1.3559, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.1560, device='cuda:0')
# epoch 2 seql 1
# tensor(1.2980, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9851, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1384, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3921, device='cuda:0')
# epoch 2 seql 1
# tensor(1.2277, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0653, device='cuda:0')
# epoch 2 seql 1
# tensor(1.2929, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5941, device='cuda:0')
# epoch 2 seql 1
# tensor(1.0481, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9596, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1640, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5309, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1677, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.9025, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1620, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9007, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1962, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8821, device='cuda:0')
# epoch 2 seql 1
# tensor(1.0901, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8823, device='cuda:0')
# epoch 2 seql 1
# tensor(1.2227, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7952, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1874, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6682, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1571, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2039, device='cuda:0')
# epoch 2 seql 1
# tensor(1.2488, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2107, device='cuda:0')
# epoch 2 seql 1
# tensor(1.2187, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6975, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1217, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.3259, device='cuda:0')
# epoch 2 seql 1
# tensor(1.1458, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9020, device='cuda:0')
# epoch 3 seql 1
# tensor(1.0746, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8437, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1989, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8661, device='cuda:0')
# epoch 3 seql 1
# tensor(1.0808, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2282, device='cuda:0')
# epoch 3 seql 1
# tensor(1.0906, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3022, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1342, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9623, device='cuda:0')
# epoch 3 seql 1
# tensor(1.2020, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0301, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1639, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1408, device='cuda:0')
# epoch 3 seql 1
# tensor(1.0951, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0334, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1056, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1156, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1489, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2122, device='cuda:0')
# epoch 3 seql 1
# tensor(1.0817, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1264, device='cuda:0')
# epoch 3 seql 1
# tensor(1.0574, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(3.3387, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1133, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1679, device='cuda:0')
# epoch 3 seql 1
# tensor(1.0779, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9288, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1431, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9929, device='cuda:0')
# epoch 3 seql 1
# tensor(1.0601, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0753, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1137, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9920, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1284, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5403, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1712, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7201, device='cuda:0')
# epoch 3 seql 1
# tensor(1.1383, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9047, device='cuda:0')
# epoch 4 seql 1
# tensor(1.2180, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4429, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0974, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7427, device='cuda:0')
# epoch 4 seql 1
# tensor(1.1095, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2333, device='cuda:0')
# epoch 4 seql 1
# tensor(1.1954, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3153, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0239, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5758, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0312, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9844, device='cuda:0')
# epoch 4 seql 1
# tensor(1.1626, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.1714, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0575, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7461, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0487, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8484, device='cuda:0')
# epoch 4 seql 1
# tensor(1.1383, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4004, device='cuda:0')
# epoch 4 seql 1
# tensor(1.1039, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8615, device='cuda:0')
# epoch 4 seql 1
# tensor(1.1101, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7943, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0978, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6740, device='cuda:0')
# epoch 4 seql 1
# tensor(1.1076, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4070, device='cuda:0')
# epoch 4 seql 1
# tensor(0.9876, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8224, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0578, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5639, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0907, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.6627, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0184, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7902, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0265, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8412, device='cuda:0')
# epoch 4 seql 1
# tensor(1.0248, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.9373, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0325, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2278, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0727, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0698, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0217, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9108, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0643, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9836, device='cuda:0')
# epoch 5 seql 1
# tensor(0.9923, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9535, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0071, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8858, device='cuda:0')
# epoch 5 seql 1
# tensor(0.9593, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1360, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0447, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0564, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0200, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2408, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0325, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.8175, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0137, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1315, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0231, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8431, device='cuda:0')
# epoch 5 seql 1
# tensor(1.1231, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.3153, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0157, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0256, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0002, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8998, device='cuda:0')
# epoch 5 seql 1
# tensor(0.9990, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6859, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0305, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4303, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0096, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2090, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0570, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7601, device='cuda:0')
# epoch 5 seql 1
# tensor(1.0479, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9955, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9858, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9953, device='cuda:0')
# epoch 6 seql 1
# tensor(1.0137, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8002, device='cuda:0')
# epoch 6 seql 1
# tensor(1.0035, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9705, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9996, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1495, device='cuda:0')
# epoch 6 seql 1
# tensor(1.0522, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9272, device='cuda:0')
# epoch 6 seql 1
# tensor(1.0152, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.5409, device='cuda:0')
# epoch 6 seql 1
# tensor(1.0601, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7418, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9811, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9627, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9752, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9622, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9948, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.4177, device='cuda:0')
# epoch 6 seql 1
# tensor(1.0088, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0452, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9051, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9737, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9426, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.4292, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9930, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6853, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9631, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1061, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9371, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8512, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9510, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6334, device='cuda:0')
# epoch 6 seql 1
# tensor(1.0036, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9032, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9193, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0339, device='cuda:0')
# epoch 6 seql 1
# tensor(0.9304, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0537, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9056, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8611, device='cuda:0')
# epoch 7 seql 1
# tensor(1.0768, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2918, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9813, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9082, device='cuda:0')
# epoch 7 seql 1
# tensor(0.8802, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0396, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9037, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1081, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9596, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9670, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9512, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1621, device='cuda:0')
# epoch 7 seql 1
# tensor(1.0128, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1946, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9054, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0036, device='cuda:0')
# epoch 7 seql 1
# tensor(0.8806, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0926, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9528, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7945, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9005, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8878, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9108, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0312, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9512, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.7193, device='cuda:0')
# epoch 7 seql 1
# tensor(1.0046, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8549, device='cuda:0')
# epoch 7 seql 1
# tensor(0.8363, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0702, device='cuda:0')
# epoch 7 seql 1
# tensor(0.8990, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.6896, device='cuda:0')
# epoch 7 seql 1
# tensor(0.9203, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4436, device='cuda:0')
# epoch 7 seql 1
# tensor(0.8639, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8249, device='cuda:0')
# epoch 7 seql 1
# tensor(1.0457, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.3458, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8451, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2700, device='cuda:0')
# epoch 8 seql 1
# tensor(0.9055, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7915, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8556, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9372, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8153, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.5169, device='cuda:0')
# epoch 8 seql 1
# tensor(0.9575, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5535, device='cuda:0')
# epoch 8 seql 1
# tensor(0.9100, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7564, device='cuda:0')
# epoch 8 seql 1
# tensor(0.9233, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.8674, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8563, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.0723, device='cuda:0')
# epoch 8 seql 1
# tensor(0.9406, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6136, device='cuda:0')
# epoch 8 seql 1
# tensor(0.9276, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7586, device='cuda:0')
# epoch 8 seql 1
# tensor(0.9236, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7467, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8864, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.3621, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8833, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7644, device='cuda:0')
# epoch 8 seql 1
# tensor(0.9262, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0218, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8867, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2791, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8327, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0327, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8856, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7901, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8565, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.6535, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8710, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7672, device='cuda:0')
# epoch 8 seql 1
# tensor(0.8855, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2230, device='cuda:0')
# epoch 9 seql 1
# tensor(0.9403, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.8094, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8265, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8573, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8660, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.5230, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8674, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(2.4006, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8317, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2146, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8881, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.7432, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8186, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.6315, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8651, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0277, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8829, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1919, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8020, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1699, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8469, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.9279, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8608, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7936, device='cuda:0')
# epoch 9 seql 1
# tensor(0.7433, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.0416, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8420, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.8500, device='cuda:0')
# epoch 9 seql 1
# tensor(0.7898, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.4648, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8509, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1270, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8218, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.1723, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8815, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(0.7530, device='cuda:0')
# epoch 9 seql 1
# tensor(0.7652, device='cuda:0', grad_fn=<MeanBackward0>)
# predictions tensor(1.2244, device='cuda:0')
# epoch 9 seql 1
# tensor(0.8236, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
"""model = model.train()
for epoch in range (20):
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(19):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      #print(x.shape,y.shape)
      if i == 0:
        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
        
      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)

      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch)
    print(loss)"""
# Out:
# 'model = model.train()\nfor epoch in range (20):\n  loss = None\n  for x,y in loader_train:\n    h0 = None\n    c0 = None\n    for i in range(19):\n      x = x.cuda()\n      y = y.cuda()\n      \n      optimizer.zero_grad()\n      #print(x.shape,y.shape)\n      if i == 0:\n        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)\n      else:\n        out, h0, c0, o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)\n        \n      loss = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)\n      writer.add_scalar("Loss/train", loss, epoch)\n\n      loss.backward()\n      optimizer.step()\n    #print(y[:,0,:2])\n    print(\'epoch\',epoch)\n    print(loss)'

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 64
test_dataset = DonutDataset(length = 64)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=4)
# Out:
# x0_y0_r_xrf_yrf torch.Size([64, 1]) torch.Size([64, 1]) torch.Size([64, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model = model.eval()
for epoch in range (1):
  loss = None
  for x,y in loader_test:
    h0 = None
    c0 = None
    loss = torch.zeros(3)
    for i in range(3):
      x = x.cuda()
      y = y.cuda()
      
      #print(x.shape,y.shape)
      if i == 0:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i)
      else:
        out, h0, c0,o = model(x,y[:,i*50:50*(i+1),:2],h0,c0,ind = i,o=o)
      
      loss[i] = torch.mean((out-y[:,1+(50*i):1+(50*(i+1)),:2])**2)
      print(loss[i])
      writer.add_scalar("Loss/val", loss[i],i, epoch)

    #print(y[:,0,:2])
    print('epoch',epoch)
    print('test loss', torch.mean(loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# tensor(0.5111, grad_fn=<SelectBackward>)
# tensor(3.4225, grad_fn=<SelectBackward>)
# tensor(12.4349, grad_fn=<SelectBackward>)
# epoch 0
# test loss tensor(5.4562, grad_fn=<MeanBackward0>)

# %%
writer.flush()
writer.close()

# %% [markdown]
# **started** with .0001 then moved to .00001 learning rate (20 epochs)
# finished with .000001 lr, but didn't see much more improvement (total 60 epochs 20,20,20) extra 20 over previous comment

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
# Out:
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
# torch.Size([1000, 2]) torch.Size([32, 32])
