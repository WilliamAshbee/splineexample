# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/LSTM_mcfixed_oldmodel_bestruns_updtedtraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %% [markdown]
# https://r2rt.com/non-zero-initial-states-for-recurrent-neural-networks.html

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):

    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}

def plot_all_model( sample = None, label=None,fig=None,ax=None):
    X = label[:,0]
    Y = label[:,1]
    img = sample[:,:].detach().squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    predres = 1000

    s = [.001 for x in range(predres)]
    
    assert len(s) == predres
    c = ['red' for x in range(predres)]
    assert len(c) == predres
    ax.scatter(X.detach().cpu().numpy(),Y.detach().cpu().numpy(),s = s,c = c)


def getXYs(model=None,loader_disp = None):

    outputs = torch.zeros(100,1000,2).cuda()
    h0 = None
    c0 = None
    
    for samples,labels in loader_disp:
      for i in range(38):
        optimizer.zero_grad()
        if i == 0:
          out, h0, c0,o,output = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i)
          outputs[:,i*25:(i+1)*25,:] = out.detach()
        else:
          out, h0, c0,o,output = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i,o = o,output=output)
          outputs[:,i*25:(i+1)*25,:] = out.detach()

      return samples, outputs


          
        

def plot_all( sample = None, labels = None,fig = None,ax = None):
    img = sample[:,:].squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    X = labels[:,0]
    Y = labels[:,1]
    s = [.001 for x in range(numpoints)]
    c = ['red' for x in range(numpoints)]
    ax.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
    
class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        fig = plt.figure()
          
        if model != None:
          model = model.eval()
          loader_disp = data.DataLoader(
            dataset, 
            batch_size=100,
            num_workers=2)
          samples, outputs = getXYs(model=model,loader_disp = loader_disp)
          for i in range(100):
            ax = fig.add_subplot(10,10,i+1)
            plot_all_model(samples[i,:,:],outputs[i,:,:],fig=fig,ax=ax)
            plt.axis('off')

        else:
          for i in range(100):
            sample, labels = dataset[i]
            ax = fig.add_subplot(10,10,i+1)
            plot_all(sample = sample,labels = labels,fig = fig, ax= ax)
            plt.axis('off')

        fig.savefig(title,dpi=450)
        plt.close(fig) #where f is the figure
        plt.clf()
        plt.cla()
        plt.close()#should free memory
        print('open file: ',title)

# %%
dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# open file:  donut.png

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 500
dataset = DonutDataset(length = 100*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([2000, 1]) torch.Size([2000, 1]) torch.Size([2000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
mini_batch = 250
test_dataset = DonutDataset(length = 1000)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1000, 1]) torch.Size([1000, 1]) torch.Size([1000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 512
        self.num_layers = 2
        self.seq_len = 25
        self.full_len = 1000
        self.lm_len = int(self.full_len/self.seq_len)
        
        self.longtermMem_lstm = None
        self.longtermMem_fc = None
        self.longtermMemP = None
        self.lstm_cell = nn.LSTM(self.hidden_size, self.hidden_size,self.num_layers)

        self.inject_image_lstm =  nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.hidden_size),
            #nn.Dropout(),
            nn.Tanh()
        )

        
        
        self.fc_out = nn.Sequential(
          nn.Linear(2+1024+3*self.hidden_size,2),
        #    nn.ReLU(),
        #    nn.Dropout(),
        #    nn.Linear(10000,2),
            nn.Sigmoid()
        )
        

        self.alpha_lstm = nn.Sequential(
            nn.Linear(self.hidden_size,self.seq_len),
            nn.Softmax()
        )
        self.alpha_fc = nn.Sequential(
            nn.Linear(self.hidden_size,self.seq_len),
            nn.Softmax()
        )

        self.alpha_long_lstm = nn.Sequential(
            nn.Linear(self.hidden_size,self.lm_len),
            nn.Softmax()
        )
        
        

        self.embs = None #= torch.empty((self.batch_size, 1000, self.hidden_size)).cuda()
        
        
        

            
        
    def forward(self, features,p0,h0 = None, c0= None, ind = 0, o = None,output = None):
        assert features != None
        #assert captions != None
        #print('featursescaptions2',features.shape,captions.shape)
        #assert features.shape[0]==captions.shape[0]
        assert len(features.shape) == 3
        self.track +=1
        batch_size = features.shape[0]
        

        #img_emb = torch.empty((batch_size, captions.size(1), self.hidden_size)).cuda()
        
        p0 = torch.flatten(p0[:,:2],start_dim=1)
        

        if o == None:
          out = p0
          self.longtermMem_lstm = torch.zeros(batch_size,self.lm_len,self.hidden_size).cuda()
          self.longtermMem_fc = torch.zeros(batch_size,self.lm_len,self.hidden_size).cuda()
          self.embs = torch.empty((batch_size, self.seq_len, self.hidden_size)).cuda()
        else:
          out = o

        
        if h0 == None and c0 == None:
          h0 = torch.zeros(self.num_layers,batch_size,self.hidden_size).cuda()
          c0 = torch.zeros(self.num_layers,batch_size,self.hidden_size).cuda()

        hidden_state = h0
        cell_state = c0
        outputs = torch.empty((batch_size, self.seq_len, 2)).cuda()
        
        output = None

        for t in range(self.seq_len):
        
            # for the first time step the input is the feature vector
            if output == None:
              output = torch.zeros(batch_size,self.hidden_size).cuda()
              outesread1_lstm = torch.zeros(batch_size,self.hidden_size).cuda()
              outesreadl1_lstm = torch.zeros(batch_size,self.hidden_size).cuda()
              outesread1_fc = torch.zeros(batch_size,self.hidden_size).cuda()
              outesreadl1_fc = torch.zeros(batch_size,self.hidden_size).cuda()
            else:
              a1_lstm = self.alpha_lstm(output.view(batch_size,self.hidden_size))
              outesreada1_lstm = self.embs.clone()*a1_lstm.unsqueeze(2)#clone
              outesread1_lstm = torch.sum(outesreada1_lstm,dim=1)
              al1_lstm = self.alpha_long_lstm(output.view(batch_size,self.hidden_size))
              outesreada1_lstm = self.longtermMem_lstm.clone()*al1_lstm.unsqueeze(2)#clone
              outesreadl1_lstm = torch.sum(outesreada1_lstm,dim=1)
              

              
            combin_lstm = torch.cat([torch.flatten(features,start_dim=1),out,output.view(batch_size,self.hidden_size),outesread1_lstm,outesreadl1_lstm],dim=1)
            combin_lstm = self.inject_image_lstm(combin_lstm)
            
            self.embs[:, t, :] = output.view(batch_size,self.hidden_size).clone().detach()
            
            
            
            output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))
            combin_lstm = None
            
            
            
            a1 = self.alpha_fc(output.view(batch_size,self.hidden_size))
            outesreada1 = self.embs.clone()*a1.unsqueeze(2)#clone
            outesread1 = torch.sum(outesreada1,dim=1)
            
            
            
            combin_fc = torch.cat([torch.flatten(features,start_dim=1),out,output.view(batch_size,self.hidden_size),outesread1_fc,outesreadl1_fc],dim=1)
            out = self.fc_out(combin_fc)
            out = out*32.0
            outputs[:, t, :] = out
            
            # build the output tensor
        self.longtermMem_lstm[:,ind,:] = output.view(batch_size,self.hidden_size).detach()
        #self.embs = self.embs.detach().clone()
        return outputs, hidden_state.detach(), cell_state.detach(), out.detach(),output.detach()#, captions

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
for seql in range(3,23,4):
  #seql = 19
  for epoch in range (5):
    loss = None
    model = model.train()

    for x,y in loader_train:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        optimizer.zero_grad()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        #writer.add_scalar("Loss/train", loss, epoch)
        
        loss.backward()
        optimizer.step()
      #print(y[:,0,:2])
      print('epoch',epoch,'seql',seql)
      print('train loss', loss)
    
    with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 3
# train loss tensor(27.7640, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(18.0819, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(8.7170, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(2.5895, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# testloss tensor(3.0009, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(2.9984, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(2.7811, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(2.8738, device='cuda:0')
# epoch 1 seql 3
# train loss tensor(5.4179, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(6.7277, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(5.5143, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.0849, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# testloss tensor(3.3596, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.6085, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.4194, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.5726, device='cuda:0')
# epoch 2 seql 3
# train loss tensor(3.1625, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.7530, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.7233, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.7389, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# testloss tensor(2.5103, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(2.6123, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(2.7185, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(2.5747, device='cuda:0')
# epoch 3 seql 3
# train loss tensor(2.8568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.9933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.9981, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(3.0880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# testloss tensor(3.1487, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(3.0446, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(3.0319, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(3.0177, device='cuda:0')
# epoch 4 seql 3
# train loss tensor(3.1513, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(3.1204, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(3.0302, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.8002, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# testloss tensor(2.6062, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.7373, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.5604, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.7009, device='cuda:0')
# epoch 0 seql 7
# train loss tensor(18.0866, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(8.7106, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(8.9135, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(9.6275, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# testloss tensor(9.0860, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(8.7454, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(8.7595, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(9.0494, device='cuda:0')
# epoch 1 seql 7
# train loss tensor(10.7566, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(11.4164, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(9.9838, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(9.0686, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# testloss tensor(8.0906, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(8.2921, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(8.4128, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(7.8727, device='cuda:0')
# epoch 2 seql 7
# train loss tensor(8.1533, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(7.4237, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(5.4063, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(6.8928, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# testloss tensor(10.1947, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(10.1936, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(10.0197, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(9.9615, device='cuda:0')
# epoch 3 seql 7
# train loss tensor(7.2240, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(3.9810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(6.7701, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(3.2490, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# testloss tensor(2.8415, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(2.6250, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(2.6683, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(2.6472, device='cuda:0')
# epoch 4 seql 7
# train loss tensor(2.3442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(2.6485, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(2.1228, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(2.0272, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# testloss tensor(1.9766, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(2.1610, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(2.1351, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(2.0818, device='cuda:0')
# epoch 0 seql 11
# train loss tensor(12.0056, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(2.1612, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(41.6776, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(10.7634, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# testloss tensor(9.5484, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(9.4579, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(9.4370, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(9.9830, device='cuda:0')
# epoch 1 seql 11
# train loss tensor(12.9582, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(8.7678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(8.4144, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(5.5679, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# testloss tensor(4.7669, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(4.9312, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(5.0488, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(4.8311, device='cuda:0')
# epoch 2 seql 11
# train loss tensor(6.4451, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(5.0243, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(4.7713, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(3.7395, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# testloss tensor(4.3066, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(4.6686, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(4.2188, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(4.4677, device='cuda:0')
# epoch 3 seql 11
# train loss tensor(2.2493, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(3.2457, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(6.5132, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(4.1127, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# testloss tensor(4.1998, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(3.9271, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(4.1878, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(4.1603, device='cuda:0')
# epoch 4 seql 11
# train loss tensor(4.7607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(4.6783, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(4.0514, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(2.7798, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# testloss tensor(3.0870, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(2.8536, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(2.8069, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(2.9318, device='cuda:0')
# epoch 0 seql 15
# train loss tensor(14.6885, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(7.2662, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(36.4338, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(15.4941, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# testloss tensor(11.9522, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(11.4007, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(11.4030, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(11.2160, device='cuda:0')
# epoch 1 seql 15
# train loss tensor(21.9879, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(12.3132, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(10.1294, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(9.1492, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# testloss tensor(6.5986, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(6.7254, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(6.2695, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(6.5657, device='cuda:0')
# epoch 2 seql 15
# train loss tensor(7.9951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(7.1504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(6.0925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(4.6664, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# testloss tensor(4.1413, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(4.3064, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(4.2098, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(4.0295, device='cuda:0')
# epoch 3 seql 15
# train loss tensor(3.8229, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(3.3050, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(2.5711, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(2.3728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# testloss tensor(2.6185, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(2.8023, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(2.4974, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(2.3247, device='cuda:0')
# epoch 4 seql 15
# train loss tensor(2.1551, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(2.4486, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(2.1385, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.9361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# testloss tensor(1.6638, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.5511, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.7326, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.6407, device='cuda:0')
# epoch 0 seql 19
# train loss tensor(8.3362, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(42.4049, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(13.6669, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(41.8572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# testloss tensor(21.1916, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(22.1647, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(21.6384, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(21.7064, device='cuda:0')
# epoch 1 seql 19
# train loss tensor(23.1607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(22.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(17.4217, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(15.9374, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# testloss tensor(13.5006, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(13.2907, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(13.5656, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(13.6227, device='cuda:0')
# epoch 2 seql 19
# train loss tensor(14.4624, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(13.6544, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(11.5647, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(9.5702, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# testloss tensor(7.3097, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(7.7593, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(7.4345, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(7.1650, device='cuda:0')
# epoch 3 seql 19
# train loss tensor(7.8578, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(3.4954, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(15.0195, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(6.6800, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# testloss tensor(5.3804, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(5.1952, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(5.3758, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(5.7534, device='cuda:0')
# epoch 4 seql 19
# train loss tensor(8.8686, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(4.9522, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(3.3974, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(2.6341, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# testloss tensor(3.5270, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(3.5507, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(3.1811, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(3.0145, device='cuda:0')

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate1.png',pred_dataset, model = model)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# open file:  intermediate1.png

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

for g in optimizer.param_groups:
    g['lr'] = 0.0001

# %%
#for seql in range(15,20,4):
seql = 23
for epoch in range (20):
  model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 23
# tensor(12.0261, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(4.2321, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(9.2412, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(62.1841, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(38.1183, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(38.8205, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(39.4430, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(41.5513, device='cuda:0')
# epoch 1 seql 23
# tensor(35.1975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(35.5287, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(30.9282, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(30.7195, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(26.1528, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(25.7716, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(26.7939, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(26.2526, device='cuda:0')
# epoch 2 seql 23
# tensor(29.6307, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(28.2252, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(27.6862, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(26.2276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(18.4922, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(17.5979, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(17.9221, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(18.2929, device='cuda:0')
# epoch 3 seql 23
# tensor(25.1914, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(27.9267, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(11.6486, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(15.2909, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(49.6210, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(50.7613, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(51.0202, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(45.2894, device='cuda:0')
# epoch 4 seql 23
# tensor(12.0108, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(10.1743, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(23.7224, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(21.2840, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(8.9059, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(8.6800, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(9.0228, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(8.9623, device='cuda:0')
# epoch 5 seql 23
# tensor(4.6785, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(4.6402, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(4.0921, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(5.9545, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(5.2019, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(5.1137, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(5.0657, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(5.2805, device='cuda:0')
# epoch 6 seql 23
# tensor(7.5718, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(3.5546, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(4.7041, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(6.4348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(2.4730, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(2.3640, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(2.5515, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(2.3425, device='cuda:0')
# epoch 7 seql 23
# tensor(3.3911, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.4648, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.3160, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(3.4918, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(3.9909, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(4.0921, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(4.2299, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(4.1332, device='cuda:0')
# epoch 8 seql 23
# tensor(4.3487, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(2.6604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(3.2525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(4.6059, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(1.8594, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.7845, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.8851, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.9117, device='cuda:0')
# epoch 9 seql 23
# tensor(2.1969, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.8287, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(2.2147, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.6628, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(2.4342, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(2.1202, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(2.0872, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(2.0873, device='cuda:0')
# epoch 10 seql 23
# tensor(1.8845, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.9398, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.7186, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(2.4038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# testloss tensor(1.9287, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.8339, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.7899, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.8190, device='cuda:0')
# epoch 11 seql 23
# tensor(2.4460, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(2.1573, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(4.3981, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(6.0046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# testloss tensor(1.5212, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.3366, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.5084, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.4162, device='cuda:0')
# epoch 12 seql 23
# tensor(2.1863, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(4.8146, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(2.5119, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(2.2827, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# testloss tensor(2.1741, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(2.1732, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(2.2750, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(2.2712, device='cuda:0')
# epoch 13 seql 23
# tensor(2.0157, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.5523, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.9836, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.3588, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# testloss tensor(1.4316, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.3044, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.3921, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.3450, device='cuda:0')
# epoch 14 seql 23
# tensor(1.6080, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(1.9669, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(1.3660, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(3.3043, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# testloss tensor(4.2264, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(4.3051, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(4.3804, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(4.2218, device='cuda:0')
# epoch 15 seql 23
# tensor(1.7042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(1.5765, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(2.5125, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(1.8680, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# testloss tensor(1.4066, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.2281, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.2811, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.4316, device='cuda:0')
# epoch 16 seql 23
# tensor(2.3119, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(2.1146, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(1.5508, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(1.6288, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# testloss tensor(2.4104, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(2.4232, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(2.5723, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(2.5846, device='cuda:0')
# epoch 17 seql 23
# tensor(1.9184, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(1.6664, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(1.4270, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(1.9622, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# testloss tensor(1.6278, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.6799, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.6757, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.5731, device='cuda:0')
# epoch 18 seql 23
# tensor(1.3073, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(1.4289, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(1.3117, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(1.3843, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# testloss tensor(1.9697, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(2.1064, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(2.1267, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(1.8737, device='cuda:0')
# epoch 19 seql 23
# tensor(2.1648, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(1.3965, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(1.3921, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(3.3720, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# testloss tensor(1.6170, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.4850, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.5431, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.5336, device='cuda:0')

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate2.png',pred_dataset, model = model)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# open file:  intermediate2.png

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
for g in optimizer.param_groups:
    g['lr'] = 0.00001

# %%
model = model.train()
#for seql in range(15,20,4):
seql = 23
for epoch in range (40):
  loss = None
  model = model.train()
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 23
# tensor(1.5105, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.3959, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.3041, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.3792, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(1.4227, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.4138, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.4250, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.3671, device='cuda:0')
# epoch 1 seql 23
# tensor(1.3563, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.3672, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.3173, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.2590, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(1.3864, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3604, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.2904, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3524, device='cuda:0')
# epoch 2 seql 23
# tensor(1.2519, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.2656, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.2706, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.2103, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(1.3137, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.1707, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.4406, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.3179, device='cuda:0')
# epoch 3 seql 23
# tensor(1.1747, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2418, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.1933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2533, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(1.2481, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.3366, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.3033, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.2820, device='cuda:0')
# epoch 4 seql 23
# tensor(1.1839, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.1639, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.2101, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.2630, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(1.3131, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.2783, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.2538, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.2980, device='cuda:0')
# epoch 5 seql 23
# tensor(1.1754, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1576, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.2203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.2362, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(1.2576, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.2494, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.2584, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.3691, device='cuda:0')
# epoch 6 seql 23
# tensor(1.1911, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.2369, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.2123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.1402, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(1.2185, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.2920, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.2657, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.3404, device='cuda:0')
# epoch 7 seql 23
# tensor(1.1618, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.2335, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.1883, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.1820, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(1.2102, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.3038, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.3109, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.2705, device='cuda:0')
# epoch 8 seql 23
# tensor(1.2516, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.1769, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.1844, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.1366, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(1.3721, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.2618, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.2171, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.2415, device='cuda:0')
# epoch 9 seql 23
# tensor(1.2010, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.1651, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.1703, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.2000, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(1.3501, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.1335, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.3719, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.2221, device='cuda:0')
# epoch 10 seql 23
# tensor(1.0911, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.2542, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.1510, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.2276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# testloss tensor(1.2325, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.3630, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.2415, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.2083, device='cuda:0')
# epoch 11 seql 23
# tensor(1.1563, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(1.1954, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(1.1680, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(1.1889, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# testloss tensor(1.3272, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.2271, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.1923, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.2869, device='cuda:0')
# epoch 12 seql 23
# tensor(1.1595, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(1.1934, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(1.1813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(1.1471, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# testloss tensor(1.2408, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(1.2870, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(1.2631, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(1.2220, device='cuda:0')
# epoch 13 seql 23
# tensor(1.1829, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.1681, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.1731, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.1479, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# testloss tensor(1.2290, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.1982, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.2943, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.2592, device='cuda:0')
# epoch 14 seql 23
# tensor(1.1559, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(1.2100, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(1.1405, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(1.1401, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# testloss tensor(1.2707, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(1.2877, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(1.1872, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(1.2065, device='cuda:0')
# epoch 15 seql 23
# tensor(1.1624, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(1.1455, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(1.1710, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(1.1590, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# testloss tensor(1.2836, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.2804, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.1754, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.2070, device='cuda:0')
# epoch 16 seql 23
# tensor(1.1389, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(1.1375, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(1.1527, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(1.1752, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# testloss tensor(1.2353, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(1.1405, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(1.2540, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(1.2800, device='cuda:0')
# epoch 17 seql 23
# tensor(1.1139, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(1.1730, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(1.1686, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(1.1375, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# testloss tensor(1.2508, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.1881, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.2149, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.2430, device='cuda:0')
# epoch 18 seql 23
# tensor(1.1525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(1.1139, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(1.1846, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(1.1180, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# testloss tensor(1.3018, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(1.1466, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(1.2347, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(1.1754, device='cuda:0')
# epoch 19 seql 23
# tensor(1.1094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(1.1917, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(1.1668, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(1.0845, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# testloss tensor(1.2373, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.0907, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.2393, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.2835, device='cuda:0')
# epoch 20 seql 23
# tensor(1.1288, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 20 seql 23
# tensor(1.1442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 20 seql 23
# tensor(1.1515, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 20 seql 23
# tensor(1.1033, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 20 seql 23
# testloss tensor(1.2670, device='cuda:0')
# epoch 20 seql 23
# testloss tensor(1.1862, device='cuda:0')
# epoch 20 seql 23
# testloss tensor(1.1501, device='cuda:0')
# epoch 20 seql 23
# testloss tensor(1.2275, device='cuda:0')
# epoch 21 seql 23
# tensor(1.1548, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 21 seql 23
# tensor(1.1328, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 21 seql 23
# tensor(1.1166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 21 seql 23
# tensor(1.1094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 21 seql 23
# testloss tensor(1.1710, device='cuda:0')
# epoch 21 seql 23
# testloss tensor(1.2538, device='cuda:0')
# epoch 21 seql 23
# testloss tensor(1.2065, device='cuda:0')
# epoch 21 seql 23
# testloss tensor(1.1693, device='cuda:0')
# epoch 22 seql 23
# tensor(1.1381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 22 seql 23
# tensor(1.1318, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 22 seql 23
# tensor(1.1114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 22 seql 23
# tensor(1.1169, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 22 seql 23
# testloss tensor(1.1976, device='cuda:0')
# epoch 22 seql 23
# testloss tensor(1.2886, device='cuda:0')
# epoch 22 seql 23
# testloss tensor(1.0658, device='cuda:0')
# epoch 22 seql 23
# testloss tensor(1.2318, device='cuda:0')
# epoch 23 seql 23
# tensor(1.1161, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 23 seql 23
# tensor(1.1765, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 23 seql 23
# tensor(1.0523, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 23 seql 23
# tensor(1.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 23 seql 23
# testloss tensor(1.1563, device='cuda:0')
# epoch 23 seql 23
# testloss tensor(1.1943, device='cuda:0')
# epoch 23 seql 23
# testloss tensor(1.1828, device='cuda:0')
# epoch 23 seql 23
# testloss tensor(1.2187, device='cuda:0')
# epoch 24 seql 23
# tensor(1.0854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 24 seql 23
# tensor(1.1624, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 24 seql 23
# tensor(1.1047, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 24 seql 23
# tensor(1.1076, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 24 seql 23
# testloss tensor(1.1939, device='cuda:0')
# epoch 24 seql 23
# testloss tensor(1.1659, device='cuda:0')
# epoch 24 seql 23
# testloss tensor(1.1818, device='cuda:0')
# epoch 24 seql 23
# testloss tensor(1.1979, device='cuda:0')
# epoch 25 seql 23
# tensor(1.1155, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 25 seql 23
# tensor(1.1319, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 25 seql 23
# tensor(1.0736, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 25 seql 23
# tensor(1.1146, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 25 seql 23
# testloss tensor(1.1577, device='cuda:0')
# epoch 25 seql 23
# testloss tensor(1.2929, device='cuda:0')
# epoch 25 seql 23
# testloss tensor(1.1367, device='cuda:0')
# epoch 25 seql 23
# testloss tensor(1.1346, device='cuda:0')
# epoch 26 seql 23
# tensor(1.0822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 26 seql 23
# tensor(1.1613, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 26 seql 23
# tensor(1.0810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 26 seql 23
# tensor(1.0920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 26 seql 23
# testloss tensor(1.0789, device='cuda:0')
# epoch 26 seql 23
# testloss tensor(1.0981, device='cuda:0')
# epoch 26 seql 23
# testloss tensor(1.2225, device='cuda:0')
# epoch 26 seql 23
# testloss tensor(1.2931, device='cuda:0')
# epoch 27 seql 23
# tensor(1.0535, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 27 seql 23
# tensor(1.0873, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 27 seql 23
# tensor(1.1602, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 27 seql 23
# tensor(1.1010, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 27 seql 23
# testloss tensor(1.1209, device='cuda:0')
# epoch 27 seql 23
# testloss tensor(1.1525, device='cuda:0')
# epoch 27 seql 23
# testloss tensor(1.1873, device='cuda:0')
# epoch 27 seql 23
# testloss tensor(1.2173, device='cuda:0')
# epoch 28 seql 23
# tensor(1.1069, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 28 seql 23
# tensor(1.0814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 28 seql 23
# tensor(1.1061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 28 seql 23
# tensor(1.0900, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 28 seql 23
# testloss tensor(1.1371, device='cuda:0')
# epoch 28 seql 23
# testloss tensor(1.1977, device='cuda:0')
# epoch 28 seql 23
# testloss tensor(1.1562, device='cuda:0')
# epoch 28 seql 23
# testloss tensor(1.1964, device='cuda:0')
# epoch 29 seql 23
# tensor(1.0813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 29 seql 23
# tensor(1.0795, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 29 seql 23
# tensor(1.1474, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 29 seql 23
# tensor(1.0447, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 29 seql 23
# testloss tensor(1.1730, device='cuda:0')
# epoch 29 seql 23
# testloss tensor(1.1802, device='cuda:0')
# epoch 29 seql 23
# testloss tensor(1.0617, device='cuda:0')
# epoch 29 seql 23
# testloss tensor(1.2175, device='cuda:0')
# epoch 30 seql 23
# tensor(1.0582, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 30 seql 23
# tensor(1.0550, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 30 seql 23
# tensor(1.1048, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 30 seql 23
# tensor(1.1185, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 30 seql 23
# testloss tensor(1.0284, device='cuda:0')
# epoch 30 seql 23
# testloss tensor(1.2532, device='cuda:0')
# epoch 30 seql 23
# testloss tensor(1.2120, device='cuda:0')
# epoch 30 seql 23
# testloss tensor(1.1189, device='cuda:0')
# epoch 31 seql 23
# tensor(1.0442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 31 seql 23
# tensor(1.1455, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 31 seql 23
# tensor(1.0668, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 31 seql 23
# tensor(1.0627, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 31 seql 23
# testloss tensor(1.0841, device='cuda:0')
# epoch 31 seql 23
# testloss tensor(1.1439, device='cuda:0')
# epoch 31 seql 23
# testloss tensor(1.1158, device='cuda:0')
# epoch 31 seql 23
# testloss tensor(1.2388, device='cuda:0')
# epoch 32 seql 23
# tensor(1.0880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 32 seql 23
# tensor(1.0360, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 32 seql 23
# tensor(1.0448, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 32 seql 23
# tensor(1.1261, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 32 seql 23
# testloss tensor(1.1953, device='cuda:0')
# epoch 32 seql 23
# testloss tensor(1.0344, device='cuda:0')
# epoch 32 seql 23
# testloss tensor(1.2314, device='cuda:0')
# epoch 32 seql 23
# testloss tensor(1.1149, device='cuda:0')
# epoch 33 seql 23
# tensor(1.0755, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 33 seql 23
# tensor(1.0531, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 33 seql 23
# tensor(1.0929, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 33 seql 23
# tensor(1.0562, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 33 seql 23
# testloss tensor(1.2177, device='cuda:0')
# epoch 33 seql 23
# testloss tensor(1.0628, device='cuda:0')
# epoch 33 seql 23
# testloss tensor(1.1074, device='cuda:0')
# epoch 33 seql 23
# testloss tensor(1.1517, device='cuda:0')
# epoch 34 seql 23
# tensor(0.9971, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 34 seql 23
# tensor(1.0990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 34 seql 23
# tensor(1.0696, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 34 seql 23
# tensor(1.0930, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 34 seql 23
# testloss tensor(1.1506, device='cuda:0')
# epoch 34 seql 23
# testloss tensor(1.0798, device='cuda:0')
# epoch 34 seql 23
# testloss tensor(1.1494, device='cuda:0')
# epoch 34 seql 23
# testloss tensor(1.1381, device='cuda:0')
# epoch 35 seql 23
# tensor(1.0391, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 35 seql 23
# tensor(1.0488, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 35 seql 23
# tensor(1.0793, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 35 seql 23
# tensor(1.0522, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 35 seql 23
# testloss tensor(1.1468, device='cuda:0')
# epoch 35 seql 23
# testloss tensor(1.1223, device='cuda:0')
# epoch 35 seql 23
# testloss tensor(1.1053, device='cuda:0')
# epoch 35 seql 23
# testloss tensor(1.1159, device='cuda:0')
# epoch 36 seql 23
# tensor(1.1122, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 36 seql 23
# tensor(1.0250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 36 seql 23
# tensor(1.0661, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 36 seql 23
# tensor(1.0178, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 36 seql 23
# testloss tensor(1.1127, device='cuda:0')
# epoch 36 seql 23
# testloss tensor(1.1153, device='cuda:0')
# epoch 36 seql 23
# testloss tensor(1.0498, device='cuda:0')
# epoch 36 seql 23
# testloss tensor(1.1776, device='cuda:0')
# epoch 37 seql 23
# tensor(1.0682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 37 seql 23
# tensor(1.0410, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 37 seql 23
# tensor(0.9493, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 37 seql 23
# tensor(1.1152, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 37 seql 23
# testloss tensor(1.1450, device='cuda:0')
# epoch 37 seql 23
# testloss tensor(1.0872, device='cuda:0')
# epoch 37 seql 23
# testloss tensor(1.0899, device='cuda:0')
# epoch 37 seql 23
# testloss tensor(1.1416, device='cuda:0')
# epoch 38 seql 23
# tensor(1.1123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 38 seql 23
# tensor(1.0566, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 38 seql 23
# tensor(1.0156, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 38 seql 23
# tensor(0.9860, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 38 seql 23
# testloss tensor(1.1124, device='cuda:0')
# epoch 38 seql 23
# testloss tensor(1.1480, device='cuda:0')
# epoch 38 seql 23
# testloss tensor(1.0965, device='cuda:0')
# epoch 38 seql 23
# testloss tensor(1.1064, device='cuda:0')
# epoch 39 seql 23
# tensor(1.0410, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 39 seql 23
# tensor(1.0446, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 39 seql 23
# tensor(1.0663, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 39 seql 23
# tensor(1.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 39 seql 23
# testloss tensor(1.0976, device='cuda:0')
# epoch 39 seql 23
# testloss tensor(1.1470, device='cuda:0')
# epoch 39 seql 23
# testloss tensor(1.1465, device='cuda:0')
# epoch 39 seql 23
# testloss tensor(1.0817, device='cuda:0')

# %%
writer.flush()
writer.close()

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
#!nvidia-smi

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# open file:  lstmpredictions.png

# %%
for name, param in model.named_parameters():
  print(name)
# Out:
# lstm_cell.weight_ih_l0
# lstm_cell.weight_hh_l0
# lstm_cell.bias_ih_l0
# lstm_cell.bias_hh_l0
# lstm_cell.weight_ih_l1
# lstm_cell.weight_hh_l1
# lstm_cell.bias_ih_l1
# lstm_cell.bias_hh_l1
# inject_image_lstm.0.weight
# inject_image_lstm.0.bias
# fc_out.0.weight
# fc_out.0.bias
# alpha_lstm.0.weight
# alpha_lstm.0.bias
# alpha_fc.0.weight
# alpha_fc.0.bias
# alpha_long_lstm.0.weight
# alpha_long_lstm.0.bias

# %%
with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 39 seql 23
# testloss tensor(1.0968, device='cuda:0')
# epoch 39 seql 23
# testloss tensor(1.1805, device='cuda:0')
# epoch 39 seql 23
# testloss tensor(1.0712, device='cuda:0')
# epoch 39 seql 23
# testloss tensor(1.1243, device='cuda:0')
