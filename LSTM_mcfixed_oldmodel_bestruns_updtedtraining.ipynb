# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/LSTM_mcfixed_oldmodel_bestruns_updtedtraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %% [markdown]
# https://r2rt.com/non-zero-initial-states-for-recurrent-neural-networks.html

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):

    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}

def plot_all_model( sample = None, label=None,fig=None,ax=None):
    X = label[:,0]
    Y = label[:,1]
    img = sample[:,:].detach().squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    predres = 1000

    s = [.001 for x in range(predres)]
    
    assert len(s) == predres
    c = ['red' for x in range(predres)]
    assert len(c) == predres
    ax.scatter(X.detach().cpu().numpy(),Y.detach().cpu().numpy(),s = s,c = c)


def getXYs(model=None,loader_disp = None):

    outputs = torch.zeros(100,1000,2).cuda()
    h0 = None
    c0 = None
    
    for samples,labels in loader_disp:
      for i in range(38):
        optimizer.zero_grad()
        if i == 0:
          out, h0, c0,o,output = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i)
          outputs[:,i*25:(i+1)*25,:] = out.detach()
        else:
          out, h0, c0,o,output = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i,o = o,output=output)
          outputs[:,i*25:(i+1)*25,:] = out.detach()

      return samples, outputs


          
        

def plot_all( sample = None, labels = None,fig = None,ax = None):
    img = sample[:,:].squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    X = labels[:,0]
    Y = labels[:,1]
    s = [.001 for x in range(numpoints)]
    c = ['red' for x in range(numpoints)]
    ax.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
    
class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,dataset, model):
        #model.setBatchSize(batch_size = 1)
        fig = plt.figure()
          
        if model != None:
          model = model.eval()
          loader_disp = data.DataLoader(
            dataset, 
            batch_size=100,
            num_workers=2)
          samples, outputs = getXYs(model=model,loader_disp = loader_disp)
          for i in range(100):
            ax = fig.add_subplot(10,10,i+1)
            plot_all_model(samples[i,:,:],outputs[i,:,:],fig=fig,ax=ax)
            plt.axis('off')

        else:
          for i in range(100):
            sample, labels = dataset[i]
            ax = fig.add_subplot(10,10,i+1)
            plot_all(sample = sample,labels = labels,fig = fig, ax= ax)
            plt.axis('off')

        fig.savefig(title,dpi=450)
        plt.close(fig) #where f is the figure
        plt.clf()
        plt.cla()
        plt.close()#should free memory
        print('open file: ',title)

# %%
dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# open file:  donut.png

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 500
dataset = DonutDataset(length = 100*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([2000, 1]) torch.Size([2000, 1]) torch.Size([2000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
mini_batch = 250
test_dataset = DonutDataset(length = 1000)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1000, 1]) torch.Size([1000, 1]) torch.Size([1000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 512
        self.num_layers = 2
        self.seq_len = 25
        self.full_len = 1000
        self.lm_len = int(self.full_len/self.seq_len)
        
        self.longtermMem_lstm = None
        
        self.lstm_cell = nn.LSTM(self.hidden_size, self.hidden_size,self.num_layers)

        self.inject_image_lstm =  nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
            #nn.Dropout(),
            nn.Tanh()
        )

        self.fc_out = nn.Sequential(
            nn.Linear(self.hidden_size,2),
            nn.Sigmoid()
        )
        

        
        self.alpha_long_lstm_r1 = nn.Sequential(
            nn.Linear(self.hidden_size,int(self.full_len/self.seq_len)),
            nn.Softmax()
        )
        
        
        self.alpha_1 = nn.Sequential(
            nn.Linear(self.hidden_size,self.seq_len),
            nn.Softmax()
        )
        self.alpha_start = nn.Sequential(
            nn.Linear(self.hidden_size,self.seq_len),
            nn.Softmax()
        )
        self.embs = None
        self.t0embs = None
          

    def forward(self, features,p0,h0 = None, c0= None, ind = 0, o = None,output = None):
        
        assert not torch.any(torch.isnan(features)).item()
        assert features != None
        assert len(features.shape) == 3
        batch_size = features.shape[0]
        
        p0 = torch.flatten(p0[:,:2],start_dim=1)
        
        if o == None:
          out = p0
          self.longtermMem_lstm = torch.zeros(batch_size,int(self.full_len/self.seq_len),self.hidden_size,requires_grad=False).cuda()
          self.embs = torch.zeros(batch_size,self.seq_len,self.hidden_size,requires_grad=False).cuda()
          self.t0embs = torch.zeros(batch_size,self.seq_len,self.hidden_size,requires_grad=False).cuda()
          self.track = 0
        else:
          out = o
        
        if h0 == None and c0 == None:
          h0 = torch.zeros(self.num_layers,batch_size,self.hidden_size).cuda()
          c0 = torch.zeros(self.num_layers,batch_size,self.hidden_size).cuda()

        hidden_state = h0
        cell_state = c0
        outputs = torch.empty((batch_size, self.seq_len, 2)).cuda()
        
        output = None

        for t in range(self.seq_len):
          self.track +=1
        
            
          if output == None:
            output = torch.zeros(batch_size,self.hidden_size).cuda()
            outesreadl1_lstm = torch.zeros(batch_size,self.hidden_size).cuda()
            outesread1_lstm = torch.zeros(batch_size,self.hidden_size).cuda()
            os_lstm = torch.zeros(batch_size,self.hidden_size).cuda()
          else:
            
            al1_lstm = self.alpha_long_lstm_r1(output.view(batch_size,self.hidden_size))
            outesreada1_lstm = self.longtermMem_lstm.clone()*al1_lstm.unsqueeze(2)#clone
            outesreadl1_lstm = torch.sum(outesreada1_lstm,dim=1)

            a1_lstm = self.alpha_1(output.view(batch_size,self.hidden_size))
            outesread1_lstm = self.embs.clone()*a1_lstm.unsqueeze(2)#clone
            outesread1_lstm = torch.sum(outesread1_lstm,dim=1)

            as_lstm = self.alpha_start(output.view(batch_size,self.hidden_size))
            os_lstm = self.t0embs.clone()*as_lstm.unsqueeze(2)#clone
            os_lstm = torch.sum(os_lstm,dim=1)

          combin_lstm = torch.cat([torch.flatten(features,start_dim=1),out,output.view(batch_size,self.hidden_size),outesreadl1_lstm,os_lstm,outesread1_lstm],dim=1)
          combin_lstm = self.inject_image_lstm(combin_lstm)
          
          
          output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))
          
          self.embs[:,t,:] = output.view(batch_size,self.hidden_size).detach()
          

          out = self.fc_out(output.view(batch_size,self.hidden_size))
          out = out*32.0
          outputs[:, t, :] = out

        self.longtermMem_lstm[:,ind,:] = output.view(batch_size,self.hidden_size).detach()
        if self.track < self.seq_len+2:
          self.t0embs = self.embs.clone() 
        return outputs, hidden_state.detach(), cell_state.detach(), out.detach(),output.detach()#, captions

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
for seql in range(3,23,4):
  #seql = 19
  for epoch in range (5):
    loss = None
    model = model.train()

    for x,y in loader_train:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        optimizer.zero_grad()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        #writer.add_scalar("Loss/train", loss, epoch)
        
        loss.backward()
        optimizer.step()
      #print(y[:,0,:2])
      print('epoch',epoch,'seql',seql)
      print('train loss', loss)
    
    with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 3
# train loss tensor(38.1546, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(23.0914, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(6.1264, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.3622, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# testloss tensor(7.3239, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(6.6766, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(6.9902, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(7.5108, device='cuda:0')
# epoch 1 seql 3
# train loss tensor(8.1015, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(6.2420, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.1539, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.4631, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# testloss tensor(3.2349, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.0304, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.0957, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.9584, device='cuda:0')
# epoch 2 seql 3
# train loss tensor(2.8610, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.0484, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(1.6696, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(1.8225, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# testloss tensor(1.9014, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.7910, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.8836, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.9279, device='cuda:0')
# epoch 3 seql 3
# train loss tensor(2.2318, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.8201, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.9411, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.8164, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# testloss tensor(2.5456, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(2.6958, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(2.4636, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(2.4675, device='cuda:0')
# epoch 4 seql 3
# train loss tensor(2.3325, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.1445, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(1.9646, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(1.7224, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# testloss tensor(1.7911, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(1.8581, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(1.6678, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(1.8822, device='cuda:0')
# epoch 0 seql 7
# train loss tensor(16.2868, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(6.1765, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(7.9724, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(11.0444, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# testloss tensor(10.2429, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(10.3458, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(10.4280, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(10.1175, device='cuda:0')
# epoch 1 seql 7
# train loss tensor(11.0288, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(9.0431, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(8.0348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(8.3928, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# testloss tensor(7.2402, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(7.3563, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(7.3504, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(7.4070, device='cuda:0')
# epoch 2 seql 7
# train loss tensor(8.1592, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(6.8170, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(6.5640, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(5.6046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# testloss tensor(3.9104, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(3.9843, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(4.0178, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(4.1029, device='cuda:0')
# epoch 3 seql 7
# train loss tensor(4.2150, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(2.7823, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.2507, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.5215, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# testloss tensor(1.3345, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.3439, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.3661, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.4975, device='cuda:0')
# epoch 4 seql 7
# train loss tensor(1.3494, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.4854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.6254, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.2849, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# testloss tensor(1.5190, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.4270, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.4415, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.2978, device='cuda:0')
# epoch 0 seql 11
# train loss tensor(11.1289, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(28.3763, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(11.5082, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(7.1947, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# testloss tensor(3.3726, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(3.3235, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(3.2082, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(3.3812, device='cuda:0')
# epoch 1 seql 11
# train loss tensor(23.5939, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(5.7189, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(7.7068, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(4.7936, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# testloss tensor(3.1487, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(3.0544, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(3.0590, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(3.0772, device='cuda:0')
# epoch 2 seql 11
# train loss tensor(6.7806, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(3.2160, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(4.8244, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(2.8648, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# testloss tensor(3.0461, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(3.1701, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(3.2806, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(3.2568, device='cuda:0')
# epoch 3 seql 11
# train loss tensor(3.9528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(4.9001, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(2.7888, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(4.1254, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# testloss tensor(3.8854, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(3.7815, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(3.6962, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(3.5792, device='cuda:0')
# epoch 4 seql 11
# train loss tensor(2.4216, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(2.7042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(2.1367, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(2.1522, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# testloss tensor(2.1304, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(2.0664, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(2.0604, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(2.2409, device='cuda:0')
# epoch 0 seql 15
# train loss tensor(6.5962, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(3.4282, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(14.7091, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(19.5677, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# testloss tensor(8.8272, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(8.9710, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(8.9605, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(9.0365, device='cuda:0')
# epoch 1 seql 15
# train loss tensor(9.4246, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(18.4830, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(6.8770, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(9.3139, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# testloss tensor(7.0798, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(6.9522, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(7.0114, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(7.1494, device='cuda:0')
# epoch 2 seql 15
# train loss tensor(6.0271, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(7.1763, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(7.7948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(5.1840, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# testloss tensor(5.0666, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(5.2999, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(5.0298, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(5.1387, device='cuda:0')
# epoch 3 seql 15
# train loss tensor(5.0369, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(4.9809, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(4.6693, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(2.4673, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# testloss tensor(2.1111, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(2.0357, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(2.1358, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(2.0514, device='cuda:0')
# epoch 4 seql 15
# train loss tensor(2.1829, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(9.9026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(3.2498, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.6637, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# testloss tensor(3.9430, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(3.7792, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(3.8538, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(3.8710, device='cuda:0')
# epoch 0 seql 19
# train loss tensor(3.5411, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(34.7771, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(30.0305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(19.1153, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# testloss tensor(11.9137, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(11.7341, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(11.6484, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(11.8274, device='cuda:0')
# epoch 1 seql 19
# train loss tensor(28.4673, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(16.9131, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(18.9355, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(15.0606, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# testloss tensor(13.7136, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(13.4593, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(13.3940, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(13.6997, device='cuda:0')
# epoch 2 seql 19
# train loss tensor(15.9273, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(13.7273, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(13.1230, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(11.6836, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# testloss tensor(6.8916, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(7.0786, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(7.0424, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(6.7919, device='cuda:0')
# epoch 3 seql 19
# train loss tensor(9.5469, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(6.5802, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(5.8923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(8.1918, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# testloss tensor(3.3298, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(3.3749, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(3.2882, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(3.3154, device='cuda:0')
# epoch 4 seql 19
# train loss tensor(8.4951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(3.6378, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(5.0171, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(18.9617, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# testloss tensor(83.3141, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(79.7088, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(79.0348, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(83.8572, device='cuda:0')

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate1.png',pred_dataset, model = model)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# open file:  intermediate1.png

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

for g in optimizer.param_groups:
    g['lr'] = 0.0001

# %%
#for seql in range(15,20,4):
seql = 23
for epoch in range (20):
  model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 23
# tensor(18.2548, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(9.2370, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(7.5500, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(26.7158, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(20.2984, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(19.9428, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(20.4935, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(20.1979, device='cuda:0')
# epoch 1 seql 23
# tensor(21.8314, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(35.1705, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(22.6518, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(21.5655, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(19.8061, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(20.2249, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(20.4176, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(20.0612, device='cuda:0')
# epoch 2 seql 23
# tensor(20.2872, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(19.9046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(18.4510, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(17.8544, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(16.4598, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(16.3062, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(16.0092, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(16.0204, device='cuda:0')
# epoch 3 seql 23
# tensor(16.8560, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(14.8767, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(13.3242, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(9.3149, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(8.5708, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(8.5858, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(8.5028, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(8.6385, device='cuda:0')
# epoch 4 seql 23
# tensor(5.3750, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(9.3491, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(10.6972, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(3.4598, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(4.2991, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(4.2283, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(4.4129, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(4.3080, device='cuda:0')
# epoch 5 seql 23
# tensor(4.0531, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(4.6983, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(3.0425, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(2.8206, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(2.6976, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(2.6902, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(2.6941, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(2.6814, device='cuda:0')
# epoch 6 seql 23
# tensor(3.3101, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.3290, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.2607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(5.6938, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(1.6573, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.6609, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.6653, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.7223, device='cuda:0')
# epoch 7 seql 23
# tensor(2.2922, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.8875, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(4.0637, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.2070, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(4.2485, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(4.1814, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(4.3645, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(4.0546, device='cuda:0')
# epoch 8 seql 23
# tensor(1.6681, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.7273, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(2.7084, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(2.3969, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(1.3992, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.4288, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.4339, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.3428, device='cuda:0')
# epoch 9 seql 23
# tensor(1.4393, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(3.2340, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(4.5551, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(3.5216, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(1.7021, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.7473, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.6814, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.9149, device='cuda:0')
# epoch 10 seql 23
# tensor(6.7190, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(3.3337, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(5.3017, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.3678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# testloss tensor(1.6693, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.6803, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.7052, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(1.7170, device='cuda:0')
# epoch 11 seql 23
# tensor(3.0391, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(1.7450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(1.4912, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(1.4136, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# testloss tensor(1.4681, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.4768, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.3908, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(1.4147, device='cuda:0')
# epoch 12 seql 23
# tensor(1.4161, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(1.5012, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(1.3739, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(1.3226, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# testloss tensor(1.3829, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(1.2847, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(1.4421, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(1.3652, device='cuda:0')
# epoch 13 seql 23
# tensor(1.4072, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.2877, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.3735, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(1.2841, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# testloss tensor(1.3098, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.3709, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.2702, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(1.3276, device='cuda:0')
# epoch 14 seql 23
# tensor(1.3198, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(1.3359, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(1.1948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(1.3180, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# testloss tensor(1.2861, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(1.3170, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(1.3631, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(1.3424, device='cuda:0')
# epoch 15 seql 23
# tensor(1.2423, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(1.2498, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(1.2778, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(1.2199, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# testloss tensor(1.2437, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.2517, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.1855, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(1.1682, device='cuda:0')
# epoch 16 seql 23
# tensor(1.4634, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(1.2518, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(1.7797, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(1.6223, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# testloss tensor(1.2174, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(1.2798, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(1.2096, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(1.1856, device='cuda:0')
# epoch 17 seql 23
# tensor(1.2420, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(2.1248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(1.5356, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(1.6276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# testloss tensor(1.2594, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.3703, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.2658, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(1.3322, device='cuda:0')
# epoch 18 seql 23
# tensor(1.5470, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(2.4628, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(3.4743, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(1.3512, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# testloss tensor(1.6366, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(1.7472, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(1.9471, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(1.7725, device='cuda:0')
# epoch 19 seql 23
# tensor(4.2651, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(3.3879, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(3.8905, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(1.3292, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# testloss tensor(1.3449, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.4459, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.3552, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(1.4559, device='cuda:0')

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate2.png',pred_dataset, model = model)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# open file:  intermediate2.png

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
for g in optimizer.param_groups:
    g['lr'] = 0.00001

# %%
model = model.train()
#for seql in range(15,20,4):
seql = 23
for epoch in range (40):
  loss = None
  model = model.train()
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 23
# tensor(1.2680, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.2025, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.1077, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.1395, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.1607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.2387, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.0621, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.1010, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.0203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.9920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.0525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.9718, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.0432, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.0491, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.9747, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.9796, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.9237, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.8966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.8524, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(0.7941, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.9200, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.9403, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.9771, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.8174, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.9207, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.7827, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.8037, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.7934, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.8661, device='cuda:0')
# epoch 1 seql 23
# tensor(0.8729, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9337, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9701, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.8359, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9405, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.8481, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9211, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.8760, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.8489, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9953, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.1457, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9556, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9758, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9470, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.8871, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9584, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.8083, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.8913, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.8381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.9755, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(0.8991, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.7555, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.7884, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.7810, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.8404, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.8371, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.9094, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.7699, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.7647, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.8547, device='cuda:0')
# epoch 2 seql 23
# tensor(0.9958, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9503, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.8488, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9677, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.8464, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9168, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9660, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9363, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9174, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.0165, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.8530, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9006, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9187, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.7970, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.7656, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.8591, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.9897, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.8392, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(0.7737, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.7824, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.8912, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.7666, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.8303, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.8198, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.8389, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.7508, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.8596, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.8210, device='cuda:0')
# epoch 3 seql 23
# tensor(0.8718, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8265, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8225, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8325, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8921, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8671, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8653, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8869, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.9360, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.9742, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.9044, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.0298, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.0719, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8753, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8559, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.9630, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.9396, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.9771, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.8251, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(0.7542, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.8511, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.7500, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.7847, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.8879, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.8483, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.8530, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.8377, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.7592, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.8410, device='cuda:0')
# epoch 4 seql 23
# tensor(0.8458, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9254, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.8474, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9370, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.8485, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.0231, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9593, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9296, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9190, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9014, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.9807, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.7865, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.8591, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.8316, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.8567, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.8586, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.8889, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.0722, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(0.8132, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.8149, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.8123, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.8083, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.7645, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.8383, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.8279, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.8902, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.8692, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.7489, device='cuda:0')
# epoch 5 seql 23
# tensor(0.8800, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.9043, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8352, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.0198, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.9193, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8919, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.9389, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.0007, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8684, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8332, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8391, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.7685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8969, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8258, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.0371, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.9477, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.9678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.0292, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.8518, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(0.8083, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.9646, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.8274, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.7856, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.8833, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.7609, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.8299, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.7204, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.8116, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.8769, device='cuda:0')
# epoch 6 seql 23
# tensor(0.9641, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8783, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8120, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8501, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8161, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8987, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.0212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.9328, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.0804, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.9636, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.7780, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.9055, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8887, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8894, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.0074, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.0047, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8358, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.8210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(0.8431, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.7423, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.7311, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.8627, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.8004, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.8370, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.8309, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.8741, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.8489, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.8713, device='cuda:0')
# epoch 7 seql 23
# tensor(0.9265, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8934, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9861, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9827, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9931, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8797, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.7980, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.7923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.7593, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9832, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8907, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8649, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9083, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8078, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.0757, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9347, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9303, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8270, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(0.7581, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.7432, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.8604, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.8952, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.8786, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.8110, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.8269, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.8944, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.7814, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.8277, device='cuda:0')
# epoch 8 seql 23
# tensor(0.8909, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.7462, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8127, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9554, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8326, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9103, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8383, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8083, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9009, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8621, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.1281, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9183, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8751, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9478, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8480, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9233, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.0217, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.8936, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(0.7954, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.7180, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.9116, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.8574, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.8506, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.7883, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.8288, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.8177, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.8572, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.8102, device='cuda:0')
# epoch 9 seql 23
# tensor(0.8751, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.7813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9687, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.8602, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.8687, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9537, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9461, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.8574, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.8587, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9435, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.8959, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9027, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.8365, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.7615, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.1047, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9390, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.8616, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.7599, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9575, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(0.7284, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.8184, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.7793, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.9048, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.8198, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.7959, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.8616, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.8544, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.7874, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.8652, device='cuda:0')
# epoch 10 seql 23
# tensor(0.8935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.7830, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.9182, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8826, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8699, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.9497, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8786, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.0201, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8374, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8663, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8418, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8631, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8407, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8518, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8131, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.9380, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.0306, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8693, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.8274, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# testloss tensor(0.8769, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.8118, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.7925, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.7872, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.7621, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.7986, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.7874, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.7816, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.8279, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.8611, device='cuda:0')
# epoch 11 seql 23
# tensor(0.9054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8583, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.7746, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.9774, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8206, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.9051, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.9205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.9183, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8052, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8223, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8800, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.7773, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8362, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8269, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(1.0347, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8179, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.9465, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.8194, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# testloss tensor(0.7175, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.7584, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.7973, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.6947, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.8444, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.8285, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.8229, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.8754, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.7533, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.8868, device='cuda:0')
# epoch 12 seql 23
# tensor(0.8212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8670, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8554, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8031, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8218, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.9313, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.9063, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.9583, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.9283, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.7740, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.9182, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.7498, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.9754, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.7354, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8021, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8338, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.9218, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.8176, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# testloss tensor(0.8670, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.7655, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.8155, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.7841, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.7535, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.7067, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.8609, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.7920, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.6484, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.8822, device='cuda:0')
# epoch 13 seql 23
# tensor(0.8149, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.9031, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.9908, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.7575, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8780, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.7870, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8788, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.9205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.7683, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8570, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8472, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8743, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8807, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8577, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8082, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8395, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.8934, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.7110, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.7258, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# testloss tensor(0.7261, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.7697, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.7702, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.7633, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.7357, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.8266, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.8362, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.7943, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.7705, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.7259, device='cuda:0')
# epoch 14 seql 23
# tensor(0.9194, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.7189, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8347, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.7253, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.7792, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8755, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.7867, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8448, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.7124, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8672, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.9388, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8057, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8195, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.7715, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8874, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.8260, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.7652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.9388, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.6973, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# testloss tensor(0.7044, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.7154, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.7053, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.8264, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.8122, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.7528, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.8556, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.7557, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.7051, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.7217, device='cuda:0')
# epoch 15 seql 23
# tensor(0.7612, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7322, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.8531, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.8114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.8173, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.9805, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7936, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.9035, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.9104, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7803, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.8217, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7280, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7004, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7600, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7481, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.6824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.7358, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.8783, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.8721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# testloss tensor(0.6980, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.8447, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.8193, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.6118, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.7663, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.6812, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.7487, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.8953, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.7034, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.6801, device='cuda:0')
# epoch 16 seql 23
# tensor(0.7055, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.6965, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.7701, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.8292, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.8896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.7411, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.7385, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.6777, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.7279, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.6948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.9451, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
writer.flush()
writer.close()

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
#!nvidia-smi

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# open file:  lstmpredictions.png

# %%
for name, param in model.named_parameters():
  print(name)

# %%
with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
