# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/abl_mlp_LSTM_readheadx6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %%
#TODO:TEST A DIFFERENT TYPE OF WRITE HEAD (ADD A SECOND LTM MEMORY MODULE)
#TODO:TEST A DIFFERENT TYPE OF LOSS TO SMOOTH OUT THE BLURRY READ/WRITE.

# %% [markdown]
# https://r2rt.com/non-zero-initial-states-for-recurrent-neural-networks.html

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):

    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}

def plot_all_model( sample = None, label=None,fig=None,ax=None):
    X = label[:,0]
    Y = label[:,1]
    img = sample[:,:].detach().squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    predres = 1000

    s = [.001 for x in range(predres)]
    
    assert len(s) == predres
    c = ['red' for x in range(predres)]
    assert len(c) == predres
    ax.scatter(X.detach().cpu().numpy(),Y.detach().cpu().numpy(),s = s,c = c)


def getXYs(model=None,loader_disp = None):

    outputs = torch.zeros(100,1000,2).cuda()
    h0 = None
    c0 = None
    
    for samples,labels in loader_disp:
      for i in range(38):
        optimizer.zero_grad()
        if i == 0:
          out, h0, c0,o,output = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i)
          outputs[:,i*25:(i+1)*25,:] = out.detach()
        else:
          out, h0, c0,o,output = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i,o = o,output=output)
          outputs[:,i*25:(i+1)*25,:] = out.detach()

      return samples, outputs


          
        

def plot_all( sample = None, labels = None,fig = None,ax = None):
    img = sample[:,:].squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    X = labels[:,0]
    Y = labels[:,1]
    s = [.001 for x in range(numpoints)]
    c = ['red' for x in range(numpoints)]
    ax.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
    
class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,ddataset, model):
        #model.setBatchSize(batch_size = 1)
        fig = plt.figure()
          
        if model != None:
          #model = model.eval()
          loader_disp = data.DataLoader(
            ddataset, 
            batch_size=100,
            num_workers=2)
          samples, outputs = getXYs(model=model,loader_disp = loader_disp)
          for i in range(100):
            ax = fig.add_subplot(10,10,i+1)
            plot_all_model(samples[i,:,:],outputs[i,:,:],fig=fig,ax=ax)
            plt.axis('off')

        else:
          for i in range(100):
            sample, labels = dataset[i]
            ax = fig.add_subplot(10,10,i+1)
            plot_all(sample = sample,labels = labels,fig = fig, ax= ax)
            plt.axis('off')

        fig.savefig(title,dpi=450)
        plt.close(fig) #where f is the figure
        plt.clf()
        plt.cla()
        plt.close()#should free memory
        print('open file: ',title)

# %%
dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# open file:  donut.png

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 100
dataset = DonutDataset(length = 100*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([2000, 1]) torch.Size([2000, 1]) torch.Size([2000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
mini_batch = 100
test_dataset = DonutDataset(length = 1000)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1000, 1]) torch.Size([1000, 1]) torch.Size([1000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 25
        self.full_len = 1000
        self.longmem_len = int(self.full_len/self.seq_len)
        self.longtermMem = None
        self.longtermMemP = None
        self.lstm_cell = nn.LSTM(2+1024+3*self.hidden_size, self.hidden_size,self.num_layers)

        self.inject_image =  nn.Sequential(
            nn.Linear(2+2*1000+1024+9*self.hidden_size,self.hidden_size*2),
            nn.ReLU()
        )

        
        self.fc_out = nn.Sequential(
            nn.Linear(2+2+1024+self.hidden_size*12,10000),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(10000,2),
            nn.Sigmoid()
        )
        self.hi_1 = nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
        )
        self.hi_2 = nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
        )

        self.ci_1 = nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
        )
        self.ci_2 = nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
        )

        self.alpha_1 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.seq_len),
            nn.Softmax()
        )
        
        self.alpha_long1 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        
        self.alpha_long2 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        
        self.alpha_long3 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        self.alpha_long4 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        self.alpha_long5 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        self.alpha_long6 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        
        self.long_term_write = nn.Sequential(
            nn.Linear(self.hidden_size*(self.seq_len+1),self.hidden_size),
            nn.ReLU()
        )
        

        self.embs = None #= torch.empty((self.batch_size, 1000, self.hidden_size)).cuda()
        self.ltm_temp = None
        self.lt_reads = None
        self.num_rh = 6
        self.st_reads = None
        
    def forward(self, features, p0,h0 = None, c0= None, ind = 0, o = None,output = None):
        #print('a')
        assert features != None
        self.track +=1
        batch_size = features.size(0)
        

        
        
        if o == None:
          out = p0
          self.longtermMem = torch.zeros(batch_size,self.longmem_len,self.hidden_size).cuda()
          self.embs = torch.empty((batch_size, self.seq_len, self.hidden_size)).cuda()
          self.longtermMemP = torch.zeros(batch_size,1000,2).cuda()
          self.ltm_temp = torch.zeros(batch_size,self.hidden_size).cuda()
          self.lt_reads = torch.zeros(batch_size,self.num_rh,self.hidden_size).cuda()
          self.st_reads = torch.zeros(batch_size,self.hidden_size).cuda()
        else:

          #self.ltm_temp = self.long_term_write(torch.cat([torch.flatten(self.embs,start_dim=1),output.squeeze()],dim=1))
          #self.longtermMem[:, ind-1, :] = self.ltm_temp
        
          #self.embs = torch.empty((batch_size, self.seq_len, self.hidden_size)).cuda()
          
          out = o

        #print('c')
        outputs = torch.empty((batch_size, self.seq_len, 2)).cuda()
        
        #output = None
        #print('b')
        for t in range(self.seq_len):
        
            # for the first time step the input is the feature vector
            if output == None:
              output = torch.zeros(batch_size,self.hidden_size).cuda()
            if t == 0:##fix this!!!
              outesread1 = self.st_reads
              outesreadl1 = self.lt_reads[:,0,:]
              outesreadl2 = self.lt_reads[:,1,:]
              outesreadl3 = self.lt_reads[:,2,:]
              outesreadl4 = self.lt_reads[:,3,:]
              outesreadl5 = self.lt_reads[:,4,:]
              outesreadl6 = self.lt_reads[:,5,:]
            #print('a')  
            combin_lstm = torch.cat([out.squeeze(),torch.flatten(features,start_dim=1),torch.flatten(self.longtermMemP,start_dim=1),output.squeeze(),outesread1,outesreadl1,outesreadl2,outesreadl3,outesreadl4,outesreadl5,outesreadl6,self.ltm_temp],dim=1)
            combin_lstm = self.inject_image(combin_lstm)
            combin_lstm = torch.cat([out.squeeze(),torch.flatten(features,start_dim=1),output.squeeze(),combin_lstm],dim=1)
            """if h0 == None and c0 == None:
              combin_init = torch.cat([combin_lstm,torch.zeros(batch_size,self.hidden_size).cuda()],dim=1)
              h_0_1 = self.hi_1(combin_init)  
              h_0_2 = self.hi_2(combin_init)  
              c_0_1 = self.ci_1(combin_init)  
              c_0_2 = self.ci_2(combin_init)  
              
              h0 = torch.stack([h_0_1,h_0_2],dim = 0)
              c0 = torch.stack([c_0_1,c_0_2],dim = 0)
              
              hidden_state = h0
              cell_state = c0
            
            elif t==0:
              #combin_init = torch.cat([torch.flatten(features,start_dim=1),out,output.squeeze(),h0[0,:,:]],dim=1)
              combin_init = torch.cat([combin_lstm,h0[0,:,:]],dim=1)
              
              h_0_1 = self.hi_1(combin_init)  
              
              #combin_init = torch.cat([torch.flatten(features,start_dim=1),out,output.squeeze(),h0[1,:,:]],dim=1)
              combin_init = torch.cat([combin_lstm,h0[1,:,:]],dim=1)
              h_0_2 = self.hi_2(combin_init)  
              
              #combin_init = torch.cat([torch.flatten(features,start_dim=1),out,output.squeeze(),c0[0,:,:]],dim=1)
              combin_init = torch.cat([combin_lstm,c0[0,:,:]],dim=1)
              c_0_1 = self.ci_1(combin_init)  
              
              #combin_init = torch.cat([torch.flatten(features,start_dim=1),out,output.squeeze(),c0[1,:,:]],dim=1)
              combin_init = torch.cat([combin_lstm,c0[1,:,:]],dim=1)
              c_0_2 = self.ci_2(combin_init)
              
              h0 = torch.stack([h_0_1,h_0_2],dim = 0)
              c0 = torch.stack([c_0_1,c_0_2],dim = 0)
        

              hidden_state = h0
              cell_state = c0
              
            #print('b')

            #a1 = self.alpha_1(combin_lstm)
            #outesreada1 = self.embs.clone()*a1.unsqueeze(2)#clone
            #outesread1 = torch.sum(outesreada1,dim=1)
            
            
            output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))
            #print('c')
            self.longtermMemP[:,self.seq_len*ind+t,:] = out.detach()
            
            self.embs[:, t, :] = output.squeeze().clone().detach()
            

            a1 = self.alpha_1(combin_lstm)
            outesreada1 = self.embs.clone()*a1.unsqueeze(2)#clone
            outesread1 = torch.sum(outesreada1,dim=1)
            self.st_reads = outesread1.detach()
            
            
            #print('d')
            al1 = self.alpha_long1(combin_lstm)
            outesreadal1 = self.longtermMem.detach()*al1.unsqueeze(2)#clone
            outesreadl1 = torch.sum(outesreadal1,dim=1)
            self.lt_reads[:,0,:] = outesreadl1.detach()
            
            al2 = self.alpha_long2(combin_lstm)
            outesreadal2 = self.longtermMem.detach()*al2.unsqueeze(2)#clone
            outesreadl2 = torch.sum(outesreadal2,dim=1)
            self.lt_reads[:,1,:] = outesreadl2.detach()
            
            al3 = self.alpha_long3(combin_lstm)
            outesreadal3 = self.longtermMem.detach()*al3.unsqueeze(2)#clone
            outesreadl3 = torch.sum(outesreadal3,dim=1)
            self.lt_reads[:,2,:] = outesreadl3.detach()
            
            al4 = self.alpha_long4(combin_lstm)
            outesreadal4 = self.longtermMem.detach()*al4.unsqueeze(2)#clone
            outesreadl4 = torch.sum(outesreadal4,dim=1)
            self.lt_reads[:,3,:] = outesreadl4.detach()
            
            al5 = self.alpha_long4(combin_lstm)
            outesreadal5 = self.longtermMem.detach()*al5.unsqueeze(2)#clone
            outesreadl5 = torch.sum(outesreadal5,dim=1)
            self.lt_reads[:,4,:] = outesreadl5.detach()
            
            al6 = self.alpha_long6(combin_lstm)
            outesreadal6 = self.longtermMem.detach()*al6.unsqueeze(2)#clone
            outesreadl6 = torch.sum(outesreadal6,dim=1)
            self.lt_reads[:,5,:] = outesreadl6.detach()
            
            #print('e')
            """
            combOut = torch.cat([combin_lstm, output.squeeze(),out,outesread1,outesreadl1,outesreadl2,outesreadl3,outesreadl4,outesreadl5,outesreadl6,self.ltm_temp],dim=1)#,outesread],dim=1)
            

            out = self.fc_out(combOut)
            out = out*32.0
            # build the output tensor
            outputs[:, t, :] = out
            
        
            
        #self.embs = self.embs.detach().clone()
        return outputs, None, None, out.detach(),None#, captions

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
for seql in range(3,23,6):
  #seql = 19
  for epoch in range (2):
    loss = None
    #model = model.train()

    for x,y in loader_train:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        optimizer.zero_grad()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        #writer.add_scalar("Loss/train", loss, epoch)
        
        loss.backward()
        optimizer.step()
      #print(y[:,0,:2])
      print('epoch',epoch,'seql',seql)
      print('train loss', loss)
    
    with torch.no_grad():
      #model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# epoch 0 seql 3
# train loss tensor(40.7580, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(26.6165, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(15.6721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(8.9932, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.2533, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.5849, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.0996, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.5200, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.4300, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.4125, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.8287, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(6.1636, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.2899, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.2210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.1859, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.5536, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.4743, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.6204, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.3523, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.9038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# testloss tensor(3.9553, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.3073, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.1534, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.3039, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.3149, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.1549, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.2528, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.1859, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.1059, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(4.1044, device='cuda:0')
# epoch 1 seql 3
# train loss tensor(4.4309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.1133, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.0027, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.3325, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.8674, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.8611, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.8340, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.7162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.8504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.0105, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.1262, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.0685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.0764, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.5794, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.9261, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.1203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.8854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(4.1534, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.9482, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.6742, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# testloss tensor(3.7851, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.9309, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.8673, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.8333, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(4.0112, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.8055, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(4.0587, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.8656, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.9498, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.7710, device='cuda:0')
# epoch 0 seql 9
# train loss tensor(33.8823, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(16.7594, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(13.4348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.0496, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(21.2671, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(20.4479, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.7851, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.2039, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(19.2580, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.6954, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.5119, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.5708, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.8964, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.6344, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.8390, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.3214, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(19.2691, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.6083, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.1613, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(18.2583, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# testloss tensor(17.8083, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(17.1554, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(16.5003, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(17.4757, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(17.1002, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(17.5960, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(17.5939, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(16.9418, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(17.1781, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(17.6322, device='cuda:0')
# epoch 1 seql 9
# train loss tensor(18.5309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.5802, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.3921, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(19.3832, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(19.0128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(17.5689, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.8237, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.8246, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.5546, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(17.6711, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.7304, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.6469, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.4850, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(17.7080, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.1492, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(19.1439, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.9744, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(17.7984, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.1822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(18.2764, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# testloss tensor(17.5602, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(16.8569, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(17.0128, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(16.4447, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(17.5970, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(17.3308, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(17.0540, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(16.5283, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(17.6546, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(17.8629, device='cuda:0')
# epoch 0 seql 15
# train loss tensor(54.8715, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(40.9036, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(44.0771, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(46.6431, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(44.5969, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(45.8738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(44.7311, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(44.3258, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(42.9588, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(43.2281, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(42.2361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(44.9872, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(43.5864, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(43.0140, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(43.2918, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(44.6193, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(43.4684, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(42.5133, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(43.1597, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(43.6991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# testloss tensor(40.8557, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(41.2376, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(40.6642, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(39.6130, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(41.6627, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(40.7912, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(39.4453, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(42.3425, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(40.2497, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(40.6483, device='cuda:0')
# epoch 1 seql 15
# train loss tensor(43.5348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(43.4432, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(42.9953, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(43.4307, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(44.7186, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(44.1945, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(44.1650, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(43.4911, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(41.7557, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(43.7330, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(41.0271, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(41.7538, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(42.6588, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(43.0192, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(44.9464, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(44.0097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(43.4867, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(42.5436, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(43.2381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(43.5955, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# testloss tensor(40.9504, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(43.1075, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(41.0322, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(40.4516, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(40.3013, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(40.3597, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(41.1674, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(39.7758, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(40.4052, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(40.6003, device='cuda:0')
# epoch 0 seql 21
# train loss tensor(72.7976, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(61.9696, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(68.7106, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(62.6187, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(64.0456, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(64.7199, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(64.4130, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(61.8747, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(63.6885, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(62.3994, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(61.5924, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(66.6911, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(65.4805, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(66.6490, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(61.3019, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(61.3593, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(62.0302, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(60.9749, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(62.2016, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(62.6307, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# testloss tensor(59.9594, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(58.6985, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(58.4697, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(60.3556, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(57.1850, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(58.7451, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(61.0261, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(60.2086, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(59.3224, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(60.0935, device='cuda:0')
# epoch 1 seql 21
# train loss tensor(63.3753, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.4291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.8957, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.6758, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.3737, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(59.5322, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(64.7094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.8665, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(64.3682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(65.1459, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.3698, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(60.6691, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.2099, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(60.7558, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.4568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(60.3024, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(63.9718, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(62.8346, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(66.0349, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(63.6355, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# testloss tensor(61.8262, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(57.7530, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(61.1551, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(58.3453, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(58.8081, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(61.1555, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(59.5481, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(60.9109, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(58.2073, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(58.9811, device='cuda:0')

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

#for g in optimizer.param_groups:
#    g['lr'] = 0.0001

torch.save(model.state_dict(), "lastmodel.pth")

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('intermediate1.png',pred_dataset, model = model)
# Out:
# open file:  intermediate1.png

# %%
#for seql in range(15,20,4):
seql = 23
for epoch in range (10):
  #model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    #model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
# Out:
# epoch 0 seql 23
# tensor(73.4191, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(67.4782, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(67.1068, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(67.4649, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.2206, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(68.7081, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.2179, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(69.7758, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(69.1678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(64.6661, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(64.8324, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(67.7910, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(67.6662, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.5275, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(68.6397, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.3387, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(66.2767, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(67.2571, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(68.7711, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(66.6426, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(62.5123, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(61.5385, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(64.8960, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(63.8780, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(61.2392, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(64.7803, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(64.0701, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(61.0332, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(66.1209, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(63.5196, device='cuda:0')
# epoch 1 seql 23
# tensor(64.9680, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(70.4706, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(67.2163, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(64.4584, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(66.7305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(66.3086, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(62.9406, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(68.3546, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.2210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.6696, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(69.7626, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(64.1039, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(64.5978, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(68.2431, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(64.1594, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(69.4309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(66.8928, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(69.2088, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(66.9030, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.7251, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(62.8221, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(63.1212, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(62.5885, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(64.9497, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(62.1301, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(63.2003, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(65.8211, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(65.7084, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(64.5069, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(63.8420, device='cuda:0')
# epoch 2 seql 23
# tensor(70.2621, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(69.1584, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(65.3017, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(63.8345, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(65.2636, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(65.1553, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(63.5959, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(68.7212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(64.9874, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(67.5725, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(65.1057, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(63.8570, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(65.9923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(67.8536, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(64.5638, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(66.8018, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(65.4981, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(66.0798, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(70.4283, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(66.5380, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(63.7721, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(66.0723, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(62.4515, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(63.9049, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(61.9927, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(60.1437, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(62.6624, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(66.4580, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(64.1646, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(62.1588, device='cuda:0')
# epoch 3 seql 23
# tensor(64.4425, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(67.0036, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(66.2201, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(66.5227, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.4535, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(66.6775, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(66.5412, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(65.7378, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(68.2203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.8442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.4850, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(66.0927, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(67.4806, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(68.6595, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(68.6642, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.3946, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(65.0095, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(65.9597, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(65.0124, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(65.8733, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(62.7440, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(63.0147, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(62.9130, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(65.4428, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(64.4948, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(64.2202, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(65.2748, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(63.1281, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(63.8238, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(63.8486, device='cuda:0')
# epoch 4 seql 23
# tensor(65.4894, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(64.7804, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(65.2600, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(69.2503, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(66.4191, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(64.1725, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(65.5403, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(64.3434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(66.6845, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(63.3764, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(68.6203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(63.6557, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(65.2779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(68.5566, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(64.8827, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(66.5677, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(67.4699, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(68.2320, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(66.7120, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(66.3700, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(65.4692, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(62.5011, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(65.3765, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(62.6111, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(63.6992, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(65.5398, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(63.4336, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(63.4546, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(61.9197, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(65.3716, device='cuda:0')
# epoch 5 seql 23
# tensor(65.8690, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(64.0267, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(66.8044, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(66.3782, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(65.6641, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(68.7165, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(66.2420, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(68.2854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(67.0044, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(67.8144, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(64.8264, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(65.7781, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(66.0413, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(64.1707, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(64.4106, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(63.6374, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(66.9081, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(68.4813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(64.9354, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(63.8721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(63.6971, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(64.0870, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(65.7724, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(64.0230, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(63.7623, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(62.7242, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(63.6592, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(65.3885, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(61.8131, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(63.5850, device='cuda:0')
# epoch 6 seql 23
# tensor(63.5895, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(63.1445, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.4243, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.9689, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(65.4149, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(63.9474, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(67.4511, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(66.7054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(65.0939, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(68.7793, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(68.6371, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(67.3217, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(62.4905, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(63.8112, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(69.1421, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(66.4990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(66.1131, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(66.9827, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(66.6733, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(66.9181, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(63.2017, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(64.3409, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(65.0989, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(61.8022, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(64.1464, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(64.1931, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(63.3408, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(64.4392, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(63.8856, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(63.1582, device='cuda:0')
# epoch 7 seql 23
# tensor(65.1573, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(66.0561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(64.6001, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(62.9097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(65.5182, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(66.1982, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(67.0231, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(65.0930, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(66.5034, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(64.5007, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(65.4986, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(63.9008, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(64.6240, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(64.7281, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(69.3841, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(69.4005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(65.4197, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(66.4939, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(64.8109, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(69.3288, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(63.4694, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(62.7290, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(65.7389, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(66.5067, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(62.6363, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(67.1513, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(65.0765, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(64.8222, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(63.7368, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(60.7377, device='cuda:0')
# epoch 8 seql 23
# tensor(69.6630, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.3876, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(61.6608, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.3598, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.3493, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(65.0368, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(68.5943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(63.0678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(66.9558, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(65.1304, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(67.3106, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(65.9807, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(65.1162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(68.8499, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(66.4237, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(66.4375, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(65.8477, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(70.0773, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(61.3107, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.9327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(63.7213, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(63.0334, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(65.3485, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(64.1186, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(65.4876, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(67.2017, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(63.6402, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(61.8619, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(62.3972, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(62.2121, device='cuda:0')
# epoch 9 seql 23
# tensor(62.9372, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(66.7710, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(64.8201, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.5080, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(68.3206, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(62.6579, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(67.3453, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(64.9381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(69.6310, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(67.4886, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(66.2192, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(68.1992, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.7501, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(62.8201, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.3216, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(66.3020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.5072, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(63.5190, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(64.9147, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.4952, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(66.8905, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(59.8509, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(64.2136, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(62.5769, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(64.5747, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(66.2445, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(63.8426, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(60.5193, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(64.9514, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(63.8989, device='cuda:0')

# %%
torch.save(model.state_dict(), "lastmodel.pth")

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('intermediate2.png',pred_dataset, model = model)
# Out:
# open file:  intermediate2.png

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
for g in optimizer.param_groups:
    g['lr'] = 0.00001

# %%
#for seql in range(15,20,4):
seql = 23
for epoch in range (200):
  #model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    #model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
# Out:
# epoch 0 seql 23
# tensor(63.0806, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(69.6810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(62.5169, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.9833, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.2785, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(64.9633, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(62.9761, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(68.6177, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(63.5157, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(63.9639, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.9341, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(69.2132, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(64.4210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(62.7910, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(68.0123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.9511, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(66.2028, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(68.0515, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(65.9698, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(66.7224, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(76.4674, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(71.7516, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(79.4030, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(76.7625, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(77.0961, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(79.1956, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(84.9214, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(71.3195, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(77.8722, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(78.2172, device='cuda:0')
# epoch 1 seql 23
# tensor(69.2798, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(68.5563, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(63.9778, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.1696, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.9925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.9424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(66.0252, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(67.1614, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(64.4622, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(63.3847, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(64.4825, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(63.0552, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(63.5184, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(66.8997, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.8900, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.0766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.5384, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(66.1188, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(65.5809, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(64.9029, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(63.7744, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(61.5321, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(64.2371, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(66.1831, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(61.7831, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(65.9912, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(62.9422, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(62.8015, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(60.5002, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(65.2270, device='cuda:0')
# epoch 2 seql 23
# tensor(64.2330, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(67.1488, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(66.6278, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(62.4796, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(64.9162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(63.8954, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(64.6007, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(63.4409, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(64.6750, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(70.7600, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(64.2650, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(63.8775, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(62.7474, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(67.8121, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(65.3690, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(69.1410, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(65.0944, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(67.5226, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(64.9961, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(63.2758, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(97.8267, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(88.7686, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(102.5085, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(98.6237, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(96.0229, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(106.8474, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(91.0995, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(80.0296, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(85.8563, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(89.2004, device='cuda:0')
# epoch 3 seql 23
# tensor(70.0073, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.8740, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(62.6670, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(68.5343, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(66.8888, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(67.2244, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(67.2763, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.7499, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(67.3085, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(60.3907, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(65.3198, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(65.9409, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(66.9877, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(63.5569, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.4807, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.6359, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(65.5443, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(62.9771, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(64.4218, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(62.6721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(64.9588, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(64.0494, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(62.0884, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(63.6889, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(61.3182, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(63.4011, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(65.8896, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(60.9623, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(63.1793, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(63.7314, device='cuda:0')
# epoch 4 seql 23
# tensor(65.1740, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(67.3877, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(62.0697, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(65.7291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(68.9782, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(63.7909, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(62.9957, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(67.6493, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(63.4410, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(64.3244, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(66.8083, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(63.3797, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(63.5058, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(62.3123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(69.4491, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(67.6540, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(63.2945, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(65.3504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(66.1345, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(65.7749, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(65.3801, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(62.3013, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(62.4599, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(60.7452, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(65.8709, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(63.4177, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(63.4564, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(61.5133, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(62.4300, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(65.4037, device='cuda:0')
# epoch 5 seql 23
# tensor(64.5567, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(63.3099, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(61.2881, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(64.0048, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(67.4676, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(67.5858, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(67.1262, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(65.8948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(62.3219, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(69.4413, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(66.5921, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(66.9597, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(63.9913, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(65.3961, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(63.8345, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(66.3919, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(63.6953, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(63.8284, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(62.2886, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(70.1323, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(67.8288, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(70.8034, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(71.1692, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(68.2254, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(67.7935, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(70.9966, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(68.3651, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(67.1933, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(69.4973, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(69.5051, device='cuda:0')
# epoch 6 seql 23
# tensor(72.2297, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(65.4819, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.8058, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(66.0933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.7581, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.3302, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.9856, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.3183, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(63.5884, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(65.7270, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(65.1581, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(63.0564, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(65.0761, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.4309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(66.5194, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.4412, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(65.7274, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(65.0990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.6830, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(64.2397, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(60.9247, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(63.0181, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(66.2348, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(61.1637, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(63.3809, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(64.6242, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(65.0584, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(66.6311, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(62.7428, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(62.8022, device='cuda:0')
# epoch 7 seql 23
# tensor(67.5466, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(63.9154, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(67.5717, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(65.3145, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(65.0206, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(65.2590, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(63.7385, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(64.7232, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(63.7114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(63.6861, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(62.4752, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(65.0106, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(62.4000, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(64.7361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(66.8742, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(69.9147, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(64.7363, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(67.3040, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(66.1652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(61.4681, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(61.6496, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(62.0126, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(64.7217, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(63.6265, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(64.9561, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(63.7917, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(63.4716, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(62.6815, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(63.2800, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(63.3079, device='cuda:0')
# epoch 8 seql 23
# tensor(65.4823, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.4239, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(65.9506, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(68.4477, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(68.2995, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.4798, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(62.5235, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(66.4436, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.3970, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(65.0582, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.3516, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.1730, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(66.0661, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(62.4402, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(69.2662, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(65.8207, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(61.9243, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(62.2766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(67.0943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(64.9398, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(62.2290, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(63.1724, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(63.5910, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(62.6376, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(64.5373, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(64.1863, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(64.9870, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(63.4608, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(64.5257, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(65.1446, device='cuda:0')
# epoch 9 seql 23
# tensor(66.3993, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(64.2448, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(62.6317, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(66.7234, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(63.9422, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.8993, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(62.1091, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(66.7002, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(67.2710, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(63.3032, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(62.2370, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(63.7619, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.1323, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(64.9531, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.3196, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(64.9984, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(69.0503, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(66.6343, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(65.9170, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(64.0120, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(64.7250, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(61.0586, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(64.8679, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(60.0312, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(62.9596, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(65.2949, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(64.3055, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(66.3163, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(59.6056, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(64.8922, device='cuda:0')
# epoch 10 seql 23
# tensor(62.6046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(62.7429, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(67.0695, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(65.3926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(65.3420, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(64.4089, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(65.1627, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(66.0990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(64.8210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(67.9641, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(67.9813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(65.6879, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(66.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(63.6038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(63.1880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(67.5489, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(63.2028, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(64.2776, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(66.5979, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(63.3728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# testloss tensor(62.7026, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(63.5762, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(64.8225, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(63.8825, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(63.5765, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(63.3083, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(63.5344, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(62.1906, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(63.3606, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(66.1618, device='cuda:0')
# epoch 11 seql 23
# tensor(68.9980, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(67.2505, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(63.5996, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(66.2421, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(65.3352, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(63.9526, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(62.5594, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(65.6137, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(66.3560, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(64.4605, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(69.4046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(66.1760, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(62.8744, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(67.3162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(66.3357, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(61.8136, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(61.5053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(64.3568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(64.1801, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(62.1108, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# testloss tensor(60.8771, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(63.5323, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(61.3483, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(65.3809, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(64.8481, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(66.0462, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(64.7714, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(64.9517, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(60.7728, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(66.0991, device='cuda:0')
# epoch 12 seql 23
# tensor(64.4395, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(63.4548, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(65.9091, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(65.2848, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(65.1644, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
#model = model.train()
#for seql in range(15,20,4):
seql = 23
for epoch in range (20):
  loss = None
  #model = model.train()
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
      #model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)

# %%
torch.save(model.state_dict(), "lastmodel.pth")

# %% [markdown]
# ran so well, interrupted

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('intermediate3.png',pred_dataset, model = model)

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
#for g in optimizer.param_groups:
#    g['lr'] = 0.0001

model = DecoderRNN()
model.load_state_dict(torch.load('/content/drive/MyDrive/modelsaves/lastmodel-f.pth'))
model = model.cuda()

optimizer = torch.optim.Adam(model.parameters(),lr = 0.000005, betas = (.9,.999))

# %%
for seql in range(25,38,2):
  #seql = 19
  for epoch in range (2):
    loss = None
    #model = model.train()

    for x,y in loader_train:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        optimizer.zero_grad()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        #writer.add_scalar("Loss/train", loss, epoch)
        
        loss.backward()
        optimizer.step()
      #print(y[:,0,:2])
      print('epoch',epoch,'seql',seql)
      print('train loss', loss)
    
    with torch.no_grad():
      #model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
      
      torch.save(model.state_dict(), "lastmodelsafe.pth")

# %%
torch.save(model.state_dict(), "lastmodel.pth")

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('intermediate4.png',pred_dataset, model = model)

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
#for g in optimizer.param_groups:
#    g['lr'] = 0.0001

#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
#for g in optimizer.param_groups:
#    g['lr'] = 0.0001

model = DecoderRNN()
model.load_state_dict(torch.load('/content/drive/MyDrive/modelsaves/lastmodel-f-p100.pth'))
model = model.cuda()

optimizer = torch.optim.Adam(model.parameters(),lr = 0.000005, betas = (.9,.999))

# %%
#for seql in range(15,20,4):
seql = 38
for epoch in range (120):
  #model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      #writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    #model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
    
    torch.save(model.state_dict(), "lastmodelsafe.pth")

# %%
torch.save(model.state_dict(), "lastmodel-f-p100.pth")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
writer.flush()
writer.close()

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
#!nvidia-smi

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)

# %%
for name, param in model.named_parameters():
  print(name)

# %%
with torch.no_grad():
      #model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(38):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('testloss',loss)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#https://datascience.stackexchange.com/questions/64131/how-to-save-dynamic-files-from-colab-to-google-drive

# %%
# !cp -r *.pth /content/gdrive/MyDrive/modelsaves/
