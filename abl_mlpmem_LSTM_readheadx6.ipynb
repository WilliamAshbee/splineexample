# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/abl_mlpmem_LSTM_readheadx6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %%
#TODO:TEST A DIFFERENT TYPE OF WRITE HEAD (ADD A SECOND LTM MEMORY MODULE)
#TODO:TEST A DIFFERENT TYPE OF LOSS TO SMOOTH OUT THE BLURRY READ/WRITE.

# %% [markdown]
# https://r2rt.com/non-zero-initial-states-for-recurrent-neural-networks.html

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):

    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}

def plot_all_model( sample = None, label=None,fig=None,ax=None):
    X = label[:,0]
    Y = label[:,1]
    img = sample[:,:].detach().squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    predres = 1000

    s = [.001 for x in range(predres)]
    
    assert len(s) == predres
    c = ['red' for x in range(predres)]
    assert len(c) == predres
    ax.scatter(X.detach().cpu().numpy(),Y.detach().cpu().numpy(),s = s,c = c)


def getXYs(model=None,loader_disp = None):

    outputs = torch.zeros(100,1000,2).cuda()
    h0 = None
    c0 = None
    
    for samples,labels in loader_disp:
      for i in range(38):
        optimizer.zero_grad()
        if i == 0:
          out, h0, c0,o,output = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i)
          outputs[:,i*25:(i+1)*25,:] = out.detach()
        else:
          out, h0, c0,o,output = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i,o = o,output=output)
          outputs[:,i*25:(i+1)*25,:] = out.detach()

      return samples, outputs


          
        

def plot_all( sample = None, labels = None,fig = None,ax = None):
    img = sample[:,:].squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    X = labels[:,0]
    Y = labels[:,1]
    s = [.001 for x in range(numpoints)]
    c = ['red' for x in range(numpoints)]
    ax.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
    
class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,ddataset, model):
        #model.setBatchSize(batch_size = 1)
        fig = plt.figure()
          
        if model != None:
          #model = model.eval()
          loader_disp = data.DataLoader(
            ddataset, 
            batch_size=100,
            num_workers=2)
          samples, outputs = getXYs(model=model,loader_disp = loader_disp)
          for i in range(100):
            ax = fig.add_subplot(10,10,i+1)
            plot_all_model(samples[i,:,:],outputs[i,:,:],fig=fig,ax=ax)
            plt.axis('off')

        else:
          for i in range(100):
            sample, labels = dataset[i]
            ax = fig.add_subplot(10,10,i+1)
            plot_all(sample = sample,labels = labels,fig = fig, ax= ax)
            plt.axis('off')

        fig.savefig(title,dpi=450)
        plt.close(fig) #where f is the figure
        plt.clf()
        plt.cla()
        plt.close()#should free memory
        print('open file: ',title)

# %%
dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# open file:  donut.png

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 100
dataset = DonutDataset(length = 100*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([2000, 1]) torch.Size([2000, 1]) torch.Size([2000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
mini_batch = 100
test_dataset = DonutDataset(length = 1000)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1000, 1]) torch.Size([1000, 1]) torch.Size([1000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 25
        self.full_len = 1000
        self.longmem_len = int(self.full_len/self.seq_len)
        self.longtermMem = None
        self.longtermMemP = None
        self.lstm_cell = nn.LSTM(2+1024+3*self.hidden_size, self.hidden_size,self.num_layers)

        self.inject_image =  nn.Sequential(
            nn.Linear(2+2*1000+1024+9*self.hidden_size,self.hidden_size*2),
            nn.ReLU()
        )

        
        self.fc_out = nn.Sequential(
            nn.Linear(2+2+1024+self.hidden_size*12,10000),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(10000,2),
            nn.Sigmoid()
        )
        self.hi_1 = nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
        )
        self.hi_2 = nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
        )

        self.ci_1 = nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
        )
        self.ci_2 = nn.Sequential(
            nn.Linear(2+1024+4*self.hidden_size,self.hidden_size),
        )

        self.alpha_1 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.seq_len),
            nn.Softmax()
        )
        
        self.alpha_long1 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        
        self.alpha_long2 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        
        self.alpha_long3 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        self.alpha_long4 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        self.alpha_long5 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        self.alpha_long6 = nn.Sequential(
            nn.Linear(2+1024+3*self.hidden_size,self.longmem_len),
            nn.Softmax()
        )
        
        self.long_term_write = nn.Sequential(
            nn.Linear(self.hidden_size*(self.seq_len+1),self.hidden_size),
            nn.ReLU()
        )
        

        self.embs = None #= torch.empty((self.batch_size, 1000, self.hidden_size)).cuda()
        self.ltm_temp = None
        self.lt_reads = None
        self.num_rh = 6
        self.st_reads = None
        
    def forward(self, features, p0,h0 = None, c0= None, ind = 0, o = None,output = None):
        #print('a')
        assert features != None
        self.track +=1
        batch_size = features.size(0)
        

        
        
        if o == None:
          out = p0
          self.longtermMem = torch.zeros(batch_size,self.longmem_len,self.hidden_size).cuda()
          self.embs = torch.empty((batch_size, self.seq_len, self.hidden_size)).cuda()
          self.longtermMemP = torch.zeros(batch_size,1000,2).cuda()
          self.ltm_temp = torch.zeros(batch_size,self.hidden_size).cuda()
          self.lt_reads = torch.zeros(batch_size,self.num_rh,self.hidden_size).cuda()
          self.st_reads = torch.zeros(batch_size,self.hidden_size).cuda()
        else:

          #self.ltm_temp = self.long_term_write(torch.cat([torch.flatten(self.embs,start_dim=1),output.squeeze()],dim=1))
          #self.longtermMem[:, ind-1, :] = self.ltm_temp
        
          #self.embs = torch.empty((batch_size, self.seq_len, self.hidden_size)).cuda()
          
          out = o

        #print('c')
        outputs = torch.empty((batch_size, self.seq_len, 2)).cuda()
        
        #output = None
        #print('b')
        for t in range(self.seq_len):
        
            # for the first time step the input is the feature vector
            if output == None:
              output = torch.zeros(batch_size,self.hidden_size).cuda()
            if t == 0:##fix this!!!
              outesread1 = self.st_reads
              outesreadl1 = self.lt_reads[:,0,:]
              outesreadl2 = self.lt_reads[:,1,:]
              outesreadl3 = self.lt_reads[:,2,:]
              outesreadl4 = self.lt_reads[:,3,:]
              outesreadl5 = self.lt_reads[:,4,:]
              outesreadl6 = self.lt_reads[:,5,:]
            #print('a')  
            combin_lstm = torch.cat([out.squeeze(),torch.flatten(features,start_dim=1),torch.flatten(self.longtermMemP,start_dim=1),output.squeeze(),outesread1,outesreadl1,outesreadl2,outesreadl3,outesreadl4,outesreadl5,outesreadl6,self.ltm_temp],dim=1)
            combin_lstm = self.inject_image(combin_lstm)
            combin_lstm = torch.cat([out.squeeze(),torch.flatten(features,start_dim=1),output.squeeze(),combin_lstm],dim=1)
            """if h0 == None and c0 == None:
              combin_init = torch.cat([combin_lstm,torch.zeros(batch_size,self.hidden_size).cuda()],dim=1)
              h_0_1 = self.hi_1(combin_init)  
              h_0_2 = self.hi_2(combin_init)  
              c_0_1 = self.ci_1(combin_init)  
              c_0_2 = self.ci_2(combin_init)  
              
              h0 = torch.stack([h_0_1,h_0_2],dim = 0)
              c0 = torch.stack([c_0_1,c_0_2],dim = 0)
              
              hidden_state = h0
              cell_state = c0
            
            elif t==0:
              #combin_init = torch.cat([torch.flatten(features,start_dim=1),out,output.squeeze(),h0[0,:,:]],dim=1)
              combin_init = torch.cat([combin_lstm,h0[0,:,:]],dim=1)
              
              h_0_1 = self.hi_1(combin_init)  
              
              #combin_init = torch.cat([torch.flatten(features,start_dim=1),out,output.squeeze(),h0[1,:,:]],dim=1)
              combin_init = torch.cat([combin_lstm,h0[1,:,:]],dim=1)
              h_0_2 = self.hi_2(combin_init)  
              
              #combin_init = torch.cat([torch.flatten(features,start_dim=1),out,output.squeeze(),c0[0,:,:]],dim=1)
              combin_init = torch.cat([combin_lstm,c0[0,:,:]],dim=1)
              c_0_1 = self.ci_1(combin_init)  
              
              #combin_init = torch.cat([torch.flatten(features,start_dim=1),out,output.squeeze(),c0[1,:,:]],dim=1)
              combin_init = torch.cat([combin_lstm,c0[1,:,:]],dim=1)
              c_0_2 = self.ci_2(combin_init)
              
              h0 = torch.stack([h_0_1,h_0_2],dim = 0)
              c0 = torch.stack([c_0_1,c_0_2],dim = 0)
        

              hidden_state = h0
              cell_state = c0
              
            #print('b')

            #a1 = self.alpha_1(combin_lstm)
            #outesreada1 = self.embs.clone()*a1.unsqueeze(2)#clone
            #outesread1 = torch.sum(outesreada1,dim=1)
            
            
            output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))
            #print('c')
            
            self.embs[:, t, :] = output.squeeze().clone().detach()
            

            a1 = self.alpha_1(combin_lstm)
            outesreada1 = self.embs.clone()*a1.unsqueeze(2)#clone
            outesread1 = torch.sum(outesreada1,dim=1)
            self.st_reads = outesread1.detach()
            
            
            #print('d')
            al1 = self.alpha_long1(combin_lstm)
            outesreadal1 = self.longtermMem.detach()*al1.unsqueeze(2)#clone
            outesreadl1 = torch.sum(outesreadal1,dim=1)
            self.lt_reads[:,0,:] = outesreadl1.detach()
            
            al2 = self.alpha_long2(combin_lstm)
            outesreadal2 = self.longtermMem.detach()*al2.unsqueeze(2)#clone
            outesreadl2 = torch.sum(outesreadal2,dim=1)
            self.lt_reads[:,1,:] = outesreadl2.detach()
            
            al3 = self.alpha_long3(combin_lstm)
            outesreadal3 = self.longtermMem.detach()*al3.unsqueeze(2)#clone
            outesreadl3 = torch.sum(outesreadal3,dim=1)
            self.lt_reads[:,2,:] = outesreadl3.detach()
            
            al4 = self.alpha_long4(combin_lstm)
            outesreadal4 = self.longtermMem.detach()*al4.unsqueeze(2)#clone
            outesreadl4 = torch.sum(outesreadal4,dim=1)
            self.lt_reads[:,3,:] = outesreadl4.detach()
            
            al5 = self.alpha_long4(combin_lstm)
            outesreadal5 = self.longtermMem.detach()*al5.unsqueeze(2)#clone
            outesreadl5 = torch.sum(outesreadal5,dim=1)
            self.lt_reads[:,4,:] = outesreadl5.detach()
            
            al6 = self.alpha_long6(combin_lstm)
            outesreadal6 = self.longtermMem.detach()*al6.unsqueeze(2)#clone
            outesreadl6 = torch.sum(outesreadal6,dim=1)
            self.lt_reads[:,5,:] = outesreadl6.detach()
            
            #print('e')
            """
            combOut = torch.cat([combin_lstm, output.squeeze(),out,outesread1,outesreadl1,outesreadl2,outesreadl3,outesreadl4,outesreadl5,outesreadl6,self.ltm_temp],dim=1)#,outesread],dim=1)
            

            out = self.fc_out(combOut)
            out = out*32.0
            # build the output tensor
            outputs[:, t, :] = out
            self.longtermMemP[:,self.seq_len*ind+t,:] = out.detach()

        
            
        #self.embs = self.embs.detach().clone()
        return outputs, None, None, out.detach(),None#, captions

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
for seql in range(3,23,6):
  #seql = 19
  for epoch in range (2):
    loss = None
    #model = model.train()

    for x,y in loader_train:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        optimizer.zero_grad()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        #writer.add_scalar("Loss/train", loss, epoch)
        
        loss.backward()
        optimizer.step()
      #print(y[:,0,:2])
      print('epoch',epoch,'seql',seql)
      print('train loss', loss)
    
    with torch.no_grad():
      #model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# epoch 0 seql 3
# train loss tensor(47.0952, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(20.0430, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(7.5650, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.3060, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(7.1757, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(8.5308, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(9.8558, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(9.8542, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(7.7845, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(6.7441, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.9967, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.2236, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.0693, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.3536, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.4213, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.5463, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.4542, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.3851, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.4421, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.4877, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# testloss tensor(3.1884, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(3.1755, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(3.0464, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(3.3533, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(3.3744, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(3.1687, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(3.3010, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(3.1496, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(2.9962, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(3.3021, device='cuda:0')
# epoch 1 seql 3
# train loss tensor(3.6119, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.5003, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0019, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.3282, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(2.9387, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.1731, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0773, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(2.8545, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(2.9288, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(2.9692, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(2.9851, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(2.8123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(2.8245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0236, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(2.9733, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.1879, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# testloss tensor(2.6600, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.6468, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.8919, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.8776, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.9469, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(3.0025, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.7173, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.9568, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.7655, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(2.8479, device='cuda:0')
# epoch 0 seql 9
# train loss tensor(25.9540, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(4.7167, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(13.3268, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(4.8881, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(4.9107, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.7812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.8768, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.5452, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.5820, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.3424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.5145, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.3237, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.3422, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.2603, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.4257, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.2872, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.0144, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.0538, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.0576, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# train loss tensor(3.1044, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 9
# testloss tensor(3.0851, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(2.8063, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(3.0552, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(2.9387, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(3.1416, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(3.0132, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(3.0082, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(3.0196, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(3.0611, device='cuda:0')
# epoch 0 seql 9
# testloss tensor(3.0029, device='cuda:0')
# epoch 1 seql 9
# train loss tensor(2.8483, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.8963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(3.0136, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.9412, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.8653, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.8978, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.7094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.6889, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.7495, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.8327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.7721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.9867, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.8781, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.7674, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.5701, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.6923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.6911, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.7178, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.6694, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# train loss tensor(2.6510, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 9
# testloss tensor(2.5208, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.6296, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.3893, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.4602, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.5786, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.5197, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.6631, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.5021, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.6694, device='cuda:0')
# epoch 1 seql 9
# testloss tensor(2.5592, device='cuda:0')
# epoch 0 seql 15
# train loss tensor(3.7002, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(34.1568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(16.3251, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(23.0984, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(4.4850, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.8342, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.7249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.7112, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.5245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.6652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.3942, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.5336, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.3790, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.3031, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.3113, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.3897, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.2724, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.3993, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.1613, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.2240, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# testloss tensor(2.1302, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.0786, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.3434, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.3598, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.1255, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.1899, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.1046, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.2522, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.1450, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(2.1757, device='cuda:0')
# epoch 1 seql 15
# train loss tensor(2.1801, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.1409, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.1056, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.1474, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.1954, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.8855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.1156, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.0520, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.1989, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.0121, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.8150, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.9539, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.9533, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.8323, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.9026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.9005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.0023, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.1808, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.9158, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(2.0414, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# testloss tensor(1.9908, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.9597, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(2.0526, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.7965, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.8945, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.8980, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(2.0112, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.8516, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.7958, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.8343, device='cuda:0')
# epoch 0 seql 21
# train loss tensor(2.4172, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(4.2966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(7.5820, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(2.8711, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(4.5369, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(2.7824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(14.5405, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(3.9505, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(3.6933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(2.2604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(2.3837, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(2.0119, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(1.9455, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(2.0161, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(2.0271, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(1.8310, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(1.9818, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(1.8061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(1.8052, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# train loss tensor(1.6139, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 21
# testloss tensor(1.6657, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.9503, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.6273, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.6988, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.7520, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.5806, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.6694, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.5238, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.6877, device='cuda:0')
# epoch 0 seql 21
# testloss tensor(1.9158, device='cuda:0')
# epoch 1 seql 21
# train loss tensor(1.8657, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.7526, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5555, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.7953, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.4934, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5204, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.6678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.7254, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.6037, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.6393, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5688, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5972, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5819, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.4699, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.6592, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5178, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.3568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# train loss tensor(1.5048, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 21
# testloss tensor(1.5080, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.5927, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.5289, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.5123, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.3695, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.5500, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.6855, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.4047, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.3769, device='cuda:0')
# epoch 1 seql 21
# testloss tensor(1.5329, device='cuda:0')

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

#for g in optimizer.param_groups:
#    g['lr'] = 0.0001

torch.save(model.state_dict(), "lastmodel.pth")

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('intermediate1.png',pred_dataset, model = model)
# Out:
# open file:  intermediate1.png

# %%
#for seql in range(15,20,4):
seql = 23
for epoch in range (10):
  #model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    #model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
# Out:
# epoch 0 seql 23
# tensor(4.3638, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.6064, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.6248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.2925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.7150, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.6765, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.3128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.3312, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.7409, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.1285, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.6589, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.2034, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.7725, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.6925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.7931, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.5741, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.8772, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.7111, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.5664, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.4389, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(1.8500, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.8735, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.8640, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.7964, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.6640, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.8103, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.6486, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.8673, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.9227, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.7037, device='cuda:0')
# epoch 1 seql 23
# tensor(1.5304, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5939, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5449, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5769, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.7313, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.6223, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.4284, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5558, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.4441, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.8750, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5639, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.4278, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5083, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5086, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5150, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.6435, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.2684, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.5241, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(1.5692, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.7115, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.4881, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.4358, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.2900, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.4308, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3783, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.4093, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.4959, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.4693, device='cuda:0')
# epoch 2 seql 23
# tensor(1.4739, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.5250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.3925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.3776, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.6088, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.5061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.3693, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.6471, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(2.0042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.8459, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.5163, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.8607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.7682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.6721, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(2.3741, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.9320, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(2.1832, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.3685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.3028, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.7419, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(1.5575, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.5722, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.7537, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.4535, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.5734, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.6145, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.5367, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.5003, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.6863, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.6356, device='cuda:0')
# epoch 3 seql 23
# tensor(1.3811, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2708, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.5749, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.5286, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.5589, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.3200, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2575, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.3977, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.3234, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2724, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2655, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2127, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2753, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.3552, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.1991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.4722, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.3170, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.2316, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.3565, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.3226, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(1.4875, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.4457, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.4870, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.3892, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.5204, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.3310, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.3109, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.5180, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.4258, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.6276, device='cuda:0')
# epoch 4 seql 23
# tensor(1.3114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.3574, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.3978, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.2420, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.5742, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.4310, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.5242, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.4786, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.4182, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.6332, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.3770, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.6135, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.6924, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.3424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.6563, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.3551, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.2065, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.7022, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.1919, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.2835, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(1.5458, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.3460, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.4166, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.3710, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.6506, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.4020, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.3356, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.2638, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.3188, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.4073, device='cuda:0')
# epoch 5 seql 23
# tensor(1.5440, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.5839, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.3978, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.3430, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.3349, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.3719, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1936, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.2608, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.2311, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1827, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1874, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.2553, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.3642, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1501, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1785, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.0119, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1095, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.1041, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.0921, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(1.3195, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.4006, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.5345, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.4788, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.6513, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.1589, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.2569, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.2909, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.4404, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.3280, device='cuda:0')
# epoch 6 seql 23
# tensor(1.0789, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.1799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.1376, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.0657, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.2950, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.3003, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.1169, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.5018, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.2002, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.4907, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.1029, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.3526, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.1416, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.7995, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.1193, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.0796, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.6589, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.3358, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.2480, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.2905, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(1.1541, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.1936, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.2570, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.2882, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.3942, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.0996, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.0634, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.3586, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.2135, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.3151, device='cuda:0')
# epoch 7 seql 23
# tensor(1.4686, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.4516, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.2438, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.3810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.4948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.1822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.1475, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.1985, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.0608, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9797, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.1393, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.0533, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.0634, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.1046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.0309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.0017, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.9645, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.1117, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.8855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(1.0282, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.1346, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.1552, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.0883, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.0042, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.0606, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.0735, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.0509, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.9477, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.9638, device='cuda:0')
# epoch 8 seql 23
# tensor(0.9699, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9337, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.9709, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.0351, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.0390, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.1128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.4568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.1468, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.0735, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.2637, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.2338, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.7575, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.4478, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.2362, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.7364, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.2629, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.7318, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.6094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.1648, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.4679, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(0.9977, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.9868, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.1028, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.0776, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.0937, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.0515, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.1179, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.9321, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.0969, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.0901, device='cuda:0')
# epoch 9 seql 23
# tensor(1.1867, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9703, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.0390, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9879, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.2474, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.0468, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.0281, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.1260, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.0045, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.0292, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.2054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9829, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.8725, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.0239, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.0955, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9704, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9235, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9413, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.0009, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.9642, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(0.9791, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.9490, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.9684, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.0539, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.0007, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.9546, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.1251, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.0933, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.1382, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.0994, device='cuda:0')

# %%
torch.save(model.state_dict(), "lastmodel.pth")

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('intermediate2.png',pred_dataset, model = model)
# Out:
# open file:  intermediate2.png

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
for g in optimizer.param_groups:
    g['lr'] = 0.00001

# %%
#for seql in range(15,20,4):
seql = 23
for epoch in range (200):
  #model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    #model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 116 seql 23
# testloss tensor(0.5626, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.5951, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.5078, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.5898, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.6193, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.5678, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.5713, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.7668, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.5926, device='cuda:0')
# epoch 116 seql 23
# testloss tensor(0.6442, device='cuda:0')
# epoch 117 seql 23
# tensor(0.2895, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.2748, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1395, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1231, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1063, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1113, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1011, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1105, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1227, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1227, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1251, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1341, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1666, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1815, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.2593, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1388, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1318, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1202, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# tensor(0.1182, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 117 seql 23
# testloss tensor(0.1975, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1650, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1652, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1771, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1581, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1453, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1707, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1995, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1680, device='cuda:0')
# epoch 117 seql 23
# testloss tensor(0.1840, device='cuda:0')
# epoch 118 seql 23
# tensor(0.1229, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1633, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1734, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.2294, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.2120, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.2637, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.2065, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1858, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1500, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1322, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1540, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1438, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1706, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1908, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1929, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.2358, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1670, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1924, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# tensor(0.1740, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 118 seql 23
# testloss tensor(0.2402, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.2324, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.2706, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.2718, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.3433, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.2448, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.2483, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.2898, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.2579, device='cuda:0')
# epoch 118 seql 23
# testloss tensor(0.2831, device='cuda:0')
# epoch 119 seql 23
# tensor(0.1728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1404, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1380, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1189, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1161, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1144, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1087, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.0994, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1116, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1318, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1406, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1741, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1606, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1944, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1202, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1141, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1114, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# tensor(0.1057, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 119 seql 23
# testloss tensor(0.1829, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.1585, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.1622, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.1600, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.1865, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.1657, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.1577, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.1860, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.1793, device='cuda:0')
# epoch 119 seql 23
# testloss tensor(0.2021, device='cuda:0')
# epoch 120 seql 23
# tensor(0.0987, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1071, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1101, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1353, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1601, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1881, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.2422, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.2659, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.3184, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.3181, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1905, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1773, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1503, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1191, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1177, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1335, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.1441, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# tensor(0.2084, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 120 seql 23
# testloss tensor(0.2552, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.2683, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.2902, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.2691, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.2658, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.3416, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.2647, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.3023, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.2738, device='cuda:0')
# epoch 120 seql 23
# testloss tensor(0.2841, device='cuda:0')
# epoch 121 seql 23
# tensor(0.2559, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.4479, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.3700, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.3988, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1783, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1146, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1090, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1062, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.0989, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1051, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1071, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1287, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1417, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1491, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1579, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1453, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# tensor(0.1385, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 121 seql 23
# testloss tensor(0.1957, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.2158, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.2492, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.2189, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.2096, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.2071, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.1798, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.2087, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.2313, device='cuda:0')
# epoch 121 seql 23
# testloss tensor(0.1857, device='cuda:0')
# epoch 122 seql 23
# tensor(0.1118, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1019, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1028, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1188, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1211, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1410, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1765, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.2583, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.2536, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.3187, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.2671, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1329, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1599, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.2336, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.2346, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.2254, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# tensor(0.1392, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 122 seql 23
# testloss tensor(0.2215, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2684, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2651, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2680, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2308, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2544, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2232, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2169, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2675, device='cuda:0')
# epoch 122 seql 23
# testloss tensor(0.2171, device='cuda:0')
# epoch 123 seql 23
# tensor(0.1043, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1167, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1085, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1140, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1277, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1438, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1213, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.0988, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1126, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1263, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1609, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.2036, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.2373, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.2065, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.2462, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1930, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# tensor(0.1829, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 123 seql 23
# testloss tensor(0.2546, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.2952, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.2476, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.2686, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.2470, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.2227, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.2589, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.2748, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.2736, device='cuda:0')
# epoch 123 seql 23
# testloss tensor(0.3096, device='cuda:0')
# epoch 124 seql 23
# tensor(0.1390, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1222, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1350, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1373, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1274, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1183, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1159, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.2030, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1346, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1157, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1128, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1132, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1001, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.0984, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# tensor(0.1178, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 124 seql 23
# testloss tensor(0.2155, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.1811, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.1892, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.1744, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.1952, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.2329, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.2074, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.1661, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.2067, device='cuda:0')
# epoch 124 seql 23
# testloss tensor(0.1888, device='cuda:0')
# epoch 125 seql 23
# tensor(0.1674, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.2434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1732, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1653, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1677, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1635, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1523, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1113, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1252, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1322, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.2070, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.2893, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.3982, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.3623, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.2508, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1521, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# tensor(0.1564, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 125 seql 23
# testloss tensor(0.1649, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.2078, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.1878, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.1600, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.1888, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.1543, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.2237, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.1901, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.1966, device='cuda:0')
# epoch 125 seql 23
# testloss tensor(0.1666, device='cuda:0')
# epoch 126 seql 23
# tensor(0.1291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1235, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1338, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1161, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1050, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1116, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1119, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1180, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1299, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1267, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1251, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1541, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1586, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1409, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1231, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1163, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1035, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# tensor(0.1015, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 126 seql 23
# testloss tensor(0.1482, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1653, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1980, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1679, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1647, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1794, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1568, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1805, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1454, device='cuda:0')
# epoch 126 seql 23
# testloss tensor(0.1728, device='cuda:0')
# epoch 127 seql 23
# tensor(0.1068, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1043, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1080, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1270, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1304, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1520, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1870, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.2058, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.2103, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1899, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1918, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.2205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.2444, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1899, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1643, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1284, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1138, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# tensor(0.1422, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 127 seql 23
# testloss tensor(0.2112, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.1893, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.2356, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.1896, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.1750, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.1719, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.2179, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.1620, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.1864, device='cuda:0')
# epoch 127 seql 23
# testloss tensor(0.1860, device='cuda:0')
# epoch 128 seql 23
# tensor(0.1490, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1662, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1493, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1743, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1706, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1976, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1903, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1841, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1840, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1332, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1105, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1218, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1122, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1208, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1398, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1782, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.1768, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# tensor(0.2028, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 128 seql 23
# testloss tensor(0.3197, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.3138, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.3636, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.3233, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.3760, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.3444, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.3786, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.3749, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.3832, device='cuda:0')
# epoch 128 seql 23
# testloss tensor(0.4164, device='cuda:0')
# epoch 129 seql 23
# tensor(0.1327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1550, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1429, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1539, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1244, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1148, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1094, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1204, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1634, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.2233, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.2778, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.2686, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.2303, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1760, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1723, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1641, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# tensor(0.1390, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 129 seql 23
# testloss tensor(0.1712, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.1870, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.1733, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.1746, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.1679, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.1531, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.1705, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.1762, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.1798, device='cuda:0')
# epoch 129 seql 23
# testloss tensor(0.2038, device='cuda:0')
# epoch 130 seql 23
# tensor(0.1315, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1308, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1371, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1231, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1177, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1181, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1226, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1277, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1519, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1407, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1773, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1509, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1275, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1256, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1235, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1100, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# tensor(0.1104, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 130 seql 23
# testloss tensor(0.1583, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.1822, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.1962, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.1784, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.1713, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.1706, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.2098, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.2231, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.1826, device='cuda:0')
# epoch 130 seql 23
# testloss tensor(0.1956, device='cuda:0')
# epoch 131 seql 23
# tensor(0.1084, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1234, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1362, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1952, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.2732, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.3308, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.2320, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.2921, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.3245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1504, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1472, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1221, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1197, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.0980, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.0988, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.0977, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.0964, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.0973, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# tensor(0.1038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 131 seql 23
# testloss tensor(0.1508, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.1779, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.1626, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.1799, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.1440, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.1769, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.1720, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.1637, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.1935, device='cuda:0')
# epoch 131 seql 23
# testloss tensor(0.2006, device='cuda:0')
# epoch 132 seql 23
# tensor(0.1053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1050, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1195, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1172, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1200, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1088, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1211, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1068, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.0971, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1019, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.0965, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1043, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1261, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.1919, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.3098, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.2816, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.3807, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.3308, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# tensor(0.2785, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 132 seql 23
# testloss tensor(0.3098, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.3316, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.3683, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.2362, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.2823, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.2912, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.2612, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.3143, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.2656, device='cuda:0')
# epoch 132 seql 23
# testloss tensor(0.2911, device='cuda:0')
# epoch 133 seql 23
# tensor(0.1377, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1178, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1746, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1449, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.2088, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.2415, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.2142, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1258, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1152, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1049, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1224, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1522, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1654, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1700, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1355, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1182, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.1057, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# tensor(0.0956, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 133 seql 23
# testloss tensor(0.1535, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1471, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1482, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1661, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1452, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1734, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1379, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1747, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1924, device='cuda:0')
# epoch 133 seql 23
# testloss tensor(0.1883, device='cuda:0')
# epoch 134 seql 23
# tensor(0.1065, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.0923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.0950, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.0926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.0935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.0943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.0962, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.0979, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1059, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1152, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1297, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1451, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1866, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.2098, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.2522, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# tensor(0.1979, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 134 seql 23
# testloss tensor(0.2176, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.1984, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.2036, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.1961, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.2188, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.1809, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.1778, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.1847, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.2121, device='cuda:0')
# epoch 134 seql 23
# testloss tensor(0.2239, device='cuda:0')
# epoch 135 seql 23
# tensor(0.2387, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1358, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1470, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1338, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1216, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1161, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1168, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1101, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1151, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1339, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1363, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.2483, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.2975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.3130, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.2682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.2170, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# tensor(0.1820, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 135 seql 23
# testloss tensor(0.2303, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.2156, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.2402, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.1798, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.2083, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.2530, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.2041, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.2513, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.1992, device='cuda:0')
# epoch 135 seql 23
# testloss tensor(0.2018, device='cuda:0')
# epoch 136 seql 23
# tensor(0.1442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1417, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1068, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1011, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.0999, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1001, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.0881, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1010, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.0956, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1064, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.0945, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.0930, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1001, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.0971, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1041, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.1519, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# tensor(0.2400, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 136 seql 23
# testloss tensor(0.3307, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.3646, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.3473, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.2752, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.2840, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.3329, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.2718, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.3195, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.3212, device='cuda:0')
# epoch 136 seql 23
# testloss tensor(0.3343, device='cuda:0')
# epoch 137 seql 23
# tensor(0.1977, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.2465, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1717, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1472, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1239, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1362, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1254, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1264, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1712, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.2156, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.2279, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.2024, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.2071, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.2286, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1521, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.1207, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# tensor(0.0956, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 137 seql 23
# testloss tensor(0.1814, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.1576, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.1974, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.1501, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.2096, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.1795, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.1822, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.1923, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.1424, device='cuda:0')
# epoch 137 seql 23
# testloss tensor(0.2034, device='cuda:0')
# epoch 138 seql 23
# tensor(0.1090, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1140, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1598, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1189, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1208, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1032, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1144, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1147, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1091, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.0951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.0985, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1074, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1047, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1029, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1109, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1111, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1368, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# tensor(0.1735, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 138 seql 23
# testloss tensor(0.2124, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.1898, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.1818, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.1700, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.1865, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.2537, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.1898, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.1766, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.1905, device='cuda:0')
# epoch 138 seql 23
# testloss tensor(0.2090, device='cuda:0')
# epoch 139 seql 23
# tensor(0.2642, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.2884, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.4983, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.3718, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.2661, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1740, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1536, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1374, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1707, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1825, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1590, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1037, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.0997, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1009, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.0971, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.1016, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# tensor(0.0966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 139 seql 23
# ...
# epoch 192 seql 23
# tensor(0.0896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.0870, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.0855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.0877, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.1011, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.0844, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.0941, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.0925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.0889, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# tensor(0.0938, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 192 seql 23
# testloss tensor(0.1864, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1967, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1614, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1340, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1362, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1672, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1150, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1444, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1585, device='cuda:0')
# epoch 192 seql 23
# testloss tensor(0.1536, device='cuda:0')
# epoch 193 seql 23
# tensor(0.0819, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0853, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0840, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0842, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0881, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0904, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0874, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0882, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0830, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0826, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0831, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0866, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0883, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0953, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.1026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# tensor(0.0952, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 193 seql 23
# testloss tensor(0.1375, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.2047, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.1640, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.1652, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.1451, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.1292, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.1808, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.1228, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.1355, device='cuda:0')
# epoch 193 seql 23
# testloss tensor(0.1592, device='cuda:0')
# epoch 194 seql 23
# tensor(0.1023, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1141, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1215, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1441, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1311, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1076, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1067, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.0922, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.0923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.0951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1186, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1448, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1487, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1508, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1294, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# tensor(0.1000, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 194 seql 23
# testloss tensor(0.1641, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1680, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1530, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1355, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1721, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1750, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1789, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1659, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1461, device='cuda:0')
# epoch 194 seql 23
# testloss tensor(0.1819, device='cuda:0')
# epoch 195 seql 23
# tensor(0.0860, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0882, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.1003, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.1047, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.1135, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.1051, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0908, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0889, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0910, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0850, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0892, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0831, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0818, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0795, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0851, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0777, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.0914, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.1005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# tensor(0.1255, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 195 seql 23
# testloss tensor(0.2299, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1675, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1748, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1672, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1753, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1718, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1988, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1844, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1730, device='cuda:0')
# epoch 195 seql 23
# testloss tensor(0.1706, device='cuda:0')
# epoch 196 seql 23
# tensor(0.1704, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1733, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.0944, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.0860, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.0847, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.0936, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1028, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1197, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1502, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.2079, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.2596, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.2291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.2608, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.2389, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1869, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1275, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1080, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1189, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# tensor(0.1188, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 196 seql 23
# testloss tensor(0.1737, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.1468, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.1714, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.1698, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.2184, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.2201, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.1947, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.2198, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.1899, device='cuda:0')
# epoch 196 seql 23
# testloss tensor(0.2016, device='cuda:0')
# epoch 197 seql 23
# tensor(0.0961, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0818, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0802, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0818, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0789, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0881, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.1079, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.1214, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.1271, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.1471, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.1233, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.1053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0877, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0818, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0873, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0845, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# tensor(0.0864, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 197 seql 23
# testloss tensor(0.1780, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1596, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1317, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1673, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1545, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1394, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1628, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1332, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1846, device='cuda:0')
# epoch 197 seql 23
# testloss tensor(0.1470, device='cuda:0')
# epoch 198 seql 23
# tensor(0.0955, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1145, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1030, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1180, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1372, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1333, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1135, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.0933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.0863, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.0887, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.0906, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.0904, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1192, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1627, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.2330, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.2818, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.2680, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.2268, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# tensor(0.1650, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 198 seql 23
# testloss tensor(0.2003, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.2232, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.2643, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.2313, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.2364, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.2225, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.2877, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.1823, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.2123, device='cuda:0')
# epoch 198 seql 23
# testloss tensor(0.2370, device='cuda:0')
# epoch 199 seql 23
# tensor(0.1270, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0956, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0826, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0846, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0823, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0971, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1068, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1749, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1511, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1222, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1217, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0838, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0835, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.0952, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# tensor(0.1162, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 199 seql 23
# testloss tensor(0.1680, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1535, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1215, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1576, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1630, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1419, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1964, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1440, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1816, device='cuda:0')
# epoch 199 seql 23
# testloss tensor(0.1972, device='cuda:0')

# %%
#model = model.train()
#for seql in range(15,20,4):
seql = 23
for epoch in range (20):
  loss = None
  #model = model.train()
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
      #model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# epoch 0 seql 23
# tensor(0.1486, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.1999, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.2127, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.2465, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.1771, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.1405, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0941, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0906, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0907, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0941, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.1058, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.1088, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.1014, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0780, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0817, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0903, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0893, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0962, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(0.0833, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(0.1526, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1590, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1955, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1689, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1605, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1837, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1593, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1698, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1479, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(0.1763, device='cuda:0')
# epoch 1 seql 23
# tensor(0.0789, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.0866, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1055, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1065, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1484, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1724, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1781, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1608, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1284, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.0955, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.0978, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.0896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1438, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1418, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1652, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1547, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(0.1970, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(0.2405, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.2252, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.2232, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.2284, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.2588, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.2402, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.1961, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.2550, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.2195, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(0.2586, device='cuda:0')
# epoch 2 seql 23
# tensor(0.1454, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.1299, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0944, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0904, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0838, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0830, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0879, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0919, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0892, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0952, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0820, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0808, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0836, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0806, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.0951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.1098, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.1513, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(0.1631, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(0.2312, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.2283, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.1757, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.2156, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.1810, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.2063, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.2250, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.1971, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.2013, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(0.2446, device='cuda:0')
# epoch 3 seql 23
# tensor(0.2073, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.1078, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0930, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0851, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0899, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0929, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0801, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0893, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0939, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.1363, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.1886, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.3360, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.3299, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.3944, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.1685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.1267, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(0.0923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(0.1509, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1647, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1753, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1594, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1407, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1783, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1592, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1456, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1265, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(0.1440, device='cuda:0')
# epoch 4 seql 23
# tensor(0.0912, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0953, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0906, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0937, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0981, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0941, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0884, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0926, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.1075, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0972, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.1022, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0877, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0891, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.0929, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.1219, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(0.1213, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(0.1302, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1600, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1569, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1581, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1319, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1537, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1572, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1498, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1467, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(0.1554, device='cuda:0')
# epoch 5 seql 23
# tensor(0.2009, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.2430, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.2455, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.1572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.1405, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.1154, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0914, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0835, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0818, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0777, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0809, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0836, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.0880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.1005, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(0.1137, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(0.1483, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1606, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1454, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1663, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1651, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1564, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1806, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1832, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1502, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(0.1444, device='cuda:0')
# epoch 6 seql 23
# tensor(0.1308, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1319, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1613, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1314, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1466, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1491, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1152, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.0989, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.0977, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1015, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.0888, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1084, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1303, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1609, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1965, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.2220, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1840, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(0.1321, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(0.1787, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.2430, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.1972, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.1673, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.1692, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.1748, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.1930, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.2090, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.2084, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(0.1992, device='cuda:0')
# epoch 7 seql 23
# tensor(0.1030, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0869, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0901, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1037, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1312, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1565, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1346, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1719, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1741, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1183, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0909, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0960, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0885, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0858, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0934, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.0925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(0.1291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(0.1508, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1605, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1893, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1552, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1896, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1714, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1762, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1727, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1673, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(0.1628, device='cuda:0')
# epoch 8 seql 23
# tensor(0.1469, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.1868, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.1588, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.1867, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.1692, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.1451, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.1039, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0846, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0939, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0903, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0853, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0776, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0800, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0811, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0865, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0853, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(0.0997, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(0.1676, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1467, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1587, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1532, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1570, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1346, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1665, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1737, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1509, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(0.1512, device='cuda:0')
# epoch 9 seql 23
# tensor(0.1054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.1350, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.1452, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.1467, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.1037, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0922, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0871, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0847, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0781, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0751, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0753, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0833, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0872, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.0894, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.1275, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.1859, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.2196, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(0.1959, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(0.1947, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2815, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2409, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2531, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2297, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2721, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2287, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2282, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2384, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(0.2227, device='cuda:0')
# epoch 10 seql 23
# tensor(0.1892, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1666, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1576, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1564, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1741, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1023, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1133, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1577, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.2007, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1770, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1347, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.1137, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.0831, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.0830, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.0738, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.0769, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.0829, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.0858, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.0796, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(0.0876, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# testloss tensor(0.1190, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1577, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1528, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1821, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1469, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1541, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1692, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1466, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1341, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(0.1302, device='cuda:0')
# epoch 11 seql 23
# tensor(0.0990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.1109, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.1558, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.1737, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.2491, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.2461, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.1596, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0904, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0970, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.1068, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.1113, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0917, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0835, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0850, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0752, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0782, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0792, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.0918, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(0.1052, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# testloss tensor(0.1690, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.2084, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.1555, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.1651, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.1561, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.1826, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.1868, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.1600, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.1734, device='cuda:0')
# epoch 11 seql 23
# testloss tensor(0.1787, device='cuda:0')
# epoch 12 seql 23
# tensor(0.1147, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.1083, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0996, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0901, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0794, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0908, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0946, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.1089, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0946, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0844, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0744, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0783, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0759, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0860, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0819, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0795, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# tensor(0.0766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 12 seql 23
# testloss tensor(0.1721, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1458, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1882, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1402, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1528, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1340, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1631, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1315, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1265, device='cuda:0')
# epoch 12 seql 23
# testloss tensor(0.1408, device='cuda:0')
# epoch 13 seql 23
# tensor(0.0723, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.0794, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.1091, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.1933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.3163, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.3972, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.3185, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.1982, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.1277, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.0962, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.0989, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.0948, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.0925, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.0938, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.0874, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.0976, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.1274, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.1569, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.1612, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# tensor(0.1636, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 13 seql 23
# testloss tensor(0.2559, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2499, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2044, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2628, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2333, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2030, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2412, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2447, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2317, device='cuda:0')
# epoch 13 seql 23
# testloss tensor(0.2093, device='cuda:0')
# epoch 14 seql 23
# tensor(0.1399, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.1270, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.1103, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.1058, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0872, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0784, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0832, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0770, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0788, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0741, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0803, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0798, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0852, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0836, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.0965, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.1129, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# tensor(0.1631, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 14 seql 23
# testloss tensor(0.1867, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.1863, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.1945, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.2140, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.1883, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.1677, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.1950, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.1747, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.1955, device='cuda:0')
# epoch 14 seql 23
# testloss tensor(0.2035, device='cuda:0')
# epoch 15 seql 23
# tensor(0.2384, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.2649, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.2307, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1133, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1025, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1054, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1302, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1631, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1776, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.1118, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.0988, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.0938, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.0923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.0935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.0966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.0908, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.0985, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# tensor(0.0867, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 15 seql 23
# testloss tensor(0.1374, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.1416, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.1484, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.1339, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.1359, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.1608, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.2063, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.1461, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.1415, device='cuda:0')
# epoch 15 seql 23
# testloss tensor(0.1309, device='cuda:0')
# epoch 16 seql 23
# tensor(0.0869, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1036, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1039, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1138, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1127, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1194, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1637, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1081, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.0849, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.0891, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1089, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1286, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1532, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1643, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1228, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1013, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.0927, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.1009, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# tensor(0.0963, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 16 seql 23
# testloss tensor(0.1430, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1695, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1320, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1584, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1764, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1907, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1564, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1692, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1480, device='cuda:0')
# epoch 16 seql 23
# testloss tensor(0.1525, device='cuda:0')
# epoch 17 seql 23
# tensor(0.0935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.0956, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.0901, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.0822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.0778, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.0814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.0835, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.0840, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.0862, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1019, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1137, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1262, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1638, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1733, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1899, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1277, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1691, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.2086, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1578, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# tensor(0.1771, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 17 seql 23
# testloss tensor(0.2442, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.2002, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.1919, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.2043, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.2697, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.2334, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.2199, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.2114, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.2252, device='cuda:0')
# epoch 17 seql 23
# testloss tensor(0.1959, device='cuda:0')
# epoch 18 seql 23
# tensor(0.1532, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.1560, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.1238, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.1061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0938, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0872, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0843, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0786, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0794, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0814, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0911, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.1058, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.1091, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.1171, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0900, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0746, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0781, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0747, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# tensor(0.0833, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 18 seql 23
# testloss tensor(0.1569, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1436, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1552, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1626, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1937, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1593, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1389, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1310, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1308, device='cuda:0')
# epoch 18 seql 23
# testloss tensor(0.1368, device='cuda:0')
# epoch 19 seql 23
# tensor(0.0829, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.0930, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1117, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1414, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1464, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1655, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1535, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1413, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.0813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.0809, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.0867, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1061, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1261, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1236, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1169, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1369, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# tensor(0.1525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 19 seql 23
# testloss tensor(0.1767, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.2047, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.1539, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.1992, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.1763, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.2087, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.1515, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.1696, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.1769, device='cuda:0')
# epoch 19 seql 23
# testloss tensor(0.1647, device='cuda:0')

# %%
torch.save(model.state_dict(), "lastmodel.pth")

# %% [markdown]
# ran so well, interrupted

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('intermediate3.png',pred_dataset, model = model)
# Out:
# open file:  intermediate3.png

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
#for g in optimizer.param_groups:
#    g['lr'] = 0.0001

model = DecoderRNN()
model.load_state_dict(torch.load('/content/drive/MyDrive/modelsaves/lastmodel-f.pth'))
model = model.cuda()

optimizer = torch.optim.Adam(model.parameters(),lr = 0.000005, betas = (.9,.999))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-90e2d352e846> in <module>()
#       4
#       5 model = DecoderRNN()
# ----> 6 model.load_state_dict(torch.load('/content/drive/MyDrive/modelsaves/lastmodel-f.pth'))
#       7 model = model.cuda()
#       8
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     577         pickle_load_args['encoding'] = 'utf-8'
#     578
# --> 579     with _open_file_like(f, 'rb') as opened_file:
#     580         if _is_zipfile(opened_file):
#     581             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/modelsaves/lastmodel-f.pth'

# %%
for seql in range(25,38,2):
  #seql = 19
  for epoch in range (2):
    loss = None
    #model = model.train()

    for x,y in loader_train:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        optimizer.zero_grad()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        #writer.add_scalar("Loss/train", loss, epoch)
        
        loss.backward()
        optimizer.step()
      #print(y[:,0,:2])
      print('epoch',epoch,'seql',seql)
      print('train loss', loss)
    
    with torch.no_grad():
      #model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
      
      torch.save(model.state_dict(), "lastmodelsafe.pth")

# %%
torch.save(model.state_dict(), "lastmodel.pth")

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('intermediate4.png',pred_dataset, model = model)

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
#for g in optimizer.param_groups:
#    g['lr'] = 0.0001

#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
#for g in optimizer.param_groups:
#    g['lr'] = 0.0001

model = DecoderRNN()
model.load_state_dict(torch.load('/content/drive/MyDrive/modelsaves/lastmodel-f-p100.pth'))
model = model.cuda()

optimizer = torch.optim.Adam(model.parameters(),lr = 0.000005, betas = (.9,.999))

# %%
#for seql in range(15,20,4):
seql = 38
for epoch in range (120):
  #model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      #writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    #model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
    
    torch.save(model.state_dict(), "lastmodelsafe.pth")

# %%
torch.save(model.state_dict(), "lastmodel-f-p100.pth")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
writer.flush()
writer.close()

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
#!nvidia-smi

# %%
with torch.no_grad():
  #model = model.eval()
  DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)

# %%
for name, param in model.named_parameters():
  print(name)

# %%
with torch.no_grad():
      #model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(38):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('testloss',loss)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#https://datascience.stackexchange.com/questions/64131/how-to-save-dynamic-files-from-colab-to-google-drive

# %%
# !cp -r *.pth /content/gdrive/MyDrive/modelsaves/
