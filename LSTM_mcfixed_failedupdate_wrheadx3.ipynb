# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamAshbee/splineexample/blob/main/LSTM_mcfixed_failedupdate_wrheadx3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# With progressive growing of the sequence, the loss drops more stably.

# %% [markdown]
# https://r2rt.com/non-zero-initial-states-for-recurrent-neural-networks.html

# %%
import torch
import numpy as np
import pylab as plt
from skimage import filters
import math

global numpoints
numpoints = 1000
side = 32

rows = torch.zeros(32,32)
columns = torch.zeros(32,32)


for i in range(32):
    columns[:,i] = i
    rows[i,:] = i


def donut_matrix(length = 10):

    radiusMax = side /3
    w = 1
    sigmas = [None, 1]
    
    canvas = torch.zeros((length,side, side))
    r0 = torch.tensor(np.random.uniform(side/4, side/3, length))

    radii = torch.zeros((length,numpoints))
    radii[:, :] = r0.unsqueeze(1)
    
    ind = [x for x in range(numpoints)]

    theta = torch.FloatTensor(ind)
    theta *= math.pi*2.0/(float)(numpoints)
    
    for i in range(1,length):
        a = np.random.uniform(1.0,3.0)*torch.sin(np.random.uniform(20.0)*theta+np.random.uniform(1000.0))
        #a = 4.0*torch.sin(10.0*theta)
        #print(a.shape,torch.max(a))
        radii[i,:] += a
        #print(radii.shape, torch.max(radii))
    
    assert torch.min(radii)>0
    #print(radii.max(axis = 0)[0].shape)
    rmaxs = radii.max(axis = 1)[0]
    pmins = rmaxs+1.0
    pmaxs = side-rmaxs-1.0
    x0 = np.random.uniform(pmins,pmaxs)
    y0 = np.random.uniform(pmins,pmaxs)
    x0[:]=side/2
    y0[:]=side/2
    x0 = torch.tensor(x0)
    y0 = torch.tensor(y0)
    
    x0 = x0.unsqueeze(1)
    y0 = y0.unsqueeze(1)
    #radii = torch.from_numpy(radii)
    xrfactors = torch.cos(theta).unsqueeze(0)
    yrfactors = torch.sin(theta).unsqueeze(0)
    
    print('x0_y0_r_xrf_yrf',x0.shape,y0.shape,radii.shape,xrfactors.shape,yrfactors.shape)

    x = (x0+(xrfactors*radii))
    y = (y0+(yrfactors*radii))
    assert x.shape == (length,numpoints)
    assert y.shape == (length,numpoints)
    assert torch.sum(x[x>(side-1)])==0 
    assert torch.sum(x[x<0])==0 
    assert torch.sum(y[y>(side-1)])==0 
    assert torch.sum(y[y<0])==0 
    
    points = torch.zeros(length,numpoints,2)
    for l in range(length):
        canvas[l,y[l,:].type(torch.LongTensor),x[l,:].type(torch.LongTensor)]=1.0
        points[l,:,0] = x[l,:]#modified for lstm discriminator
        points[l,:,1] = y[l,:]#modified for lstm discriminator 
    
    
    return {
        'canvas': canvas, 
        'points':points.type(torch.FloatTensor)}

def plot_all_model( sample = None, label=None,fig=None,ax=None):
    X = label[:,0]
    Y = label[:,1]
    img = sample[:,:].detach().squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    predres = 1000

    s = [.001 for x in range(predres)]
    
    assert len(s) == predres
    c = ['red' for x in range(predres)]
    assert len(c) == predres
    ax.scatter(X.detach().cpu().numpy(),Y.detach().cpu().numpy(),s = s,c = c)


def getXYs(model=None,loader_disp = None):

    outputs = torch.zeros(100,1000,2).cuda()
    h0 = None
    c0 = None
    
    for samples,labels in loader_disp:
      for i in range(38):
        optimizer.zero_grad()
        if i == 0:
          out, h0, c0,o,output,combin_lstm = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i)
          outputs[:,i*25:(i+1)*25,:] = out.detach()
        else:
          out, h0, c0,o,output,combin_lstm = model(samples.cuda(),labels[:,0,:2].cuda(),h0,c0,ind = i,o = o,output=output,combin_lstm=combin_lstm)
          outputs[:,i*25:(i+1)*25,:] = out.detach()

      return samples, outputs


          
        

def plot_all( sample = None, labels = None,fig = None,ax = None):
    img = sample[:,:].squeeze().cpu().numpy()
    ax.imshow(img, cmap=plt.cm.gray_r)
    X = labels[:,0]
    Y = labels[:,1]
    s = [.001 for x in range(numpoints)]
    c = ['red' for x in range(numpoints)]
    ax.scatter(X.cpu().numpy(),Y.cpu().numpy(),s = s,c = c)
    
class DonutDataset(torch.utils.data.Dataset):
    """Donut dataset."""
    def __init__(self, length = 10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.length = length
        self.values = donut_matrix(length)
        assert self.values['canvas'].shape[0] == self.length
        assert self.values['points'].shape[0] == self.length
        
        count = 0
        for i in range(self.length):
          a = self[i]
          c = a[0]
          for el in a[1]:
            #print(c[(int)(el[1]),(int)(el[0])].item())
            #assert c[(int)(el[1]),(int)(el[0])].item() == 1
            y,x = (int)(el[1]),(int)(el[0])
            if x < side-2 and x > 2 and y < side-2 and y > 2: 
              if c[y,x] != 1 and \
                c[y+1,x] != 1 and c[y+1,-1+x] != 1 and c[y+1,1+x] != 1 and \
                c[y-1,x] != 1 and c[y,-1+x] != 1 and c[y,1+x] != 1:
                count+=1
        assert count ==0
    def __len__(self):
        return self.length


    def __getitem__(self, idx):
        canvas = self.values["canvas"]
        
        canvas = canvas[idx,:,:]
        assert canvas.shape == (side,side)
        
        points = self.values["points"]
        points = points[idx,:]
        #points = points.unsqueeze(1)
        #z = torch.zeros(numpoints,1)
        #print(z.shape)
        #points = torch.cat([points,z], dim = 1)
        
        #print('points', points.shape)
        return canvas, points
    
    @staticmethod
    def displayCanvas(title,ddataset, model):
        #model.setBatchSize(batch_size = 1)
        fig = plt.figure()
          
        if model != None:
          model = model.eval()
          loader_disp = data.DataLoader(
            ddataset, 
            batch_size=100,
            num_workers=2)
          samples, outputs = getXYs(model=model,loader_disp = loader_disp)
          for i in range(100):
            ax = fig.add_subplot(10,10,i+1)
            plot_all_model(samples[i,:,:],outputs[i,:,:],fig=fig,ax=ax)
            plt.axis('off')

        else:
          for i in range(100):
            sample, labels = dataset[i]
            ax = fig.add_subplot(10,10,i+1)
            plot_all(sample = sample,labels = labels,fig = fig, ax= ax)
            plt.axis('off')

        fig.savefig(title,dpi=450)
        plt.close(fig) #where f is the figure
        plt.clf()
        plt.cla()
        plt.close()#should free memory
        print('open file: ',title)

# %%
dataset = DonutDataset(length = 100)

DonutDataset.displayCanvas('donut.png',dataset, model = None)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])
# open file:  donut.png

# %%
from torch.utils import data
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

mini_batch = 100
dataset = DonutDataset(length = 100*20)
loader_train = data.DataLoader(
    dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([2000, 1]) torch.Size([2000, 1]) torch.Size([2000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
mini_batch = 100
test_dataset = DonutDataset(length = 1000)
loader_test = data.DataLoader(
    test_dataset, 
    batch_size=mini_batch,
    sampler=RandomSampler(data_source=test_dataset),
    num_workers=2)
# Out:
# x0_y0_r_xrf_yrf torch.Size([1000, 1]) torch.Size([1000, 1]) torch.Size([1000, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
pred_dataset = DonutDataset(length = 100)
# Out:
# x0_y0_r_xrf_yrf torch.Size([100, 1]) torch.Size([100, 1]) torch.Size([100, 1000]) torch.Size([1, 1000]) torch.Size([1, 1000])

# %%
import torch
input_var = torch.randn(3, 5, 2)
  
# print size
print(input_var.size())
  
print(input_var)
  
# dimensions permuted
input_var = input_var.permute(2, 0, 1)
print(input_var.shape)
# Out:
# torch.Size([3, 5, 2])
# tensor([[[ 0.4241, -0.4265],
#          [ 1.1165, -0.1756],
#          [ 0.4450,  0.4333],
#          [-0.1873, -1.2086],
#          [-0.2241,  0.2508]],
#
#         [[ 1.0512, -1.1037],
#          [ 0.7432,  0.3933],
#          [-1.1511,  0.3238],
#          [-0.0366,  0.7087],
#          [ 0.6085,  0.8195]],
#
#         [[-1.9675,  0.7282],
#          [-0.5544, -2.0052],
#          [ 1.0746,  0.5908],
#          [-0.9826,  0.1404],
#          [ 0.1004,  0.7153]]])
# torch.Size([2, 3, 5])

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url

class DecoderRNN(nn.Module):
    def __init__(self):
        super(DecoderRNN, self).__init__()
        self.track = 0
        # define the properties
        self.embed_size = 2
        self.hidden_size = 256
        self.num_layers = 2
        self.seq_len = 25
        self.full_len = 1000
        self.longmem_len = int(self.full_len/self.seq_len)
        self.longtermMem = None
        self.longtermMemP = None
        self.lstm_cell = nn.LSTM(self.hidden_size*2, self.hidden_size,self.num_layers)

        self.inject_image =  nn.Sequential(
            nn.Linear(2*1000+1024+6*self.hidden_size,self.hidden_size*2),
            nn.ReLU()
        )

        
        self.fc_out = nn.Sequential(
            nn.Linear(2+self.hidden_size*4,10000),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(10000,2),
            nn.Sigmoid()
        )
        self.hi = nn.Sequential(
            nn.Linear(self.hidden_size*2+(self.num_layers*self.hidden_size),self.num_layers*self.hidden_size),
        )
        
        self.ci = nn.Sequential(
            nn.Linear(self.hidden_size*2+(self.num_layers*self.hidden_size),self.num_layers*self.hidden_size),
        )

        self.alpha_1 = nn.Sequential(
            nn.Linear(self.hidden_size*2,self.seq_len),
            nn.Softmax()
        )
        
        self.alpha_long1 = nn.Sequential(
            nn.Linear(self.hidden_size*2,self.longmem_len),
            nn.Softmax()
        )
        
        self.alpha_long2 = nn.Sequential(
            nn.Linear(self.hidden_size*2,self.longmem_len),
            nn.Softmax()
        )
        
        self.alpha_long3 = nn.Sequential(
            nn.Linear(self.hidden_size*2,self.longmem_len),
            nn.Softmax()
        )
        
        self.long_term_write = nn.Sequential(
            nn.Linear(self.hidden_size*(self.seq_len+1),self.hidden_size),
            nn.ReLU()
        )

        self.init_combin_lstm  = nn.Sequential(nn.Linear(1024,self.hidden_size*2),nn.ReLU())
        

        self.embs = None #= torch.empty((self.batch_size, 1000, self.hidden_size)).cuda()
        self.ltm_temp = None
        

            
        
    def forward(self, features, p0,h0 = None, c0= None, ind = 0, o = None,output = None,combin_lstm = None):
        #print('a')
        assert features != None
        self.track +=1
        batch_size = features.size(0)
        

        
        
        if o == None:
          out = p0
          self.longtermMem = torch.zeros(batch_size,self.longmem_len,self.hidden_size).cuda()
          self.embs = torch.empty((batch_size, self.seq_len, self.hidden_size)).cuda()
          self.longtermMemP = torch.zeros(batch_size,1000,2).cuda()
          self.ltm_temp = torch.zeros(batch_size,self.hidden_size).cuda()
        else:

          self.ltm_temp = self.long_term_write(torch.cat([torch.flatten(self.embs,start_dim=1),output.squeeze()],dim=1))
          self.longtermMem[:, ind-1, :] = self.ltm_temp
        
          self.embs = torch.empty((batch_size, self.seq_len, self.hidden_size)).cuda()
          
          out = o

        if h0 == None and c0 == None:
          h0 = torch.zeros(self.num_layers,batch_size,self.hidden_size).cuda()
          c0 = torch.zeros(self.num_layers,batch_size,self.hidden_size).cuda()
          
        
        hidden_state = h0
        cell_state = c0
        outputs = torch.empty((batch_size, self.seq_len, 2)).cuda()
        
        if output == None:
          output = torch.zeros(batch_size,self.hidden_size).cuda()
          combin_lstm = self.init_combin_lstm(torch.flatten(features,start_dim=1))
              
        for t in range(self.seq_len):
            #print('b')
            # for the first time step the input is the feature vector
            
            
            
            a1 = self.alpha_1(combin_lstm)
            outesreada1 = self.embs.clone()*a1.unsqueeze(2)#clone
            outesread1 = torch.sum(outesreada1,dim=1)
            
            
            al1 = self.alpha_long1(combin_lstm)
            outesreadal1 = self.longtermMem.detach()*al1.unsqueeze(2)#clone
            outesreadl1 = torch.sum(outesreadal1,dim=1)
            
            al2 = self.alpha_long2(combin_lstm)
            outesreadal2 = self.longtermMem.detach()*al2.unsqueeze(2)#clone
            outesreadl2 = torch.sum(outesreadal2,dim=1)
            
            al3 = self.alpha_long3(combin_lstm)
            outesreadal3 = self.longtermMem.detach()*al3.unsqueeze(2)#clone
            outesreadl3 = torch.sum(outesreadal3,dim=1)
              
            combin_lstm = torch.cat([torch.flatten(features,start_dim=1),torch.flatten(self.longtermMemP,start_dim=1),output.squeeze(),outesread1,outesreadl1,outesreadl2,outesreadl3,self.ltm_temp],dim=1)
            combin_lstm = self.inject_image(combin_lstm)
            

            hidden_state = hidden_state.permute(1,0,2)
            cell_state = cell_state.permute(1,0,2)
            
            hidden_state = self.hi(torch.cat([combin_lstm,torch.flatten(hidden_state,start_dim=1)],dim=1)).reshape(batch_size,self.num_layers,self.hidden_size).permute(1,0,2).contiguous()
            cell_state = self.hi(torch.cat([combin_lstm,torch.flatten(cell_state,start_dim=1)],dim=1)).reshape(batch_size,self.num_layers,self.hidden_size).permute(1,0,2).contiguous()

            output, (hidden_state, cell_state) = self.lstm_cell(combin_lstm.unsqueeze(0), (hidden_state, cell_state))

            outputs[:, t, :] = out
            self.longtermMemP[:,self.seq_len*ind+t,:] = out.detach()
            
            self.embs[:, t, :] = output.squeeze().clone().detach()
            

            combOut = torch.cat([combin_lstm, output.squeeze(),out,self.ltm_temp],dim=1)#,outesread],dim=1)
            

            out = self.fc_out(combOut)
            out = out*32.0
            # build the output tensor
            
        
            
        #self.embs = self.embs.detach().clone()
        return outputs, hidden_state.detach(), cell_state.detach(), out.detach(),output.detach(),combin_lstm.detach()#, captions

# %%
model = DecoderRNN().cuda()

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
for seql in range(3,23,4):
  #seql = 19
  for epoch in range (5):
    loss = None
    model = model.train()

    for x,y in loader_train:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        optimizer.zero_grad()
        
        if i == 0:
          out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output,combin_lstm=combin_lstm)
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        #writer.add_scalar("Loss/train", loss, epoch)
        
        loss.backward()
        optimizer.step()
      #print(y[:,0,:2])
      print('epoch',epoch,'seql',seql)
      print('train loss', loss)
    
    with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output,combin_lstm=combin_lstm)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 3
# train loss tensor(24.7582, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(46.9139, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(8.8807, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(11.4514, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.6951, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(6.9750, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(7.7790, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.4529, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.4694, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.5445, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(5.1572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.9428, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.3425, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.1173, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.6205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.2516, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(4.1654, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.9197, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.8585, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# train loss tensor(3.9559, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 3
# testloss tensor(1.2787, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.2857, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.5178, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.5065, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.2623, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.2000, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.1884, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.1922, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.4203, device='cuda:0')
# epoch 0 seql 3
# testloss tensor(1.3537, device='cuda:0')
# epoch 1 seql 3
# train loss tensor(4.0406, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.8033, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.7115, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.6966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.4424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.5032, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.4496, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.6124, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.4858, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.7502, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.6415, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.4026, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.4809, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.5560, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.6442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.2924, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.2497, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.2581, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0658, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# train loss tensor(3.0962, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 3
# testloss tensor(1.2895, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.1879, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.3730, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.2062, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.3557, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.3029, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.1318, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.4539, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.2519, device='cuda:0')
# epoch 1 seql 3
# testloss tensor(1.1686, device='cuda:0')
# epoch 2 seql 3
# train loss tensor(3.2250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.2065, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.0871, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.0296, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.0737, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.1829, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.0865, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.8910, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.9127, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.6662, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.8539, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.9624, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.0113, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.0311, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.0178, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.9268, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(3.1470, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.8182, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.8249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# train loss tensor(2.7664, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 3
# testloss tensor(1.1852, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.2977, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.0556, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.3585, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.1176, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.1895, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.2044, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.1433, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.4306, device='cuda:0')
# epoch 2 seql 3
# testloss tensor(1.3224, device='cuda:0')
# epoch 3 seql 3
# train loss tensor(2.8291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.8016, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.6728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.5520, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.8091, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.8748, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.5644, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.7463, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.5154, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.5008, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.8855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.5336, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.4944, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.2528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.1160, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.3681, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.7702, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.9975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.5366, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# train loss tensor(2.1409, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 3
# testloss tensor(1.5098, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.7239, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.2198, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.4472, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.5831, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.4960, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.6965, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.3410, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.2188, device='cuda:0')
# epoch 3 seql 3
# testloss tensor(1.5017, device='cuda:0')
# epoch 4 seql 3
# train loss tensor(2.3646, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.3755, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.3437, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.0252, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(1.9566, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.2740, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.0915, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(1.9646, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(1.9574, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(1.8997, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(1.7860, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.5249, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(5.7691, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(6.7166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(3.7993, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.6971, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(3.4286, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(3.2421, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(2.6290, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# train loss tensor(3.6305, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 3
# testloss tensor(2.5337, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.1052, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.0358, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.1406, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.2453, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.1986, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(1.9759, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.3911, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.2100, device='cuda:0')
# epoch 4 seql 3
# testloss tensor(2.3529, device='cuda:0')
# epoch 0 seql 7
# train loss tensor(17.4530, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(65.4994, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(85.9597, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(4.4345, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(13.5137, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(25.5079, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(3.4561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(13.2483, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(4.0882, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(3.8554, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(3.7682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(2.6607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(2.8730, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(2.4450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(2.8824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(3.0827, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(2.6572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(2.1130, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(2.6278, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# train loss tensor(2.4158, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 7
# testloss tensor(1.2971, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(1.1607, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(1.3393, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(1.3676, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(1.2988, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(0.9595, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(1.2198, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(1.1656, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(1.2182, device='cuda:0')
# epoch 0 seql 7
# testloss tensor(1.3783, device='cuda:0')
# epoch 1 seql 7
# train loss tensor(2.1074, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.0902, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(1.9890, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.2570, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.0301, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.1264, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(1.8894, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.6196, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.6339, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(1.7258, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.4442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(3.4366, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.2107, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.7467, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(2.5455, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(1.9361, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(1.6756, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(1.7966, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(1.5390, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# train loss tensor(1.7052, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 7
# testloss tensor(1.2442, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(1.3503, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(1.2519, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(1.1656, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(1.1300, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(1.1125, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(1.0497, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(0.9549, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(1.1441, device='cuda:0')
# epoch 1 seql 7
# testloss tensor(1.2212, device='cuda:0')
# epoch 2 seql 7
# train loss tensor(1.6823, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.6053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.4517, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.7101, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.7070, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(2.1231, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(2.0577, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(2.3941, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(2.6464, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(2.1800, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(2.2115, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(2.0449, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.7799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.7883, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.9197, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.7596, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.4486, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.5256, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.7067, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# train loss tensor(1.5688, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 7
# testloss tensor(2.1519, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(2.1242, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(2.3050, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(2.3980, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(2.3030, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(2.1053, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(2.2563, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(2.4194, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(1.9458, device='cuda:0')
# epoch 2 seql 7
# testloss tensor(1.7606, device='cuda:0')
# epoch 3 seql 7
# train loss tensor(1.5031, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.5607, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.8624, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.5933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.9303, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(2.7245, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(2.5269, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.7272, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.9805, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.9410, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.7434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(2.2187, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.5038, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.4646, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.4315, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.5864, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.4024, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.4561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.2247, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# train loss tensor(1.5775, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 7
# testloss tensor(1.1702, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.2725, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.1636, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.1102, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.1249, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.1702, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.2360, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.0855, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.1469, device='cuda:0')
# epoch 3 seql 7
# testloss tensor(1.1108, device='cuda:0')
# epoch 4 seql 7
# train loss tensor(1.3914, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.1360, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.2739, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.3698, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.5146, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.4838, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.5406, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.4931, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.3990, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.4071, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.7726, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.6453, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.5979, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.3718, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.5413, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.4348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.4637, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.6687, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.6236, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# train loss tensor(1.5339, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 7
# testloss tensor(1.3996, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.2051, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.3365, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.1453, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.2473, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.2856, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.2754, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.3507, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.3811, device='cuda:0')
# epoch 4 seql 7
# testloss tensor(1.3395, device='cuda:0')
# epoch 0 seql 11
# train loss tensor(2.0461, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(3.7372, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(36.5313, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(7.8133, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(6.9511, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(23.0247, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(9.5956, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(20.4125, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(25.1046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(5.3599, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(4.8810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(2.5679, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(6.3809, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(7.8648, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(1.8758, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(2.0642, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(1.6628, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(2.0374, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(1.7872, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# train loss tensor(1.7004, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 11
# testloss tensor(1.1562, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.5137, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.4140, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.2928, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.2512, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.3030, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.2265, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.3545, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.5677, device='cuda:0')
# epoch 0 seql 11
# testloss tensor(1.3843, device='cuda:0')
# epoch 1 seql 11
# train loss tensor(1.6766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.5757, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.7363, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.6312, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.4219, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.5688, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.6307, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.6123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.4693, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.5978, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.5047, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.6153, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.4975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.2896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.5165, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.4439, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.5326, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.3268, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.3673, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# train loss tensor(1.4409, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 11
# testloss tensor(1.3934, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.5020, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.0886, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.3981, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.2929, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.2259, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.2939, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.1009, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.3037, device='cuda:0')
# epoch 1 seql 11
# testloss tensor(1.2276, device='cuda:0')
# epoch 2 seql 11
# train loss tensor(1.3066, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.4042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.3728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.4597, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.5568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.4309, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.2523, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.3333, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.4450, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.5572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.4703, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.6935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.6083, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.6000, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.3855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.5999, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.5868, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.3049, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.4181, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# train loss tensor(1.3663, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 11
# testloss tensor(1.2219, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.3876, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.2079, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.3231, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.3066, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.0748, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.3764, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.1553, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.1774, device='cuda:0')
# epoch 2 seql 11
# testloss tensor(1.3968, device='cuda:0')
# epoch 3 seql 11
# train loss tensor(1.2935, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.5521, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.3566, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.3782, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.4185, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.3821, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.3582, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.5206, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.2593, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.4342, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.4171, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.3517, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.4713, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.3402, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.2785, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.4570, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.4846, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.4111, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.4328, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# train loss tensor(1.5375, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 11
# testloss tensor(1.2585, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(1.2267, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(1.2474, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(1.2381, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(1.1291, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(1.1760, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(1.2381, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(1.0691, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(1.3158, device='cuda:0')
# epoch 3 seql 11
# testloss tensor(0.9834, device='cuda:0')
# epoch 4 seql 11
# train loss tensor(1.5065, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.3467, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.6605, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.3880, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.3626, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.5267, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.4672, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.3943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.4794, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.5447, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.6050, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.9561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.5854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(2.0073, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.8446, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.5072, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.3216, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.3443, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.3212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# train loss tensor(1.3510, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 11
# testloss tensor(1.1833, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.4795, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.2245, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.4110, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.4130, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.4997, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.3134, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.2682, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.3456, device='cuda:0')
# epoch 4 seql 11
# testloss tensor(1.2353, device='cuda:0')
# epoch 0 seql 15
# train loss tensor(7.4728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(3.9321, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(7.1137, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(3.5118, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.3275, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(3.1930, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(5.3454, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.5624, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(10.9893, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.1108, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.0216, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.4822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(5.7803, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.0592, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(1.9822, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(2.5523, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(1.5288, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(1.5219, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(1.3486, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# train loss tensor(1.4640, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 15
# testloss tensor(1.2250, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.3454, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.1942, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.2635, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.2644, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.1049, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.1400, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.2541, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.3148, device='cuda:0')
# epoch 0 seql 15
# testloss tensor(1.3025, device='cuda:0')
# epoch 1 seql 15
# train loss tensor(1.6171, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3834, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.4218, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.4513, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3895, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.4970, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.4703, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3723, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.2711, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3727, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3609, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3546, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3758, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3175, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.4762, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.4561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.3574, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.5585, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.4062, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# train loss tensor(1.2799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 15
# testloss tensor(1.1264, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.1306, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.2605, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.2330, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.3289, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.0966, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.3767, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.2650, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.4207, device='cuda:0')
# epoch 1 seql 15
# testloss tensor(1.3577, device='cuda:0')
# epoch 2 seql 15
# train loss tensor(1.6141, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.9503, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.5557, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(3.1755, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(2.0778, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(2.7689, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(2.0252, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.9203, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.6766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.3704, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.4760, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.5434, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.2538, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.3702, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.6291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.4604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.6500, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.4874, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.4064, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# train loss tensor(1.5210, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 15
# testloss tensor(1.1062, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.2782, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.1563, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.3044, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.1121, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.1364, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.1297, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.3351, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.2134, device='cuda:0')
# epoch 2 seql 15
# testloss tensor(1.2514, device='cuda:0')
# epoch 3 seql 15
# train loss tensor(1.3250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.4755, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.2532, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.4160, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.5654, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.6901, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.4264, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.3702, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.5449, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(2.6774, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.4490, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(7.5377, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.4378, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.5103, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(2.5842, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(2.0559, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.3583, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.5032, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.6357, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# train loss tensor(1.6451, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 15
# testloss tensor(1.5561, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.4717, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.3207, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.4106, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.6125, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.5031, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.4984, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.4685, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.6333, device='cuda:0')
# epoch 3 seql 15
# testloss tensor(1.5632, device='cuda:0')
# epoch 4 seql 15
# train loss tensor(1.6294, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3813, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3553, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.2068, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3791, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3906, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.4484, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.2375, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.2545, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.1915, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.4400, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.2243, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3912, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3362, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3915, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.4420, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3039, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.4246, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.3933, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# train loss tensor(1.2761, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 15
# testloss tensor(1.1228, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.2620, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.2370, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.2479, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.1437, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.2136, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.2913, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.0489, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.1810, device='cuda:0')
# epoch 4 seql 15
# testloss tensor(1.2201, device='cuda:0')
# epoch 0 seql 19
# train loss tensor(5.4731, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(10.7080, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(7.2274, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(5.6552, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(3.4431, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(4.9613, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(12.2442, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(3.4354, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(2.6475, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(3.4171, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(2.4599, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(1.9918, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(5.5705, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(12.6104, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(4.4388, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(1.9541, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(1.7549, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(2.1474, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(2.6716, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# train loss tensor(1.9543, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 19
# testloss tensor(1.5289, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.4995, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.3697, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.3580, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.5611, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.2455, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.4151, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.5550, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.4929, device='cuda:0')
# epoch 0 seql 19
# testloss tensor(1.5235, device='cuda:0')
# epoch 1 seql 19
# train loss tensor(2.0396, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.9452, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(2.0046, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(2.8604, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.8027, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(2.6921, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.8322, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.7123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.5982, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.6418, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.5300, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.5784, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.4002, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.5166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.4943, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.5690, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.4815, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.6062, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.5300, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# train loss tensor(1.3188, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 19
# testloss tensor(1.1356, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.3041, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.3652, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.2668, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.3978, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.6822, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.3766, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.3403, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.3011, device='cuda:0')
# epoch 1 seql 19
# testloss tensor(1.2160, device='cuda:0')
# epoch 2 seql 19
# train loss tensor(1.6004, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.4824, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.5685, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.5368, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.5530, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.5729, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(2.1215, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(2.0619, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.6991, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.9222, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.7799, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.6975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.5997, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.7536, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.5893, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.4374, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.5699, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.8088, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.5667, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# train loss tensor(1.8196, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 19
# testloss tensor(1.2148, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.2812, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.1042, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.4268, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.2074, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.4728, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.2794, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.4402, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.2066, device='cuda:0')
# epoch 2 seql 19
# testloss tensor(1.2869, device='cuda:0')
# epoch 3 seql 19
# train loss tensor(1.6098, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(2.0852, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(2.0024, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.4390, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.8176, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(2.4576, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.9356, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.6354, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.5710, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.7353, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.6032, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.7248, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.5063, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.7526, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.4007, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.3276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.5435, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.6882, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.5314, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# train loss tensor(1.6923, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 19
# testloss tensor(1.3564, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.4196, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.3821, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.4595, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.2972, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.2528, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.3822, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.5371, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.2493, device='cuda:0')
# epoch 3 seql 19
# testloss tensor(1.3309, device='cuda:0')
# epoch 4 seql 19
# train loss tensor(1.7931, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(2.2320, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.7125, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.7632, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.7856, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(2.0720, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.7036, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.5548, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.5302, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.7828, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.5945, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.6984, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.4897, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.7320, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.4887, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.6680, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.4183, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.6276, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.6168, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# train loss tensor(1.5812, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 19
# testloss tensor(1.4208, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.4326, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.5492, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.3951, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.3960, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.3390, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.3891, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.2690, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.3609, device='cuda:0')
# epoch 4 seql 19
# testloss tensor(1.3202, device='cuda:0')

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate1.png',pred_dataset, model = model)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# open file:  intermediate1.png

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.0001, betas = (.9,.999))#ideal

for g in optimizer.param_groups:
    g['lr'] = 0.0001

# %%
#for seql in range(15,20,4):
seql = 23
for epoch in range (20):
  model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output,combin_lstm=combin_lstm)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output,combin_lstm=combin_lstm)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0 seql 23
# tensor(5.5118, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(9.7480, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(13.1095, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(6.4875, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(12.2373, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(5.6972, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(3.0615, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(7.1539, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(3.2053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(3.9382, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(4.4264, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(3.2845, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.3888, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(3.1588, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.9262, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(4.9932, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.5876, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.0709, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(2.2832, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# tensor(1.9934, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 0 seql 23
# testloss tensor(1.4310, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.6001, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.3429, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.3066, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.3487, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.1036, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.5264, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.5710, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.6501, device='cuda:0')
# epoch 0 seql 23
# testloss tensor(1.2141, device='cuda:0')
# epoch 1 seql 23
# tensor(1.8226, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.8295, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.7379, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.8525, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.8425, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.7900, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.7393, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.8710, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.6732, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.6531, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(2.0527, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.6742, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.8174, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.8810, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.7503, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.7237, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.7171, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.6543, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.6273, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# tensor(1.7241, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 1 seql 23
# testloss tensor(1.4145, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3570, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3427, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3443, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.2715, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3516, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.2851, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.2948, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3116, device='cuda:0')
# epoch 1 seql 23
# testloss tensor(1.3020, device='cuda:0')
# epoch 2 seql 23
# tensor(2.0205, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.8840, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.9793, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.9773, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.9589, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(2.4777, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.7561, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(2.7196, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.9536, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.7411, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.5975, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.6078, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.7687, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(2.1098, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.7351, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(2.0241, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(2.3689, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.6022, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.6097, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# tensor(1.9467, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 2 seql 23
# testloss tensor(1.4032, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.6114, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.3030, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.5439, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.7779, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.5015, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.7351, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.6213, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.4868, device='cuda:0')
# epoch 2 seql 23
# testloss tensor(1.4539, device='cuda:0')
# epoch 3 seql 23
# tensor(1.9352, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.2572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.1953, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.2568, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.2405, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.4713, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.6690, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.8758, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.5936, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.2528, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.8896, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.1024, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.8855, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.5053, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.5537, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.8231, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(1.7766, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.1483, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.2646, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# tensor(2.1682, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 3 seql 23
# testloss tensor(1.4121, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.4414, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.4883, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.7195, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.3728, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.8336, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.5108, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.5342, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.2459, device='cuda:0')
# epoch 3 seql 23
# testloss tensor(1.3414, device='cuda:0')
# epoch 4 seql 23
# tensor(2.1615, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.6115, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.4981, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.9897, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.6647, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(2.5746, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(2.2134, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(2.4166, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(2.0469, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.6293, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.8420, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(2.2646, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.4621, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(2.1906, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.9067, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.8163, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.8212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.8116, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(1.6779, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# tensor(2.6354, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 4 seql 23
# testloss tensor(1.4397, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.6988, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.6726, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.8433, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.8494, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.8570, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.6022, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.8960, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(1.9211, device='cuda:0')
# epoch 4 seql 23
# testloss tensor(2.1615, device='cuda:0')
# epoch 5 seql 23
# tensor(2.2878, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(2.4253, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.4490, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.7904, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.7104, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.9212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.8324, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(2.3716, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(2.5112, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.8039, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.7686, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.6388, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.5753, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.6608, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.5279, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.6993, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.7884, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(2.0719, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.6650, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# tensor(1.6627, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 5 seql 23
# testloss tensor(1.4109, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.1924, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.5103, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.3396, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.1930, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.3342, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.1379, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.3822, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.4957, device='cuda:0')
# epoch 5 seql 23
# testloss tensor(1.2869, device='cuda:0')
# epoch 6 seql 23
# tensor(1.6042, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.4488, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.6751, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.5209, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.1327, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.7854, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.5077, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.6129, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.7385, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.8742, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.0256, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.8394, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.1256, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.6232, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(1.7282, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.5483, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.1348, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(3.0279, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.1949, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# tensor(2.0645, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 6 seql 23
# testloss tensor(1.5376, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.4887, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.5870, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.4315, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.3600, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.4921, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.6299, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.3248, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.3892, device='cuda:0')
# epoch 6 seql 23
# testloss tensor(1.5517, device='cuda:0')
# epoch 7 seql 23
# tensor(2.0265, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.0360, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.6784, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.9291, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.3244, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.9478, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.5930, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.4875, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.4494, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.8187, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.7617, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(6.0212, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.3471, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.2347, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.6841, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.6381, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.5787, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.1132, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(1.8220, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# tensor(2.4501, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 7 seql 23
# testloss tensor(1.8375, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(2.0544, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.7958, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.5330, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(2.0632, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(2.0225, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.5278, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(1.9383, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(2.0108, device='cuda:0')
# epoch 7 seql 23
# testloss tensor(2.1552, device='cuda:0')
# epoch 8 seql 23
# tensor(1.6904, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.6572, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.7505, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.3678, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.4979, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.3534, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.8151, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.6486, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.4202, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.6365, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(2.1638, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(2.7194, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(2.0259, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(4.2352, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(2.0279, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.6713, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.4729, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.6989, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(1.6906, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# tensor(2.7633, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 8 seql 23
# testloss tensor(2.0323, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(2.4938, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(2.6436, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(2.0620, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(2.3373, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(2.0381, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(2.0856, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(1.8290, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(2.4173, device='cuda:0')
# epoch 8 seql 23
# testloss tensor(2.1300, device='cuda:0')
# epoch 9 seql 23
# tensor(1.6477, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.9062, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.7215, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.6391, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.5204, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.4112, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.6241, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(2.6728, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.7123, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(2.6502, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.7924, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(2.0764, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.7734, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.8677, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.8917, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.9657, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(2.0250, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(2.3232, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(1.4816, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# tensor(2.5020, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 9 seql 23
# testloss tensor(1.9822, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.8652, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.7717, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.7112, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.9379, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(2.0810, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.8298, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.8899, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.7076, device='cuda:0')
# epoch 9 seql 23
# testloss tensor(1.7501, device='cuda:0')
# epoch 10 seql 23
# tensor(1.6920, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(2.0849, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.8748, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.6617, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.8424, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(3.2496, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.5058, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.9207, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.6918, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.5992, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.6973, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(2.8924, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.2884, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.7321, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.4539, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(2.4255, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.7321, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(3.3716, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(1.8421, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# tensor(2.7787, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 10 seql 23
# testloss tensor(2.6738, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.7877, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.7285, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.4860, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.5044, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.7159, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.6604, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.3782, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.7399, device='cuda:0')
# epoch 10 seql 23
# testloss tensor(2.8608, device='cuda:0')
# epoch 11 seql 23
# tensor(3.9582, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(3.1340, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# epoch 11 seql 23
# tensor(nan, device='cuda:0', grad_fn=<MeanBackward0>)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-104-0e2665cdc12d> in <module>()
#      41         loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
#      42
# ---> 43         assert not torch.any(torch.isnan(out)).item()
#      44         assert not torch.any(torch.isnan(y)).item()
#      45
#
# AssertionError:

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate2.png',pred_dataset, model = model)

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
for g in optimizer.param_groups:
    g['lr'] = 0.00001

# %%
model = model.train()
#for seql in range(15,20,4):
seql = 23
for epoch in range (10):
  loss = None
  model = model.train()
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output,combin_lstm)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i,combin_lstm)
          else:
            out, h0, c0,o,output,combin_lstm = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output,combin_lstm)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)

# %% [markdown]
# ran so well, interrupted

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate3.png',pred_dataset, model = model)

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
for g in optimizer.param_groups:
    g['lr'] = 0.0001

# %%
for seql in range(23,39,4):
  #seql = 19
  for epoch in range (5):
    loss = None
    model = model.train()

    for x,y in loader_train:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        optimizer.zero_grad()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        #writer.add_scalar("Loss/train", loss, epoch)
        
        loss.backward()
        optimizer.step()
      #print(y[:,0,:2])
      print('epoch',epoch,'seql',seql)
      print('train loss', loss)
    
    with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate4.png',pred_dataset, model = model)

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
for g in optimizer.param_groups:
    g['lr'] = 0.0001

# %%
#for seql in range(15,20,4):
seql = 38
for epoch in range (20):
  model = model.train()
  loss = None
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
    model = model.eval()
    for x,y in loader_test:
      h0 = None
      c0 = None
      for i in range(seql):
        x = x.cuda()
        y = y.cuda()
        
        if i == 0:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
        else:
          out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
        
        loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      
        assert not torch.any(torch.isnan(out)).item()
        assert not torch.any(torch.isnan(y)).item()
      
      print('epoch',epoch,'seql',seql)
      print('testloss',loss)

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('intermediate5.png',pred_dataset, model = model)

# %%
#optimizer = torch.optim.Adam(model.parameters(),lr = 0.00001, betas = (.9,.999))#ideal
for g in optimizer.param_groups:
    g['lr'] = 0.00001

# %%
model = model.train()
#for seql in range(15,20,4):
seql = 38
for epoch in range (60):
  loss = None
  model = model.train()
  for x,y in loader_train:
    h0 = None
    c0 = None
    for i in range(seql):
      x = x.cuda()
      y = y.cuda()
      
      optimizer.zero_grad()
      
      if i == 0:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
      else:
        out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
      loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
      writer.add_scalar("Loss/train", loss, epoch)
      
      loss.backward()
      optimizer.step()
    #print(y[:,0,:2])
    print('epoch',epoch,'seql',seql)
    print(loss)
  with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)

# %%
writer.flush()
writer.close()

# %%
#%load_ext tensorboard

# %%
#!kill 3285
#%tensorboard --logdir runs

# %%
#!nvidia-smi

# %%
with torch.no_grad():
  model = model.eval()
  DonutDataset.displayCanvas('lstmpredictions.png',pred_dataset, model = model)

# %%
for name, param in model.named_parameters():
  print(name)

# %%
with torch.no_grad():
      model = model.eval()
      for x,y in loader_test:
        h0 = None
        c0 = None
        for i in range(seql):
          x = x.cuda()
          y = y.cuda()
          
          if i == 0:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i)
          else:
            out, h0, c0,o,output = model(x,y[:,0,:2],h0,c0,ind = i,o = o,output=output)
          
          loss = torch.mean((out-y[:,1+(25*i):1+(25*(i+1)),:2])**2)
        
          assert not torch.any(torch.isnan(out)).item()
          assert not torch.any(torch.isnan(y)).item()
        
        print('epoch',epoch,'seql',seql)
        print('testloss',loss)
